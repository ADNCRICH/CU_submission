# %% [markdown]
# # **2110433 - Computer Vision (2023/2)**
# #**Lab 8 - Convolutional Neural Network [Homework]** <br>
# In this lab, we will learn how to use Convolutional Neural Network to perform image classification in the provided real world dataset using PyTorch. This notebook includes both coding and written questions. Please hand in this notebook file with all outputs and your answer.
#
# **Collaboration is encouraged in this course.** You must turn in your own write ups of all problems. If you collaborate with others, you must put the names and ids of the students you worked with in below block.
#
# Collaboration List:
# - ...
# - ...

# %% [markdown]
# # Assignment 1 : Food Image Classification
# ![alt text](https://cdn.pixabay.com/photo/2015/08/26/10/58/the-pork-fried-rice-made-908333_1280.jpg)
#
# Classify 50 food menus from Chula-Food-50 dataset
#
#
# In this assignment you have to replace YOUR_STUDENT_ID_WITH21 variable with your student id (in integer). There will be 2 sets of data: train and test
#
# By using the knowledge from the lab and lecture, you have to design your own CNN food image classification model and tested on unknown label dataset!
#
#
#
# Scoreboard URL : https://www.piclab.ai/classes/cv2023/lab8/scoreboard

# %%
import random
import glob
import os
import numpy as np
import cv2
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm
import matplotlib
from matplotlib import font_manager

import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, Subset
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torchvision import models as models
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

##### Add Thai font ######

# !wget https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
font_manager.fontManager.addfont(path= 'thsarabunnew-webfont.ttf')
matplotlib.rc('font', family='TH Sarabun New')

##### Don't forget to put your ID here (in integer) ####
YOUR_STUDENT_ID_WITH21 = 6432085221
#######################################################

def isStudentIDValid(studentID):
  strID = str(studentID)
  isEndWith21 = strID.endswith('21')
  isLengthOK = len(strID) == 10
  if isEndWith21 and isLengthOK:
    return True
  else:
    return False

print('Student ID status:',isStudentIDValid(YOUR_STUDENT_ID_WITH21))
# Out:
# Student ID status: True

# %% [markdown]
# ## Your model description goes here: ###
# WRITE HERE

# %% [markdown]
# ## GPU Status Check

# %%
# !nvidia-smi
# Out:
# Sat Mar 23 01:57:39 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.08              Driver Version: 545.23.08    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4080        On  | 00000000:01:00.0  On |                  N/A |
# |  0%   43C    P8              15W / 340W |    464MiB / 16376MiB |      3%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1259      G   /usr/lib/xorg/Xorg                          194MiB |
# |    0   N/A  N/A      1501      G   /usr/bin/gnome-shell                         28MiB |
# |    0   N/A  N/A      8818      G   ...seed-version=20240321-050138.474000       45MiB |
# |    0   N/A  N/A     14015      G   gnome-control-center                          3MiB |
# |    0   N/A  N/A     14247      G   ...sion,SpareRendererForSitePerProcess      175MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Download and inspect Chula-Food-50 dataset

# %%
# !wget  -O assets/Lab8/chula-food-50.zip https://piclab.ai/classes/cv2021/Chula-food-50.zip
# !unzip -qo chula-food-50.zip

# %%
### Helper function to display image from dataset ###
def getImageFromDataset(dataset, idx):
  sampleImage, sampleLabel = dataset.__getitem__(idx)
  ### Revert transformation ###
  sampleImage = ((sampleImage.permute(1,2,0).numpy() * np.array([0.229, 0.224, 0.225])) + np.array([0.485, 0.456, 0.406]))*255
  sampleImage = sampleImage.astype(np.uint8)
  sampleClassName = dataset.classes[sampleLabel]
  return sampleImage, sampleClassName

# %%
#### FILL Any Augmenetation HERE ####
transformTrain = transforms.Compose([
        transforms.Resize(size=(224,224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])

transformVal =  transforms.Compose([
        transforms.Resize(size=(224,224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
### Load Dataset ###
foodTrainDataset = ImageFolder('train/', transform=transformTrain)
# foodTestDataset = ImageFolder('foodpic/test/', transform=transformVal)

print('Number of classes:', len(foodTrainDataset.classes))
# Out:
# Number of classes: 50

# %%
### Split train and validation ###
TEST_SIZE = 0.1
SEED = 42
BATCH_SIZE = 16
# generate indices: instead of the actual data we pass in integers instead
train_indices, test_indices, _, _ = train_test_split(
    range(len(foodTrainDataset)),
    foodTrainDataset.targets,
    stratify=foodTrainDataset.targets,
    test_size=TEST_SIZE,
    random_state=SEED
)

# generate subset based on indices
train_split = Subset(foodTrainDataset, train_indices)
test_split = Subset(foodTrainDataset, test_indices)

# %% [markdown]
# ## Dataset Visualization

# %%
image1, image1ClassName = getImageFromDataset(foodTrainDataset, 0)
image2, image2ClassName = getImageFromDataset(foodTrainDataset, 1600)

_, figure = plt.subplots(1,2)

figure[0].imshow(image1,cmap='gray')
figure[0].set_title(image1ClassName)
figure[1].imshow(image2,cmap='gray')
figure[1].set_title(image2ClassName)
plt.show()

# %% [markdown]
# ## Define CNN network for food classification
# Hint
# 1. You can freely uses any structure/pretrained model to do this homework but don't forgot to cited them in this notebook.
#
#    A very big collection of pretrained model can be found here : https://github.com/rwightman/pytorch-image-models
#
# 2. Don't forget to change mean and std in the pre-processing to match with your pretrained model.

# %%
import os 

l = os.listdir('dataset/train/')
for idx, name in enumerate(l):
    print(str(idx) + ": " + name)

# %%
from glob import glob

thr = 0.1
with open('dataset/train.txt', 'w') as train_f, open('dataset/val.txt', 'w') as val_f:
    for idx, name in enumerate(glob('dataset/train/*/*')):
        nn = np.random.rand()
        if nn < thr:
            val_f.write('./' + name + '\n')
        else:
            train_f.write('./' + name + '\n')

# %%
import shutil

with open('dataset/train.txt', 'r') as f:
    for line in f:
        line = line.strip()
        fold = line.split('/')[3]
        if not os.path.exists('dataset/mytrain/' + fold):
            os.makedirs('dataset/mytrain/' + fold)
        shutil.copy(line, 'dataset/mytrain/' + fold)

with open('dataset/val.txt', 'r') as f:
    for line in f:
        line = line.strip()
        fold = line.split('/')[3]
        if not os.path.exists('dataset/myval/' + fold):
            os.makedirs('dataset/myval/' + fold)
        shutil.copy(line, 'dataset/myval/' + fold)

# %%
import multiprocessing

bind = "127.0.0.1:8000"
workers = multiprocessing.cpu_count() * 2 + 1
print(workers)
# Out:
# 49

# %%
print(torch.get_num_threads())
print(torch.get_num_interop_threads())
# Out:
# 16
# 24

# %%
from ultralytics import YOLO

torch.cuda.empty_cache()

yolo_model = YOLO('yolov8l-cls.pt')
config = {
    'model' : yolo_model,
    'data' : 'dataset',
    'epochs' : 30,
    'batch' : 48,
    'imgsz' : [512, 512],
    'device' : 0,
    'workers' : 20,
    'verbose' : True
}
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8l-cls.pt to 'yolov8l-cls.pt'...
# 100%|██████████| 71.7M/71.7M [01:25<00:00, 880kB/s]

# %%
# %env OPENBLAS_MAIN_FREE=1
# Out:
# env: OPENBLAS_MAIN_FREE=1

# %%
yolo_model.train(data=config['data'],
                        epochs=config['epochs'],
                        batch=config['batch'],
                        imgsz=config['imgsz'],
                        device=config['device'],
                        workers=config['workers'],
                        verbose=config['verbose'])
# Out:
# New https://pypi.org/project/ultralytics/8.1.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.16 🚀 Python-3.12.2 torch-2.2.1 CUDA:0 (NVIDIA GeForce RTX 4080, 16071MiB)
# engine/trainer: task=classify, mode=train, model=yolov8l-cls.pt, data=dataset, epochs=30, time=None, patience=100, batch=48, imgsz=[512, 512], save=True, save_period=-1, cache=False, device=0, workers=20, project=None, name=train4, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/classify/train4
# train: /home/andre/Desktop/CU_submission/chulacv2023/Lab8/dataset/train... found 18007 images in 50 classes ✅
# val: /home/andre/Desktop/CU_submission/chulacv2023/Lab8/dataset/val... found 1993 images in 50 classes ✅
# test: None...
# Overriding model.yaml nc=1000 with nc=50
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   4720640  ultralytics.nn.modules.conv.Conv             [512, 1024, 3, 2]
#   8                  -1  3  17836032  ultralytics.nn.modules.block.C2f             [1024, 1024, 3, True]
#   9                  -1  1   1377330  ultralytics.nn.modules.head.Classify         [1024, 50]
# YOLOv8l-cls summary: 183 layers, 36263794 parameters, 36263794 gradients
# Transferred 300/302 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# WARNING ⚠️ updating to 'imgsz=512'. 'train' and 'val' imgsz must be an integer, while 'predict' and 'export' imgsz may be a [h, w] list or an integer, i.e. 'yolo export imgsz=640,480' or 'yolo export imgsz=640'
# train: Scanning /home/andre/Desktop/CU_submission/chulacv2023/Lab8/dataset/train... 18007 images, 0 corrupt: 100%|██████████| 18007/18007 [00:00<?, ?it/s]
# val: Scanning /home/andre/Desktop/CU_submission/chulacv2023/Lab8/dataset/val... 1993 images, 0 corrupt: 100%|██████████| 1993/1993 [00:00<?, ?it/s]
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 50 weight(decay=0.0), 51 weight(decay=0.000375), 51 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 20 dataloader workers
# Logging results to runs/classify/train4
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/30      12.8G      2.615          7        512: 100%|██████████| 376/376 [02:00<00:00,  3.13it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  5.02it/s]
#                    all      0.773      0.941
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30      13.1G     0.8614          7        512: 100%|██████████| 376/376 [01:51<00:00,  3.37it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.98it/s]
#                    all      0.817      0.958
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30      13.1G     0.6975          7        512: 100%|██████████| 376/376 [01:48<00:00,  3.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  5.01it/s]
#                    all      0.813      0.956
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30      13.1G     0.6212          7        512: 100%|██████████| 376/376 [01:52<00:00,  3.35it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.79it/s]
#                    all      0.826       0.96
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30      13.1G     0.5063          7        512: 100%|██████████| 376/376 [01:44<00:00,  3.59it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  5.07it/s]
#                    all      0.839      0.956
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30      13.1G     0.4381          7        512: 100%|██████████| 376/376 [01:44<00:00,  3.60it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  5.09it/s]
#                    all      0.861      0.966
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30      13.1G     0.3641          7        512: 100%|██████████| 376/376 [01:45<00:00,  3.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.89it/s]
#                    all      0.871      0.969
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30      13.1G      0.308          7        512: 100%|██████████| 376/376 [01:44<00:00,  3.59it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.76it/s]
#                    all      0.875      0.964
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30      13.1G     0.2765          7        512: 100%|██████████| 376/376 [01:45<00:00,  3.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.82it/s]
#                    all      0.877      0.971
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30      13.1G     0.2482          7        512: 100%|██████████| 376/376 [01:45<00:00,  3.56it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.77it/s]
#                    all      0.893      0.973
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30      13.2G     0.2155          7        512: 100%|██████████| 376/376 [01:47<00:00,  3.49it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.88it/s]
#                    all      0.885      0.974
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30      13.1G     0.1948          7        512: 100%|██████████| 376/376 [01:46<00:00,  3.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.76it/s]
#                    all      0.884      0.972
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30      13.1G     0.1785          7        512: 100%|██████████| 376/376 [01:46<00:00,  3.54it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.88it/s]
#                    all        0.9      0.975
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30      13.1G     0.1576          7        512: 100%|██████████| 376/376 [01:43<00:00,  3.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.76it/s]
#                    all      0.899      0.974
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30      13.1G     0.1464          7        512: 100%|██████████| 376/376 [01:45<00:00,  3.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.81it/s]
#                    all      0.896      0.973
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30      13.1G      0.122          7        512: 100%|██████████| 376/376 [01:44<00:00,  3.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.81it/s]
#                    all        0.9      0.975
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30      13.1G     0.1135          7        512: 100%|██████████| 376/376 [01:45<00:00,  3.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.82it/s]
#                    all      0.901      0.976
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30      13.1G    0.09537          7        512: 100%|██████████| 376/376 [01:44<00:00,  3.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.83it/s]
#                    all      0.905      0.975
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30      13.1G      0.076          7        512: 100%|██████████| 376/376 [01:45<00:00,  3.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.78it/s]
#                    all      0.902      0.974
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30      13.1G    0.06543          7        512: 100%|██████████| 376/376 [01:45<00:00,  3.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.83it/s]
#                    all      0.914      0.978
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30      13.2G    0.06418          7        512: 100%|██████████| 376/376 [01:46<00:00,  3.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.78it/s]
#                    all      0.911      0.978
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30      13.1G    0.05936          7        512: 100%|██████████| 376/376 [01:45<00:00,  3.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.85it/s]
#                    all      0.913      0.976
#       Epoch    GPU_mem       loss  Instances       Size
#       23/30      13.1G    0.04915          7        512: 100%|██████████| 376/376 [01:44<00:00,  3.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.88it/s]
#                    all      0.916      0.977
#       Epoch    GPU_mem       loss  Instances       Size
#       24/30      13.1G    0.04547          7        512: 100%|██████████| 376/376 [01:45<00:00,  3.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.77it/s]
#                    all      0.915      0.978
#       Epoch    GPU_mem       loss  Instances       Size
#       25/30      13.1G    0.04205          7        512: 100%|██████████| 376/376 [01:45<00:00,  3.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.81it/s]
#                    all      0.918      0.977
#       Epoch    GPU_mem       loss  Instances       Size
#       26/30      13.1G    0.03828          7        512: 100%|██████████| 376/376 [01:44<00:00,  3.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.77it/s]
#                    all      0.926      0.977
#       Epoch    GPU_mem       loss  Instances       Size
#       27/30      13.1G    0.02955          7        512: 100%|██████████| 376/376 [01:44<00:00,  3.59it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  5.05it/s]
#                    all      0.924      0.977
#       Epoch    GPU_mem       loss  Instances       Size
#       28/30      13.1G    0.03026          7        512: 100%|██████████| 376/376 [01:46<00:00,  3.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  4.77it/s]
#                    all      0.926      0.979
#       Epoch    GPU_mem       loss  Instances       Size
#       29/30      13.1G    0.02551          7        512: 100%|██████████| 376/376 [01:45<00:00,  3.55it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  5.07it/s]
#                    all      0.925       0.98
#       Epoch    GPU_mem       loss  Instances       Size
#       30/30      13.1G    0.02478          7        512: 100%|██████████| 376/376 [01:45<00:00,  3.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  5.18it/s]
#                    all      0.928      0.981
# 30 epochs completed in 0.929 hours.
# Optimizer stripped from runs/classify/train4/weights/last.pt, 72.7MB
# Optimizer stripped from runs/classify/train4/weights/best.pt, 72.7MB
#
# Validating runs/classify/train4/weights/best.pt...
# Ultralytics YOLOv8.1.16 🚀 Python-3.12.2 torch-2.2.1 CUDA:0 (NVIDIA GeForce RTX 4080, 16071MiB)
# YOLOv8l-cls summary (fused): 133 layers, 36248626 parameters, 0 gradients
# train: /home/andre/Desktop/CU_submission/chulacv2023/Lab8/dataset/train... found 18007 images in 50 classes ✅
# val: /home/andre/Desktop/CU_submission/chulacv2023/Lab8/dataset/val... found 1993 images in 50 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100%|██████████| 21/21 [00:04<00:00,  5.18it/s]
#                    all      0.928      0.981
# Speed: 0.2ms preprocess, 1.8ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train4
# Results saved to runs/classify/train4
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x719e6020c560>
# curves: []
# curves_results: []
# fitness: 0.9543401896953583
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 0.9277471303939819, 'metrics/accuracy_top5': 0.9809332489967346, 'fitness': 0.9543401896953583}
# save_dir: PosixPath('runs/classify/train4')
# speed: {'preprocess': 0.15948217117301913, 'inference': 1.8280595615767858, 'loss': 0.00018757668441106372, 'postprocess': 3.2060300651891e-05}
# task: 'classify'
# top1: 0.9277471303939819
# top5: 0.9809332489967346

# %%
bestModel = YOLO('runs/classify/train4/weights/best.pt')

# 43-s-20
# ''-m-20
# 2-m-30
# 4-l-30


res = bestModel.predict('test/', device='cuda', stream=False)
print(res[0].probs.top1)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1.jpg: 512x512 honey toast 1.00, ขาหมูเยอรมัน 0.00, ขนมปังปิ้ง 0.00, แกงส้มชะอมกุ้ง 0.00, ฮะเก๋า 0.00, 3.1ms
# image 2/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/10.jpg: 512x512 ข้าวหมูกรอบ 1.00, ข้าวหน้าเป็ด 0.00, ก๋วยจั๊บ 0.00, ข้าวหน้าเนื้อ 0.00, ขาหมูเยอรมัน 0.00, 3.3ms
# image 3/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/100.jpg: 512x512 ทาโกะยากิ 1.00, ปูนิ่มทอดกระเทียม 0.00, ยำถั่วพลู 0.00, ยำสาหร่าย 0.00, ยำแซลมอน 0.00, 3.1ms
# image 4/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1000.jpg: 512x512 น้ำตกหมู 1.00, ก๋วยเตี๋ยวเรือ 0.00, ก๋วยจั๊บ 0.00, ซุปเห็ด 0.00, เป็ดพะโล้ 0.00, 3.3ms
# image 5/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1001.jpg: 512x512 ก๋วยจั๊บ 0.99, กระเพาะปลา 0.01, ต้มเลือดหมู 0.00, ก๋วยเตี๋ยวเรือ 0.00, แกงส้มชะอมกุ้ง 0.00, 3.4ms
# image 6/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1002.jpg: 512x512 ปูผัดผงกะหรี่ 1.00, แกงส้มชะอมกุ้ง 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ปูนิ่มทอดกระเทียม 0.00, ออส่วน 0.00, 3.4ms
# image 7/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1003.jpg: 512x512 ยำสาหร่าย 1.00, ทาโกะยากิ 0.00, ชาบู 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, ยำแซลมอน 0.00, 3.0ms
# image 8/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1004.jpg: 512x512 ก๋วยเตี๋ยวคั่วไก่ 1.00, เกี๊ยวทอด 0.00, ยำหมูยอ 0.00, ข้าวหน้าเป็ด 0.00, ปูผัดผงกะหรี่ 0.00, 3.3ms
# image 9/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1005.jpg: 512x512 ข้าวผัดกระเทียม 1.00, ข้าวหน้าเนื้อ 0.00, ชาบู 0.00, ข้าวหมกไก่ 0.00, ปูนิ่มทอดกระเทียม 0.00, 3.4ms
# image 10/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1006.jpg: 512x512 ข้าวหมูกรอบ 1.00, ข้าวหน้าเป็ด 0.00, ข้าวหมกไก่ 0.00, ก๋วยจั๊บ 0.00, ขนมปังปิ้ง 0.00, 3.4ms
# image 11/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1007.jpg: 512x512 ก๋วยเตี๋ยวคั่วไก่ 1.00, บะหมี่แห้ง 0.00, ข้าวหมกไก่ 0.00, ออส่วน 0.00, ปูผัดผงกะหรี่ 0.00, 3.3ms
# image 12/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1008.jpg: 512x512 ปูผัดผงกะหรี่ 1.00, เกี๊ยวทอด 0.00, กระเพาะปลา 0.00, ยำหมูยอ 0.00, เป็ดพะโล้ 0.00, 3.1ms
# image 13/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1009.jpg: 512x512 ขนมถ้วย 1.00, ไข่ตุ๋น 0.00, ซุปเห็ด 0.00, ขนมปังปิ้ง 0.00, กระเพาะปลา 0.00, 3.3ms
# image 14/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/101.jpg: 512x512 แกงส้มชะอมกุ้ง 1.00, แกงคั่วหอยขม 0.00, น้ำพริกไข่ปู 0.00, น้ำตกหมู 0.00, ปูผัดผงกะหรี่ 0.00, 3.4ms
# image 15/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1010.jpg: 512x512 ยำแซลมอน 1.00, ยำสาหร่าย 0.00, หมูมะนาว 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, ยำหมูยอ 0.00, 3.3ms
# image 16/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1011.jpg: 512x512 ก๋วยเตี๋ยวคั่วไก่ 1.00, ไข่กระทะ 0.00, สเต็กหมู 0.00, ออส่วน 0.00, ก๋วยจั๊บ 0.00, 3.1ms
# image 17/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1012.jpg: 512x512 ข้าวผัดกระเทียม 1.00, ข้าวหน้าเนื้อ 0.00, ต้มเลือดหมู 0.00, ข้าวหมกไก่ 0.00, ปูนิ่มทอดกระเทียม 0.00, 3.3ms
# image 18/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1013.jpg: 512x512 ไส้อั่ว 1.00, ปอเปี๊ยะทอด 0.00, ก๋วยจั๊บ 0.00, ขนมปัง 0.00, น้ำตกหมู 0.00, 3.0ms
# image 19/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1014.jpg: 512x512 ข้าวหมกไก่ 1.00, ไส้อั่ว 0.00, ข้าวหมูกรอบ 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ข้าวผัดกระเทียม 0.00, 3.3ms
# image 20/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1015.jpg: 512x512 เป็ดพะโล้ 1.00, เป็ดย่าง 0.00, ข้าวหน้าเป็ด 0.00, ก๋วยจั๊บ 0.00, น้ำตกหมู 0.00, 3.1ms
# image 21/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1016.jpg: 512x512 เป็ดย่าง 0.99, ข้าวหน้าเป็ด 0.01, เนื้อย่าง 0.00, ขาหมูเยอรมัน 0.00, เป็ดพะโล้ 0.00, 3.3ms
# image 22/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1017.jpg: 512x512 แกงคั่วหอยขม 1.00, ปลากระพงนึ่งมะนาว 0.00, ยำถั่วพลู 0.00, แกงส้มชะอมกุ้ง 0.00, ปูผัดผงกะหรี่ 0.00, 3.2ms
# image 23/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1018.jpg: 512x512 ต้มเลือดหมู 1.00, ก๋วยจั๊บ 0.00, กระเพาะปลา 0.00, เป็ดพะโล้ 0.00, ก๋วยจั๊บญวน 0.00, 3.2ms
# image 24/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1019.jpg: 512x512 ชาบู 1.00, ก๋วยจั๊บญวน 0.00, ไอศกรีม 0.00, กระเพาะปลา 0.00, ข้าวหน้าเนื้อ 0.00, 3.4ms
# image 25/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/102.jpg: 512x512 ไข่กระทะ 1.00, ไข่ตุ๋น 0.00, สเต็กหมู 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, ข้าวหน้าเนื้อ 0.00, 3.0ms
# image 26/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1020.jpg: 512x512 ไข่กระทะ 1.00, ชาบู 0.00, ซุปเห็ด 0.00, ฮะเก๋า 0.00, ไข่ตุ๋น 0.00, 3.1ms
# image 27/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1021.jpg: 512x512 ปูนิ่มทอดกระเทียม 0.76, ไส้อั่ว 0.08, ยำถั่วพลู 0.03, ข้าวหมูกรอบ 0.03, ปอเปี๊ยะทอด 0.02, 3.0ms
# image 28/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1022.jpg: 512x512 ปลากระพงนึ่งมะนาว 1.00, ยำแซลมอน 0.00, ทาโกะยากิ 0.00, ข้าวหน้าเป็ด 0.00, หมูมะนาว 0.00, 3.4ms
# image 29/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1023.jpg: 512x512 เป็ดพะโล้ 0.99, ข้าวหน้าเป็ด 0.00, เป็ดย่าง 0.00, ปูผัดผงกะหรี่ 0.00, เนื้อย่าง 0.00, 2.9ms
# image 30/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1024.jpg: 512x512 ข้าวหน้าเนื้อ 1.00, ข้าวผัดกระเทียม 0.00, ไข่กระทะ 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ข้าวหน้าเป็ด 0.00, 3.0ms
# image 31/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1025.jpg: 512x512 น้ำตกหมู 1.00, ยำหมูยอ 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ปูผัดผงกะหรี่ 0.00, ก๋วยจั๊บ 0.00, 2.8ms
# image 32/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1026.jpg: 512x512 ฮะเก๋า 1.00, ยำแซลมอน 0.00, ชาบู 0.00, ขนมถ้วย 0.00, สเต็กหมู 0.00, 3.0ms
# image 33/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1027.jpg: 512x512 เค้ก 0.99, ขนมปัง 0.01, ทาโกะยากิ 0.00, ขนมปังปิ้ง 0.00, ยำสาหร่าย 0.00, 2.8ms
# image 34/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1028.jpg: 512x512 ขนมถ้วย 1.00, ไข่ตุ๋น 0.00, ชาบู 0.00, สเต็กหมู 0.00, ขนมปังปิ้ง 0.00, 3.1ms
# image 35/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1029.jpg: 512x512 เกี๊ยวทอด 0.71, ขนมปัง 0.12, เป็ดพะโล้ 0.11, ไส้อั่ว 0.05, ปอเปี๊ยะทอด 0.01, 3.0ms
# image 36/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/103.jpg: 512x512 บะหมี่แห้ง 1.00, ก๋วยเตี๋ยวเรือ 0.00, ก๋วยจั๊บญวน 0.00, ข้าวหมกไก่ 0.00, ยำถั่วพลู 0.00, 3.1ms
# image 37/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1030.jpg: 512x512 สปาเก็ตตี้ขี้เมาทะเล 1.00, สปาเก็ตตี้คาโบนาร่า 0.00, ยำหมูยอ 0.00, ซุปเห็ด 0.00, honey toast 0.00, 3.3ms
# image 38/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1031.jpg: 512x512 ขนมปังปิ้ง 1.00, honey toast 0.00, ขนมปัง 0.00, สเต็กหมู 0.00, ซุปเห็ด 0.00, 2.8ms
# image 39/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1032.jpg: 512x512 เนื้อย่าง 1.00, น้ำตกหมู 0.00, เป็ดย่าง 0.00, ข้าวหน้าเนื้อ 0.00, ไส้อั่ว 0.00, 2.9ms
# image 40/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1033.jpg: 512x512 แกงคั่วหอยขม 1.00, แกงส้มชะอมกุ้ง 0.00, ปูผัดผงกะหรี่ 0.00, ปลากระพงนึ่งมะนาว 0.00, น้ำตกหมู 0.00, 3.2ms
# image 41/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1034.jpg: 512x512 ไอศกรีม 0.53, ขนมปังปิ้ง 0.28, ขนมปังสังขยา 0.07, ขนมปัง 0.06, ทาโกะยากิ 0.02, 2.9ms
# image 42/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1035.jpg: 512x512 ต้มเลือดหมู 1.00, บะหมี่แห้ง 0.00, ก๋วยจั๊บ 0.00, ข้าวหน้าเป็ด 0.00, ชาบู 0.00, 3.1ms
# image 43/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1036.jpg: 512x512 ฮะเก๋า 1.00, สเต็กหมู 0.00, ชาบู 0.00, honey toast 0.00, ก๋วยจั๊บ 0.00, 2.7ms
# image 44/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1037.jpg: 512x512 ปูม้านึ่ง 1.00, ปูนิ่มทอดกระเทียม 0.00, เป็ดย่าง 0.00, น้ำพริกไข่ปู 0.00, ปูผัดผงกะหรี่ 0.00, 3.1ms
# image 45/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1038.jpg: 512x512 ปลากระพงนึ่งมะนาว 1.00, หมูมะนาว 0.00, ยำแซลมอน 0.00, ยำสาหร่าย 0.00, ยำปลาดุกฟู 0.00, 3.0ms
# image 46/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1039.jpg: 512x512 ขาหมูเยอรมัน 1.00, ไส้อั่ว 0.00, สเต็กหมู 0.00, honey toast 0.00, เป็ดย่าง 0.00, 3.0ms
# image 47/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/104.jpg: 512x512 ยำแซลมอน 1.00, ยำสาหร่าย 0.00, ข้าวหน้าเนื้อ 0.00, หมูมะนาว 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, 3.1ms
# image 48/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1040.jpg: 512x512 กระเพาะปลา 1.00, ซุปเห็ด 0.00, ก๋วยจั๊บญวน 0.00, ต้มเลือดหมู 0.00, ชาบู 0.00, 3.0ms
# image 49/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1041.jpg: 512x512 กระเพาะปลา 1.00, ออส่วน 0.00, เป็ดพะโล้ 0.00, น้ำพริกไข่ปู 0.00, แกงส้มชะอมกุ้ง 0.00, 2.9ms
# image 50/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1042.jpg: 512x512 ปอเปี๊ยะทอด 0.86, ขนมปังสังขยา 0.11, ขนมปัง 0.02, ขนมปังปิ้ง 0.01, honey toast 0.00, 3.1ms
# image 51/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1043.jpg: 512x512 ยำถั่วพลู 1.00, ยำแซลมอน 0.00, ซุปเห็ด 0.00, สเต็กหมู 0.00, แกงคั่วหอยขม 0.00, 2.7ms
# image 52/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1044.jpg: 512x512 ยำสาหร่าย 1.00, ชาบู 0.00, ยำปลาดุกฟู 0.00, ยำแซลมอน 0.00, แกงคั่วหอยขม 0.00, 3.1ms
# image 53/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1045.jpg: 512x512 สปาเก็ตตี้คาโบนาร่า 1.00, สเต็กหมู 0.00, ไอศกรีม 0.00, ข้าวผัดกระเทียม 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, 3.0ms
# image 54/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1046.jpg: 512x512 ฮะเก๋า 1.00, ชาบู 0.00, ขนมถ้วย 0.00, honey toast 0.00, ก๋วยจั๊บ 0.00, 3.0ms
# image 55/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1047.jpg: 512x512 ต้มเลือดหมู 1.00, ก๋วยจั๊บ 0.00, เป็ดพะโล้ 0.00, กระเพาะปลา 0.00, ก๋วยจั๊บญวน 0.00, 3.0ms
# image 56/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1048.jpg: 512x512 ยำหมูยอ 1.00, ก๋วยจั๊บญวน 0.00, ไข่กระทะ 0.00, เค้ก 0.00, เป็ดย่าง 0.00, 2.8ms
# image 57/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1049.jpg: 512x512 น้ำพริกไข่ปู 1.00, ไส้อั่ว 0.00, ชาบู 0.00, แกงคั่วหอยขม 0.00, เป็ดย่าง 0.00, 3.2ms
# image 58/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/105.jpg: 512x512 ยำถั่วพลู 1.00, ปูนิ่มทอดกระเทียม 0.00, ยำปลาดุกฟู 0.00, ยำแซลมอน 0.00, น้ำตกหมู 0.00, 3.1ms
# image 59/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1050.jpg: 512x512 ข้าวหมกไก่ 1.00, ข้าวหมูกรอบ 0.00, ข้าวผัดกระเทียม 0.00, ต้มเลือดหมู 0.00, บะหมี่แห้ง 0.00, 3.0ms
# image 60/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1051.jpg: 512x512 ซุปเห็ด 1.00, ไข่ตุ๋น 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, แกงคั่วหอยขม 0.00, ข้าวหมกไก่ 0.00, 3.1ms
# image 61/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1052.jpg: 512x512 ซุปเห็ด 0.97, ไข่ตุ๋น 0.02, ขนมปังสังขยา 0.00, ไอศกรีม 0.00, ขนมปังปิ้ง 0.00, 3.9ms
# image 62/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1053.jpg: 512x512 ไข่ตุ๋น 0.77, ยำปลาดุกฟู 0.11, ปลากระพงนึ่งมะนาว 0.04, เค้ก 0.04, หมูมะนาว 0.02, 3.1ms
# image 63/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1054.jpg: 512x512 ยำแซลมอน 1.00, ยำหมูยอ 0.00, ยำถั่วพลู 0.00, น้ำตกหมู 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, 3.0ms
# image 64/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1055.jpg: 512x512 ขนมปังสังขยา 0.77, ฮะเก๋า 0.19, ขนมถ้วย 0.03, ขนมปัง 0.01, ไอศกรีม 0.00, 3.1ms
# image 65/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1056.jpg: 512x512 ขนมปัง 0.94, ฮะเก๋า 0.05, ขนมปังสังขยา 0.00, ขนมถ้วย 0.00, ขนมปังปิ้ง 0.00, 3.1ms
# image 66/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1057.jpg: 512x512 สเต็กหมู 1.00, เนื้อย่าง 0.00, ขาหมูเยอรมัน 0.00, ข้าวหน้าเนื้อ 0.00, หมูมะนาว 0.00, 3.2ms
# image 67/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1058.jpg: 512x512 เค้ก 1.00, ไอศกรีม 0.00, ยำหมูยอ 0.00, เกี๊ยวทอด 0.00, กระเพาะปลา 0.00, 3.0ms
# image 68/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1059.jpg: 512x512 ยำแซลมอน 1.00, หมูมะนาว 0.00, ปลากระพงนึ่งมะนาว 0.00, สเต็กหมู 0.00, แกงส้มชะอมกุ้ง 0.00, 3.1ms
# image 69/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/106.jpg: 512x512 แกงคั่วหอยขม 1.00, ปลากระพงนึ่งมะนาว 0.00, ข้าวหน้าเนื้อ 0.00, ชาบู 0.00, ซุปเห็ด 0.00, 7.0ms
# image 70/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1060.jpg: 512x512 สปาเก็ตตี้ขี้เมาทะเล 1.00, บะหมี่แห้ง 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, สเต็กหมู 0.00, ซุปเห็ด 0.00, 3.1ms
# image 71/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1061.jpg: 512x512 ข้าวหมกไก่ 1.00, ข้าวหมูกรอบ 0.00, ไอศกรีม 0.00, ไส้อั่ว 0.00, ข้าวผัดกระเทียม 0.00, 2.9ms
# image 72/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1062.jpg: 512x512 ขนมปังปิ้ง 1.00, ขนมปัง 0.00, สเต็กหมู 0.00, ซุปเห็ด 0.00, เค้ก 0.00, 3.3ms
# image 73/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1063.jpg: 512x512 ไข่ตุ๋น 1.00, น้ำพริกไข่ปู 0.00, แกงคั่วหอยขม 0.00, ซุปเห็ด 0.00, ขนมปังสังขยา 0.00, 3.3ms
# image 74/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1064.jpg: 512x512 ขนมถ้วย 1.00, ไข่ตุ๋น 0.00, ชาบู 0.00, เกี๊ยวทอด 0.00, ไส้อั่ว 0.00, 3.2ms
# image 75/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1065.jpg: 512x512 ซุปเห็ด 0.76, กระเพาะปลา 0.23, ชาบู 0.01, ฮะเก๋า 0.00, ก๋วยจั๊บ 0.00, 3.0ms
# image 76/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1066.jpg: 512x512 ขนมปังปิ้ง 0.92, honey toast 0.05, ขนมปังสังขยา 0.02, ปอเปี๊ยะทอด 0.01, ขนมปัง 0.00, 3.1ms
# image 77/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1067.jpg: 512x512 บะหมี่แห้ง 1.00, ก๋วยเตี๋ยวเรือ 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, ออส่วน 0.00, 3.0ms
# image 78/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1068.jpg: 512x512 ปูม้านึ่ง 1.00, เป็ดย่าง 0.00, ปูนิ่มทอดกระเทียม 0.00, ปูผัดผงกะหรี่ 0.00, เป็ดพะโล้ 0.00, 3.1ms
# image 79/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1069.jpg: 512x512 ขนมปังสังขยา 0.96, ขนมปังปิ้ง 0.04, ขนมปัง 0.00, ข้าวหมูกรอบ 0.00, ไข่กระทะ 0.00, 3.0ms
# image 80/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/107.jpg: 512x512 ไอศกรีม 0.38, เค้ก 0.26, ขนมปังสังขยา 0.23, ก๋วยจั๊บญวน 0.03, เกี๊ยวทอด 0.02, 3.2ms
# image 81/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1070.jpg: 512x512 ทาโกะยากิ 1.00, ขนมปัง 0.00, ยำถั่วพลู 0.00, ไข่กระทะ 0.00, สเต็กหมู 0.00, 3.0ms
# image 82/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1071.jpg: 512x512 ฮะเก๋า 1.00, กระเพาะปลา 0.00, honey toast 0.00, ขนมถ้วย 0.00, ยำแซลมอน 0.00, 3.2ms
# image 83/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1072.jpg: 512x512 เป็ดย่าง 0.77, ขาหมูเยอรมัน 0.17, ไส้อั่ว 0.02, เนื้อย่าง 0.01, น้ำตกหมู 0.01, 3.2ms
# image 84/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1073.jpg: 512x512 ยำหมูยอ 1.00, น้ำตกหมู 0.00, ซุปเห็ด 0.00, ก๋วยจั๊บ 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, 3.3ms
# image 85/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1074.jpg: 512x512 ข้าวหมกไก่ 1.00, ปูผัดผงกะหรี่ 0.00, ชาบู 0.00, ขนมปัง 0.00, ข้าวหน้าเนื้อ 0.00, 3.1ms
# image 86/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1075.jpg: 512x512 แกงส้มชะอมกุ้ง 1.00, แกงคั่วหอยขม 0.00, ปูผัดผงกะหรี่ 0.00, เกี๊ยวทอด 0.00, เป็ดย่าง 0.00, 3.2ms
# image 87/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1076.jpg: 512x512 แกงส้มชะอมกุ้ง 1.00, ชาบู 0.00, แกงคั่วหอยขม 0.00, ปลากระพงนึ่งมะนาว 0.00, ก๋วยจั๊บญวน 0.00, 3.3ms
# image 88/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1077.jpg: 512x512 เกี๊ยวทอด 1.00, ยำหมูยอ 0.00, ก๋วยเตี๋ยวเรือ 0.00, บะหมี่แห้ง 0.00, ขนมปัง 0.00, 3.2ms
# image 89/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1078.jpg: 512x512 ปลากระพงนึ่งมะนาว 1.00, กระเพาะปลา 0.00, แกงคั่วหอยขม 0.00, หมูมะนาว 0.00, ออส่วน 0.00, 3.3ms
# image 90/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1079.jpg: 512x512 สเต็กหมู 1.00, ขาหมูเยอรมัน 0.00, เนื้อย่าง 0.00, ไส้อั่ว 0.00, เค้ก 0.00, 3.1ms
# image 91/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/108.jpg: 512x512 แกงคั่วหอยขม 1.00, แกงส้มชะอมกุ้ง 0.00, น้ำพริกไข่ปู 0.00, ชาบู 0.00, สเต็กหมู 0.00, 2.7ms
# image 92/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1080.jpg: 512x512 ปูผัดผงกะหรี่ 1.00, ยำปลาดุกฟู 0.00, ปูนิ่มทอดกระเทียม 0.00, ออส่วน 0.00, ยำถั่วพลู 0.00, 2.8ms
# image 93/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1081.jpg: 512x512 ยำหมูยอ 1.00, บะหมี่แห้ง 0.00, ก๋วยจั๊บญวน 0.00, ไข่กระทะ 0.00, น้ำตกหมู 0.00, 2.7ms
# image 94/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1082.jpg: 512x512 ยำถั่วพลู 1.00, แกงคั่วหอยขม 0.00, ซุปเห็ด 0.00, น้ำตกหมู 0.00, ก๋วยจั๊บ 0.00, 2.7ms
# image 95/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1083.jpg: 512x512 ข้าวหน้าเป็ด 0.89, ข้าวหมูกรอบ 0.11, ต้มเลือดหมู 0.00, ข้าวหน้าเนื้อ 0.00, เป็ดพะโล้ 0.00, 2.7ms
# image 96/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1084.jpg: 512x512 ปลากระพงนึ่งมะนาว 1.00, เป็ดพะโล้ 0.00, ก๋วยจั๊บ 0.00, ยำหมูยอ 0.00, ก๋วยจั๊บญวน 0.00, 2.7ms
# image 97/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1085.jpg: 512x512 ก๋วยเตี๋ยวคั่วไก่ 1.00, น้ำตกหมู 0.00, ยำแซลมอน 0.00, ยำถั่วพลู 0.00, ปูผัดผงกะหรี่ 0.00, 2.7ms
# image 98/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1086.jpg: 512x512 ก๋วยเตี๋ยวคั่วไก่ 1.00, ออส่วน 0.00, บะหมี่แห้ง 0.00, ปูผัดผงกะหรี่ 0.00, ไข่กระทะ 0.00, 2.7ms
# image 99/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1087.jpg: 512x512 ชาบู 1.00, เนื้อย่าง 0.00, สเต็กหมู 0.00, ต้มเลือดหมู 0.00, ข้าวหน้าเนื้อ 0.00, 2.8ms
# image 100/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1088.jpg: 512x512 ชาบู 1.00, ยำสาหร่าย 0.00, ปลากระพงนึ่งมะนาว 0.00, ข้าวหน้าเนื้อ 0.00, ข้าวหน้าเป็ด 0.00, 3.5ms
# image 101/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1089.jpg: 512x512 ปูนิ่มทอดกระเทียม 1.00, ปูผัดผงกะหรี่ 0.00, ยำถั่วพลู 0.00, ข้าวหมกไก่ 0.00, ยำปลาดุกฟู 0.00, 3.1ms
# image 102/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/109.jpg: 512x512 เนื้อย่าง 1.00, ข้าวหน้าเนื้อ 0.00, น้ำตกหมู 0.00, เป็ดย่าง 0.00, สเต็กหมู 0.00, 3.0ms
# image 103/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1090.jpg: 512x512 ข้าวหมกไก่ 1.00, ข้าวหมูกรอบ 0.00, ขาหมูเยอรมัน 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ไส้อั่ว 0.00, 3.2ms
# image 104/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1091.jpg: 512x512 ก๋วยจั๊บ 1.00, ก๋วยจั๊บญวน 0.00, แกงส้มชะอมกุ้ง 0.00, กระเพาะปลา 0.00, ซุปเห็ด 0.00, 3.1ms
# image 105/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1092.jpg: 512x512 ยำปลาดุกฟู 1.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ออส่วน 0.00, สเต็กหมู 0.00, ปูนิ่มทอดกระเทียม 0.00, 3.2ms
# image 106/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1093.jpg: 512x512 เค้ก 1.00, ปลากระพงนึ่งมะนาว 0.00, ยำหมูยอ 0.00, ข้าวผัดกระเทียม 0.00, ไอศกรีม 0.00, 3.0ms
# image 107/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1094.jpg: 512x512 เป็ดย่าง 1.00, เป็ดพะโล้ 0.00, ข้าวหน้าเป็ด 0.00, ก๋วยจั๊บ 0.00, น้ำตกหมู 0.00, 2.9ms
# image 108/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1095.jpg: 512x512 ปูนิ่มทอดกระเทียม 1.00, ข้าวผัดกระเทียม 0.00, หมูมะนาว 0.00, ออส่วน 0.00, ข้าวหมูกรอบ 0.00, 3.0ms
# image 109/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1096.jpg: 512x512 ขนมปังปิ้ง 0.70, ขนมปังสังขยา 0.25, เกี๊ยวทอด 0.03, ขนมปัง 0.02, ไส้อั่ว 0.00, 3.1ms
# image 110/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1097.jpg: 512x512 ข้าวหน้าเนื้อ 1.00, เนื้อย่าง 0.00, น้ำตกหมู 0.00, เป็ดพะโล้ 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, 3.1ms
# image 111/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1098.jpg: 512x512 ก๋วยเตี๋ยวคั่วไก่ 1.00, ออส่วน 0.00, ปูนิ่มทอดกระเทียม 0.00, ปูผัดผงกะหรี่ 0.00, ข้าวหมกไก่ 0.00, 3.2ms
# image 112/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1099.jpg: 512x512 ขนมปัง 1.00, ขนมปังสังขยา 0.00, เป็ดพะโล้ 0.00, ปอเปี๊ยะทอด 0.00, ขนมปังปิ้ง 0.00, 3.0ms
# image 113/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/11.jpg: 512x512 ปอเปี๊ยะทอด 1.00, เกี๊ยวทอด 0.00, ก๋วยจั๊บ 0.00, ขนมปังสังขยา 0.00, ขาหมูเยอรมัน 0.00, 3.1ms
# image 114/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/110.jpg: 512x512 ออส่วน 1.00, ปูผัดผงกะหรี่ 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, แกงคั่วหอยขม 0.00, ไข่ตุ๋น 0.00, 3.0ms
# image 115/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1100.jpg: 512x512 ขนมปัง 0.96, ขนมปังปิ้ง 0.04, ขนมปังสังขยา 0.00, honey toast 0.00, ไข่กระทะ 0.00, 3.1ms
# image 116/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1101.jpg: 512x512 สปาเก็ตตี้ขี้เมาทะเล 1.00, ยำหมูยอ 0.00, ปูผัดผงกะหรี่ 0.00, บะหมี่แห้ง 0.00, ยำถั่วพลู 0.00, 3.0ms
# image 117/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1102.jpg: 512x512 บะหมี่แห้ง 1.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, ก๋วยเตี๋ยวเรือ 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, ก๋วยจั๊บญวน 0.00, 3.0ms
# image 118/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1103.jpg: 512x512 ขาหมูเยอรมัน 1.00, เป็ดย่าง 0.00, เป็ดพะโล้ 0.00, ไส้อั่ว 0.00, ข้าวหมกไก่ 0.00, 3.2ms
# image 119/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1104.jpg: 512x512 ข้าวหน้าเป็ด 1.00, ข้าวหมูกรอบ 0.00, เป็ดย่าง 0.00, ข้าวหน้าเนื้อ 0.00, ข้าวหมกไก่ 0.00, 3.3ms
# image 120/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1105.jpg: 512x512 เป็ดพะโล้ 1.00, เป็ดย่าง 0.00, ข้าวหน้าเป็ด 0.00, ก๋วยจั๊บ 0.00, น้ำตกหมู 0.00, 3.2ms
# image 121/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1106.jpg: 512x512 ข้าวหมูกรอบ 1.00, ข้าวหน้าเป็ด 0.00, ข้าวหน้าเนื้อ 0.00, ข้าวผัดกระเทียม 0.00, ต้มเลือดหมู 0.00, 3.0ms
# image 122/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1107.jpg: 512x512 ไข่กระทะ 1.00, สเต็กหมู 0.00, ซุปเห็ด 0.00, ก๋วยจั๊บ 0.00, ฮะเก๋า 0.00, 3.1ms
# image 123/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1108.jpg: 512x512 ข้าวหน้าเนื้อ 1.00, เนื้อย่าง 0.00, ชาบู 0.00, ข้าวผัดกระเทียม 0.00, ไข่กระทะ 0.00, 3.1ms
# image 124/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1109.jpg: 512x512 ขนมปังปิ้ง 1.00, ขนมปัง 0.00, ขนมปังสังขยา 0.00, honey toast 0.00, ซุปเห็ด 0.00, 3.1ms
# image 125/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/111.jpg: 512x512 ยำแซลมอน 1.00, ยำสาหร่าย 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, หมูมะนาว 0.00, ปูผัดผงกะหรี่ 0.00, 3.1ms
# image 126/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1110.jpg: 512x512 ไอศกรีม 1.00, honey toast 0.00, ต้มเลือดหมู 0.00, ขนมถ้วย 0.00, ไข่ตุ๋น 0.00, 3.3ms
# image 127/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1111.jpg: 512x512 บะหมี่แห้ง 1.00, ก๋วยเตี๋ยวเรือ 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, หมูมะนาว 0.00, ก๋วยจั๊บ 0.00, 3.3ms
# image 128/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1112.jpg: 512x512 กระเพาะปลา 1.00, ก๋วยจั๊บญวน 0.00, แกงส้มชะอมกุ้ง 0.00, ต้มเลือดหมู 0.00, เป็ดพะโล้ 0.00, 3.3ms
# image 129/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1113.jpg: 512x512 บะหมี่แห้ง 0.93, ก๋วยเตี๋ยวคั่วไก่ 0.05, ไส้อั่ว 0.02, ก๋วยเตี๋ยวเรือ 0.00, ข้าวหมกไก่ 0.00, 3.0ms
# image 130/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1114.jpg: 512x512 แกงส้มชะอมกุ้ง 1.00, ยำถั่วพลู 0.00, ชาบู 0.00, ปูผัดผงกะหรี่ 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, 3.1ms
# image 131/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1115.jpg: 512x512 ก๋วยจั๊บ 1.00, ก๋วยจั๊บญวน 0.00, ต้มเลือดหมู 0.00, ชาบู 0.00, ก๋วยเตี๋ยวเรือ 0.00, 3.1ms
# image 132/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1116.jpg: 512x512 ขนมปังปิ้ง 0.91, เค้ก 0.04, เนื้อย่าง 0.04, สเต็กหมู 0.02, ขนมปัง 0.00, 3.2ms
# image 133/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1117.jpg: 512x512 ไส้อั่ว 1.00, ปอเปี๊ยะทอด 0.00, ปูนิ่มทอดกระเทียม 0.00, ขาหมูเยอรมัน 0.00, เป็ดย่าง 0.00, 3.2ms
# image 134/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1118.jpg: 512x512 ยำหมูยอ 1.00, ก๋วยจั๊บญวน 0.00, ไข่กระทะ 0.00, บะหมี่แห้ง 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, 3.1ms
# image 135/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1119.jpg: 512x512 ออส่วน 0.99, ปูนิ่มทอดกระเทียม 0.01, เป็ดพะโล้ 0.00, ไข่ตุ๋น 0.00, ข้าวหมูกรอบ 0.00, 3.1ms
# image 136/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/112.jpg: 512x512 น้ำพริกไข่ปู 1.00, ไส้อั่ว 0.00, ข้าวหมกไก่ 0.00, หมูมะนาว 0.00, ปอเปี๊ยะทอด 0.00, 3.4ms
# image 137/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1120.jpg: 512x512 ขนมปังปิ้ง 0.95, ขนมปังสังขยา 0.05, ข้าวหมูกรอบ 0.00, honey toast 0.00, ปอเปี๊ยะทอด 0.00, 3.1ms
# image 138/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1121.jpg: 512x512 ข้าวหน้าเป็ด 1.00, ข้าวหมูกรอบ 0.00, ข้าวหน้าเนื้อ 0.00, บะหมี่แห้ง 0.00, ไข่ตุ๋น 0.00, 3.2ms
# image 139/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1122.jpg: 512x512 ข้าวหมกไก่ 1.00, ข้าวหมูกรอบ 0.00, ขาหมูเยอรมัน 0.00, ปูนิ่มทอดกระเทียม 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, 3.2ms
# image 140/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1123.jpg: 512x512 ปอเปี๊ยะทอด 0.45, กระเพาะปลา 0.22, เกี๊ยวทอด 0.19, ปูนิ่มทอดกระเทียม 0.05, ฮะเก๋า 0.04, 3.2ms
# image 141/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1124.jpg: 512x512 แกงคั่วหอยขม 1.00, ปลากระพงนึ่งมะนาว 0.00, ยำถั่วพลู 0.00, ข้าวหมกไก่ 0.00, ซุปเห็ด 0.00, 3.1ms
# image 142/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1125.jpg: 512x512 เป็ดย่าง 1.00, ข้าวหน้าเป็ด 0.00, เนื้อย่าง 0.00, สเต็กหมู 0.00, ไส้อั่ว 0.00, 3.4ms
# image 143/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1126.jpg: 512x512 ยำปลาดุกฟู 1.00, ยำถั่วพลู 0.00, ไส้อั่ว 0.00, ยำสาหร่าย 0.00, ข้าวหมกไก่ 0.00, 3.2ms
# image 144/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1127.jpg: 512x512 ปูผัดผงกะหรี่ 0.93, น้ำตกหมู 0.07, ยำถั่วพลู 0.00, ปูนิ่มทอดกระเทียม 0.00, ข้าวหน้าเนื้อ 0.00, 3.4ms
# image 145/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1128.jpg: 512x512 ก๋วยเตี๋ยวคั่วไก่ 0.89, ข้าวหน้าเป็ด 0.04, ขาหมูเยอรมัน 0.02, ข้าวหน้าเนื้อ 0.02, เป็ดย่าง 0.01, 3.2ms
# image 146/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1129.jpg: 512x512 ก๋วยเตี๋ยวเรือ 1.00, น้ำตกหมู 0.00, ก๋วยจั๊บ 0.00, ก๋วยจั๊บญวน 0.00, แกงคั่วหอยขม 0.00, 3.4ms
# image 147/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/113.jpg: 512x512 ไข่ตุ๋น 1.00, ไข่กระทะ 0.00, ออส่วน 0.00, ข้าวผัดกระเทียม 0.00, ข้าวหน้าเนื้อ 0.00, 3.2ms
# image 148/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1130.jpg: 512x512 ไข่กระทะ 1.00, ซุปเห็ด 0.00, ชาบู 0.00, ยำถั่วพลู 0.00, honey toast 0.00, 3.4ms
# image 149/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1131.jpg: 512x512 ข้าวหน้าเนื้อ 1.00, เนื้อย่าง 0.00, ชาบู 0.00, ข้าวผัดกระเทียม 0.00, ไข่กระทะ 0.00, 3.1ms
# image 150/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1132.jpg: 512x512 ไอศกรีม 1.00, honey toast 0.00, เค้ก 0.00, ขนมปัง 0.00, ข้าวหน้าเนื้อ 0.00, 3.5ms
# image 151/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1133.jpg: 512x512 ออส่วน 1.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, กระเพาะปลา 0.00, เป็ดพะโล้ 0.00, ข้าวหน้าเนื้อ 0.00, 3.2ms
# image 152/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1134.jpg: 512x512 ต้มเลือดหมู 0.88, หมูมะนาว 0.12, น้ำตกหมู 0.00, เป็ดพะโล้ 0.00, ก๋วยจั๊บ 0.00, 3.4ms
# image 153/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1135.jpg: 512x512 honey toast 1.00, เค้ก 0.00, ขาหมูเยอรมัน 0.00, ไอศกรีม 0.00, ขนมปังปิ้ง 0.00, 3.2ms
# image 154/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1136.jpg: 512x512 ข้าวผัดกระเทียม 0.96, ข้าวหน้าเนื้อ 0.03, ข้าวหมูกรอบ 0.01, ข้าวหน้าเป็ด 0.00, ต้มเลือดหมู 0.00, 3.4ms
# image 155/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1137.jpg: 512x512 เนื้อย่าง 1.00, ข้าวหมูกรอบ 0.00, เป็ดย่าง 0.00, น้ำตกหมู 0.00, หมูมะนาว 0.00, 3.2ms
# image 156/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1138.jpg: 512x512 ยำแซลมอน 1.00, สเต็กหมู 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ยำหมูยอ 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, 3.2ms
# image 157/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1139.jpg: 512x512 แกงส้มชะอมกุ้ง 1.00, ปูผัดผงกะหรี่ 0.00, แกงคั่วหอยขม 0.00, ยำแซลมอน 0.00, ชาบู 0.00, 3.1ms
# image 158/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/114.jpg: 512x512 สปาเก็ตตี้ขี้เมาทะเล 1.00, บะหมี่แห้ง 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, ก๋วยเตี๋ยวเรือ 0.00, ไข่ตุ๋น 0.00, 3.1ms
# image 159/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1140.jpg: 512x512 เนื้อย่าง 1.00, สเต็กหมู 0.00, เป็ดย่าง 0.00, ปูนิ่มทอดกระเทียม 0.00, หมูมะนาว 0.00, 3.1ms
# image 160/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1141.jpg: 512x512 ข้าวหน้าเป็ด 0.89, ข้าวหมูกรอบ 0.11, ข้าวหน้าเนื้อ 0.00, เป็ดย่าง 0.00, ขาหมูเยอรมัน 0.00, 3.6ms
# image 161/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1142.jpg: 512x512 ขนมปัง 0.62, ขนมปังปิ้ง 0.25, honey toast 0.12, ขนมปังสังขยา 0.00, ไอศกรีม 0.00, 4.1ms
# image 162/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1143.jpg: 512x512 ปอเปี๊ยะทอด 1.00, ขนมปังสังขยา 0.00, honey toast 0.00, ขนมปัง 0.00, ฮะเก๋า 0.00, 3.1ms
# image 163/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1144.jpg: 512x512 ก๋วยจั๊บญวน 1.00, ก๋วยจั๊บ 0.00, ยำหมูยอ 0.00, ต้มเลือดหมู 0.00, บะหมี่แห้ง 0.00, 3.1ms
# image 164/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1145.jpg: 512x512 ขนมถ้วย 1.00, ไข่ตุ๋น 0.00, ซุปเห็ด 0.00, กระเพาะปลา 0.00, เค้ก 0.00, 3.1ms
# image 165/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1146.jpg: 512x512 ข้าวหน้าเป็ด 1.00, ข้าวหมูกรอบ 0.00, ข้าวหน้าเนื้อ 0.00, เป็ดพะโล้ 0.00, ข้าวหมกไก่ 0.00, 3.3ms
# image 166/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1147.jpg: 512x512 ปูนิ่มทอดกระเทียม 1.00, ข้าวหมกไก่ 0.00, ยำปลาดุกฟู 0.00, เป็ดพะโล้ 0.00, ยำถั่วพลู 0.00, 3.2ms
# image 167/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1148.jpg: 512x512 เนื้อย่าง 1.00, น้ำตกหมู 0.00, ขาหมูเยอรมัน 0.00, หมูมะนาว 0.00, เป็ดย่าง 0.00, 3.0ms
# image 168/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1149.jpg: 512x512 ไอศกรีม 0.98, ขนมปังปิ้ง 0.01, เค้ก 0.00, ไส้อั่ว 0.00, ทาโกะยากิ 0.00, 3.1ms
# image 169/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/115.jpg: 512x512 ยำถั่วพลู 0.67, ยำหมูยอ 0.19, ยำปลาดุกฟู 0.10, ปูผัดผงกะหรี่ 0.02, แกงคั่วหอยขม 0.01, 3.0ms
# image 170/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1150.jpg: 512x512 สปาเก็ตตี้ขี้เมาทะเล 1.00, ยำถั่วพลู 0.00, ยำหมูยอ 0.00, ปูผัดผงกะหรี่ 0.00, บะหมี่แห้ง 0.00, 3.1ms
# image 171/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1151.jpg: 512x512 ขนมถ้วย 1.00, ฮะเก๋า 0.00, บะหมี่แห้ง 0.00, ขนมปังสังขยา 0.00, ขนมปังปิ้ง 0.00, 3.1ms
# image 172/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1152.jpg: 512x512 ยำถั่วพลู 1.00, ซุปเห็ด 0.00, น้ำตกหมู 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, บะหมี่แห้ง 0.00, 3.4ms
# image 173/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1153.jpg: 512x512 บะหมี่แห้ง 1.00, ข้าวหน้าเนื้อ 0.00, ก๋วยเตี๋ยวเรือ 0.00, ก๋วยจั๊บญวน 0.00, สเต็กหมู 0.00, 3.4ms
# image 174/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1154.jpg: 512x512 ปูผัดผงกะหรี่ 1.00, แกงคั่วหอยขม 0.00, เป็ดย่าง 0.00, แกงส้มชะอมกุ้ง 0.00, ยำแซลมอน 0.00, 3.2ms
# image 175/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1155.jpg: 512x512 ก๋วยจั๊บ 1.00, ข้าวหน้าเนื้อ 0.00, เป็ดพะโล้ 0.00, บะหมี่แห้ง 0.00, ต้มเลือดหมู 0.00, 3.2ms
# image 176/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1156.jpg: 512x512 ข้าวหน้าเนื้อ 1.00, เนื้อย่าง 0.00, ชาบู 0.00, ข้าวผัดกระเทียม 0.00, ไข่กระทะ 0.00, 3.4ms
# image 177/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1157.jpg: 512x512 ก๋วยเตี๋ยวคั่วไก่ 1.00, ออส่วน 0.00, ข้าวหน้าเนื้อ 0.00, สเต็กหมู 0.00, บะหมี่แห้ง 0.00, 3.1ms
# image 178/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1158.jpg: 512x512 สเต็กหมู 1.00, ขาหมูเยอรมัน 0.00, เนื้อย่าง 0.00, เป็ดย่าง 0.00, ไส้อั่ว 0.00, 3.0ms
# image 179/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1159.jpg: 512x512 ปอเปี๊ยะทอด 1.00, ขาหมูเยอรมัน 0.00, เกี๊ยวทอด 0.00, ปูนิ่มทอดกระเทียม 0.00, ไส้อั่ว 0.00, 3.2ms
# image 180/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/116.jpg: 512x512 ปลากระพงนึ่งมะนาว 1.00, ยำหมูยอ 0.00, เป็ดพะโล้ 0.00, กระเพาะปลา 0.00, ก๋วยจั๊บ 0.00, 3.2ms
# image 181/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1160.jpg: 512x512 ยำปลาดุกฟู 1.00, ปูนิ่มทอดกระเทียม 0.00, ข้าวหมกไก่ 0.00, ข้าวผัดกระเทียม 0.00, ปูผัดผงกะหรี่ 0.00, 3.3ms
# image 182/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1161.jpg: 512x512 ไข่ตุ๋น 1.00, ไข่กระทะ 0.00, ออส่วน 0.00, ก๋วยจั๊บญวน 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, 3.2ms
# image 183/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1162.jpg: 512x512 ปูนิ่มทอดกระเทียม 1.00, ออส่วน 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ขาหมูเยอรมัน 0.00, ปอเปี๊ยะทอด 0.00, 3.4ms
# image 184/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1163.jpg: 512x512 ขนมปังปิ้ง 1.00, ขนมปัง 0.00, honey toast 0.00, ขนมปังสังขยา 0.00, สเต็กหมู 0.00, 3.2ms
# image 185/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1164.jpg: 512x512 ปูผัดผงกะหรี่ 0.92, ยำถั่วพลู 0.03, ข้าวหน้าเป็ด 0.01, เป็ดพะโล้ 0.01, ขาหมูเยอรมัน 0.01, 3.3ms
# image 186/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1165.jpg: 512x512 ขาหมูเยอรมัน 1.00, สเต็กหมู 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ปอเปี๊ยะทอด 0.00, ข้าวหมูกรอบ 0.00, 3.1ms
# image 187/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1166.jpg: 512x512 เป็ดย่าง 1.00, ข้าวหน้าเป็ด 0.00, เนื้อย่าง 0.00, สเต็กหมู 0.00, ยำแซลมอน 0.00, 3.2ms
# image 188/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1167.jpg: 512x512 ข้าวหน้าเป็ด 1.00, ข้าวหมูกรอบ 0.00, ข้าวหน้าเนื้อ 0.00, เป็ดย่าง 0.00, ปูนิ่มทอดกระเทียม 0.00, 3.1ms
# image 189/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1168.jpg: 512x512 สเต็กหมู 1.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ออส่วน 0.00, ไข่กระทะ 0.00, ขาหมูเยอรมัน 0.00, 3.2ms
# image 190/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1169.jpg: 512x512 ปอเปี๊ยะทอด 1.00, ขนมปัง 0.00, ขนมปังสังขยา 0.00, เกี๊ยวทอด 0.00, ฮะเก๋า 0.00, 3.2ms
# image 191/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/117.jpg: 512x512 ขนมปัง 0.99, ทาโกะยากิ 0.01, ซุปเห็ด 0.00, สเต็กหมู 0.00, ไส้อั่ว 0.00, 3.3ms
# image 192/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1170.jpg: 512x512 เนื้อย่าง 1.00, น้ำตกหมู 0.00, สเต็กหมู 0.00, ข้าวหมูกรอบ 0.00, ไส้อั่ว 0.00, 3.2ms
# image 193/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1171.jpg: 512x512 ยำถั่วพลู 1.00, น้ำตกหมู 0.00, ปูผัดผงกะหรี่ 0.00, แกงคั่วหอยขม 0.00, ซุปเห็ด 0.00, 3.4ms
# image 194/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1172.jpg: 512x512 บะหมี่แห้ง 0.98, ก๋วยเตี๋ยวเรือ 0.02, ก๋วยจั๊บ 0.00, ยำถั่วพลู 0.00, ต้มเลือดหมู 0.00, 3.2ms
# image 195/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1173.jpg: 512x512 ขาหมูเยอรมัน 0.87, สเต็กหมู 0.11, ทาโกะยากิ 0.01, ปอเปี๊ยะทอด 0.00, ไส้อั่ว 0.00, 3.4ms
# image 196/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1174.jpg: 512x512 สเต็กหมู 0.99, เนื้อย่าง 0.01, ไส้อั่ว 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ปอเปี๊ยะทอด 0.00, 3.2ms
# image 197/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1175.jpg: 512x512 ก๋วยจั๊บญวน 1.00, ก๋วยจั๊บ 0.00, ไข่กระทะ 0.00, ซุปเห็ด 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, 3.4ms
# image 198/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1176.jpg: 512x512 ออส่วน 1.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ปูนิ่มทอดกระเทียม 0.00, ปูผัดผงกะหรี่ 0.00, ไข่ตุ๋น 0.00, 3.2ms
# image 199/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1177.jpg: 512x512 ออส่วน 1.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ปูผัดผงกะหรี่ 0.00, ไข่ตุ๋น 0.00, เป็ดพะโล้ 0.00, 3.4ms
# image 200/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1178.jpg: 512x512 บะหมี่แห้ง 0.72, สปาเก็ตตี้คาโบนาร่า 0.28, ก๋วยเตี๋ยวคั่วไก่ 0.00, ออส่วน 0.00, ข้าวหน้าเป็ด 0.00, 3.2ms
# image 201/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1179.jpg: 512x512 ขนมปังสังขยา 0.99, ขนมปัง 0.01, ขนมปังปิ้ง 0.00, ฮะเก๋า 0.00, เกี๊ยวทอด 0.00, 3.0ms
# image 202/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/118.jpg: 512x512 กระเพาะปลา 1.00, ก๋วยจั๊บ 0.00, ต้มเลือดหมู 0.00, ซุปเห็ด 0.00, เป็ดพะโล้ 0.00, 3.1ms
# image 203/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1180.jpg: 512x512 ชาบู 1.00, ปลากระพงนึ่งมะนาว 0.00, ไข่กระทะ 0.00, ข้าวหน้าเนื้อ 0.00, ไข่ตุ๋น 0.00, 3.2ms
# image 204/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1181.jpg: 512x512 ยำปลาดุกฟู 1.00, ยำสาหร่าย 0.00, ข้าวหมกไก่ 0.00, บะหมี่แห้ง 0.00, ขนมปัง 0.00, 3.1ms
# image 205/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1182.jpg: 512x512 น้ำพริกไข่ปู 1.00, ข้าวหมกไก่ 0.00, ไส้อั่ว 0.00, ข้าวหมูกรอบ 0.00, เป็ดย่าง 0.00, 3.1ms
# image 206/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1183.jpg: 512x512 เป็ดพะโล้ 0.73, ปูผัดผงกะหรี่ 0.16, เป็ดย่าง 0.04, แกงคั่วหอยขม 0.03, ข้าวหน้าเป็ด 0.02, 3.1ms
# image 207/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1184.jpg: 512x512 ยำถั่วพลู 1.00, ปูนิ่มทอดกระเทียม 0.00, ข้าวหมกไก่ 0.00, ก๋วยจั๊บญวน 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, 3.0ms
# image 208/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1185.jpg: 512x512 ปอเปี๊ยะทอด 1.00, เกี๊ยวทอด 0.00, ซุปเห็ด 0.00, ขนมปัง 0.00, honey toast 0.00, 3.1ms
# image 209/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1186.jpg: 512x512 ยำปลาดุกฟู 1.00, ข้าวหมกไก่ 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, ขนมปัง 0.00, ปูผัดผงกะหรี่ 0.00, 3.1ms
# image 210/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1187.jpg: 512x512 แกงส้มชะอมกุ้ง 1.00, ปูผัดผงกะหรี่ 0.00, ยำถั่วพลู 0.00, ยำแซลมอน 0.00, กระเพาะปลา 0.00, 3.2ms
# image 211/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1188.jpg: 512x512 ปูม้านึ่ง 1.00, เป็ดพะโล้ 0.00, เป็ดย่าง 0.00, ข้าวหน้าเป็ด 0.00, ขนมปัง 0.00, 3.0ms
# image 212/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1189.jpg: 512x512 เกี๊ยวทอด 1.00, ปูม้านึ่ง 0.00, เป็ดพะโล้ 0.00, ยำหมูยอ 0.00, ปูผัดผงกะหรี่ 0.00, 3.3ms
# image 213/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/119.jpg: 512x512 ขนมถ้วย 1.00, ไอศกรีม 0.00, ฮะเก๋า 0.00, กระเพาะปลา 0.00, บะหมี่แห้ง 0.00, 3.6ms
# image 214/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1190.jpg: 512x512 ปูผัดผงกะหรี่ 1.00, แกงคั่วหอยขม 0.00, ออส่วน 0.00, ข้าวหน้าเนื้อ 0.00, แกงส้มชะอมกุ้ง 0.00, 3.1ms
# image 215/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1191.jpg: 512x512 ออส่วน 1.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ข้าวหมกไก่ 0.00, ปูนิ่มทอดกระเทียม 0.00, ปูผัดผงกะหรี่ 0.00, 3.2ms
# image 216/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1192.jpg: 512x512 ขนมถ้วย 1.00, ไข่ตุ๋น 0.00, ขนมปังปิ้ง 0.00, ชาบู 0.00, ไส้อั่ว 0.00, 3.1ms
# image 217/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1193.jpg: 512x512 ปูผัดผงกะหรี่ 1.00, ปูม้านึ่ง 0.00, เป็ดย่าง 0.00, ยำแซลมอน 0.00, แกงคั่วหอยขม 0.00, 3.1ms
# image 218/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1194.jpg: 512x512 ปูม้านึ่ง 1.00, ขนมปัง 0.00, เป็ดย่าง 0.00, แกงส้มชะอมกุ้ง 0.00, ชาบู 0.00, 3.1ms
# image 219/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1195.jpg: 512x512 เป็ดพะโล้ 1.00, เป็ดย่าง 0.00, ข้าวหน้าเป็ด 0.00, ก๋วยจั๊บ 0.00, กระเพาะปลา 0.00, 3.1ms
# image 220/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1196.jpg: 512x512 เป็ดพะโล้ 1.00, เป็ดย่าง 0.00, ข้าวหน้าเป็ด 0.00, เนื้อย่าง 0.00, ก๋วยจั๊บ 0.00, 3.0ms
# image 221/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1197.jpg: 512x512 ก๋วยจั๊บญวน 1.00, ก๋วยจั๊บ 0.00, บะหมี่แห้ง 0.00, ก๋วยเตี๋ยวเรือ 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, 3.1ms
# image 222/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1198.jpg: 512x512 ยำสาหร่าย 1.00, ยำแซลมอน 0.00, ทาโกะยากิ 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, 3.1ms
# image 223/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1199.jpg: 512x512 ขนมปังสังขยา 1.00, ขนมปังปิ้ง 0.00, ขนมปัง 0.00, ซุปเห็ด 0.00, ไข่กระทะ 0.00, 3.3ms
# image 224/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/12.jpg: 512x512 ชาบู 1.00, ไอศกรีม 0.00, ข้าวผัดกระเทียม 0.00, เนื้อย่าง 0.00, ไข่ตุ๋น 0.00, 3.1ms
# image 225/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/120.jpg: 512x512 สปาเก็ตตี้ขี้เมาทะเล 1.00, ยำถั่วพลู 0.00, ยำหมูยอ 0.00, ยำสาหร่าย 0.00, ทาโกะยากิ 0.00, 3.2ms
# image 226/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1200.jpg: 512x512 เกี๊ยวทอด 1.00, ออส่วน 0.00, ขนมถ้วย 0.00, กระเพาะปลา 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, 3.3ms
# image 227/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1201.jpg: 512x512 บะหมี่แห้ง 1.00, ก๋วยเตี๋ยวเรือ 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, ก๋วยจั๊บ 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, 3.2ms
# image 228/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1202.jpg: 512x512 ต้มเลือดหมู 0.55, ก๋วยจั๊บ 0.45, ก๋วยจั๊บญวน 0.00, ข้าวหน้าเป็ด 0.00, หมูมะนาว 0.00, 3.0ms
# image 229/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1203.jpg: 512x512 น้ำตกหมู 1.00, เนื้อย่าง 0.00, ข้าวหน้าเนื้อ 0.00, ปูผัดผงกะหรี่ 0.00, เป็ดพะโล้ 0.00, 3.1ms
# image 230/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1204.jpg: 512x512 เป็ดพะโล้ 1.00, ข้าวหน้าเป็ด 0.00, ขนมปัง 0.00, เป็ดย่าง 0.00, เกี๊ยวทอด 0.00, 3.1ms
# image 231/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1205.jpg: 512x512 กระเพาะปลา 1.00, น้ำพริกไข่ปู 0.00, แกงส้มชะอมกุ้ง 0.00, ก๋วยจั๊บญวน 0.00, ก๋วยจั๊บ 0.00, 3.1ms
# image 232/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1206.jpg: 512x512 ขนมปัง 0.95, ไอศกรีม 0.03, honey toast 0.01, ทาโกะยากิ 0.00, ก๋วยเตี๋ยวเรือ 0.00, 3.0ms
# image 233/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1207.jpg: 512x512 ข้าวหน้าเป็ด 1.00, เป็ดพะโล้ 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ข้าวหมกไก่ 0.00, ข้าวหมูกรอบ 0.00, 3.1ms
# image 234/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1208.jpg: 512x512 ก๋วยเตี๋ยวคั่วไก่ 1.00, น้ำตกหมู 0.00, ปูผัดผงกะหรี่ 0.00, ข้าวหมกไก่ 0.00, สเต็กหมู 0.00, 3.1ms
# image 235/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1209.jpg: 512x512 ออส่วน 1.00, ชาบู 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ปลากระพงนึ่งมะนาว 0.00, ข้าวหมกไก่ 0.00, 3.2ms
# image 236/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/121.jpg: 512x512 ยำหมูยอ 1.00, สเต็กหมู 0.00, ยำแซลมอน 0.00, ปลากระพงนึ่งมะนาว 0.00, หมูมะนาว 0.00, 3.2ms
# image 237/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1210.jpg: 512x512 ขาหมูเยอรมัน 0.95, ปูนิ่มทอดกระเทียม 0.03, เป็ดย่าง 0.01, ออส่วน 0.00, ปูผัดผงกะหรี่ 0.00, 3.4ms
# image 238/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1211.jpg: 512x512 หมูมะนาว 1.00, ปลากระพงนึ่งมะนาว 0.00, ยำแซลมอน 0.00, น้ำตกหมู 0.00, เนื้อย่าง 0.00, 3.1ms
# image 239/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1212.jpg: 512x512 สปาเก็ตตี้ขี้เมาทะเล 1.00, ก๋วยจั๊บ 0.00, ยำสาหร่าย 0.00, แกงคั่วหอยขม 0.00, ไข่ตุ๋น 0.00, 3.3ms
# image 240/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1213.jpg: 512x512 ข้าวหน้าเนื้อ 1.00, ทาโกะยากิ 0.00, กระเพาะปลา 0.00, ยำแซลมอน 0.00, เป็ดย่าง 0.00, 3.1ms
# image 241/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1214.jpg: 512x512 ก๋วยจั๊บ 0.98, กระเพาะปลา 0.02, ต้มเลือดหมู 0.01, ก๋วยจั๊บญวน 0.00, ข้าวหมูกรอบ 0.00, 3.3ms
# image 242/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1215.jpg: 512x512 ขนมปังปิ้ง 0.99, ขนมปัง 0.01, honey toast 0.00, ขนมปังสังขยา 0.00, ซุปเห็ด 0.00, 3.1ms
# image 243/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1216.jpg: 512x512 เกี๊ยวทอด 1.00, ขนมปัง 0.00, ปอเปี๊ยะทอด 0.00, ขนมปังปิ้ง 0.00, honey toast 0.00, 3.2ms
# image 244/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1217.jpg: 512x512 สปาเก็ตตี้คาโบนาร่า 0.98, สปาเก็ตตี้ขี้เมาทะเล 0.02, ข้าวหน้าเนื้อ 0.00, บะหมี่แห้ง 0.00, ทาโกะยากิ 0.00, 3.2ms
# image 245/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1218.jpg: 512x512 ก๋วยเตี๋ยวคั่วไก่ 1.00, บะหมี่แห้ง 0.00, ข้าวหน้าเนื้อ 0.00, ก๋วยเตี๋ยวเรือ 0.00, ออส่วน 0.00, 3.0ms
# image 246/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1219.jpg: 512x512 แกงส้มชะอมกุ้ง 1.00, ชาบู 0.00, กระเพาะปลา 0.00, ปลากระพงนึ่งมะนาว 0.00, น้ำพริกไข่ปู 0.00, 3.1ms
# image 247/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/122.jpg: 512x512 สปาเก็ตตี้ขี้เมาทะเล 1.00, ปูผัดผงกะหรี่ 0.00, ยำถั่วพลู 0.00, ยำแซลมอน 0.00, ยำหมูยอ 0.00, 3.1ms
# image 248/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1220.jpg: 512x512 ข้าวหมูกรอบ 0.87, ข้าวหน้าเป็ด 0.13, ข้าวหน้าเนื้อ 0.00, ข้าวหมกไก่ 0.00, ข้าวผัดกระเทียม 0.00, 3.1ms
# image 249/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1221.jpg: 512x512 ฮะเก๋า 1.00, honey toast 0.00, ขนมถ้วย 0.00, กระเพาะปลา 0.00, เป็ดพะโล้ 0.00, 3.2ms
# image 250/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1222.jpg: 512x512 ปูม้านึ่ง 1.00, น้ำพริกไข่ปู 0.00, ขนมปัง 0.00, ข้าวผัดกระเทียม 0.00, เกี๊ยวทอด 0.00, 3.1ms
# image 251/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1223.jpg: 512x512 เป็ดย่าง 1.00, ข้าวหน้าเป็ด 0.00, สเต็กหมู 0.00, honey toast 0.00, ข้าวหน้าเนื้อ 0.00, 3.1ms
# image 252/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1224.jpg: 512x512 ยำหมูยอ 1.00, ไข่กระทะ 0.00, ก๋วยจั๊บญวน 0.00, ก๋วยจั๊บ 0.00, เป็ดย่าง 0.00, 3.1ms
# image 253/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1225.jpg: 512x512 เค้ก 1.00, ไอศกรีม 0.00, ขนมปัง 0.00, honey toast 0.00, ขนมปังปิ้ง 0.00, 3.1ms
# image 254/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1226.jpg: 512x512 น้ำตกหมู 1.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ซุปเห็ด 0.00, ยำถั่วพลู 0.00, เนื้อย่าง 0.00, 3.2ms
# image 255/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1227.jpg: 512x512 น้ำพริกไข่ปู 1.00, สเต็กหมู 0.00, ข้าวหมกไก่ 0.00, ขาหมูเยอรมัน 0.00, ข้าวหมูกรอบ 0.00, 3.3ms
# image 256/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1228.jpg: 512x512 ยำถั่วพลู 1.00, ยำแซลมอน 0.00, ยำหมูยอ 0.00, ยำสาหร่าย 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, 3.2ms
# image 257/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1229.jpg: 512x512 ยำแซลมอน 1.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ข้าวหน้าเนื้อ 0.00, ข้าวผัดกระเทียม 0.00, สเต็กหมู 0.00, 3.2ms
# image 258/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/123.jpg: 512x512 ยำหมูยอ 1.00, ยำแซลมอน 0.00, ปลากระพงนึ่งมะนาว 0.00, ไข่กระทะ 0.00, ปูผัดผงกะหรี่ 0.00, 3.0ms
# image 259/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1230.jpg: 512x512 ซุปเห็ด 1.00, แกงคั่วหอยขม 0.00, ขนมปัง 0.00, ไอศกรีม 0.00, ไข่ตุ๋น 0.00, 3.1ms
# image 260/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1231.jpg: 512x512 ยำแซลมอน 1.00, สปาเก็ตตี้คาโบนาร่า 0.00, ข้าวหน้าเนื้อ 0.00, ชาบู 0.00, สเต็กหมู 0.00, 3.1ms
# image 261/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1232.jpg: 512x512 ยำสาหร่าย 1.00, ข้าวหน้าเนื้อ 0.00, ยำแซลมอน 0.00, เป็ดย่าง 0.00, แกงคั่วหอยขม 0.00, 3.1ms
# image 262/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1233.jpg: 512x512 น้ำตกหมู 1.00, เนื้อย่าง 0.00, ซุปเห็ด 0.00, หมูมะนาว 0.00, ก๋วยเตี๋ยวเรือ 0.00, 3.0ms
# image 263/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/1234.jpg: 512x512 ปอเปี๊ยะทอด 0.99, ฮะเก๋า 0.00, เกี๊ยวทอด 0.00, ขาหมูเยอรมัน 0.00, เนื้อย่าง 0.00, 3.2ms
# ...
# image 4914/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/920.jpg: 512x512 น้ำตกหมู 1.00, หมูมะนาว 0.00, ยำถั่วพลู 0.00, ซุปเห็ด 0.00, ข้าวหน้าเนื้อ 0.00, 2.8ms
# image 4915/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/921.jpg: 512x512 บะหมี่แห้ง 1.00, สปาเก็ตตี้คาโบนาร่า 0.00, ก๋วยเตี๋ยวเรือ 0.00, ก๋วยจั๊บญวน 0.00, ก๋วยจั๊บ 0.00, 4.2ms
# image 4916/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/922.jpg: 512x512 ข้าวหมกไก่ 1.00, ข้าวหมูกรอบ 0.00, ข้าวผัดกระเทียม 0.00, ไส้อั่ว 0.00, ปูนิ่มทอดกระเทียม 0.00, 4.2ms
# image 4917/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/923.jpg: 512x512 ออส่วน 1.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, บะหมี่แห้ง 0.00, ปูผัดผงกะหรี่ 0.00, ยำสาหร่าย 0.00, 3.6ms
# image 4918/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/924.jpg: 512x512 สปาเก็ตตี้ขี้เมาทะเล 0.99, สเต็กหมู 0.01, ข้าวหน้าเนื้อ 0.00, ยำสาหร่าย 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, 2.9ms
# image 4919/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/925.jpg: 512x512 หมูมะนาว 1.00, น้ำตกหมู 0.00, เนื้อย่าง 0.00, ไส้อั่ว 0.00, ยำหมูยอ 0.00, 3.0ms
# image 4920/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/926.jpg: 512x512 ข้าวหน้าเป็ด 1.00, ข้าวหมูกรอบ 0.00, honey toast 0.00, ข้าวหน้าเนื้อ 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, 3.0ms
# image 4921/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/927.jpg: 512x512 ขนมปัง 0.89, ขนมปังสังขยา 0.08, ปอเปี๊ยะทอด 0.02, บะหมี่แห้ง 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, 2.9ms
# image 4922/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/928.jpg: 512x512 ข้าวหมกไก่ 1.00, ข้าวหมูกรอบ 0.00, ข้าวหน้าเป็ด 0.00, ข้าวผัดกระเทียม 0.00, ขาหมูเยอรมัน 0.00, 3.1ms
# image 4923/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/929.jpg: 512x512 น้ำพริกไข่ปู 1.00, ไส้อั่ว 0.00, หมูมะนาว 0.00, แกงคั่วหอยขม 0.00, ข้าวหมกไก่ 0.00, 3.1ms
# image 4924/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/93.jpg: 512x512 ยำปลาดุกฟู 1.00, ข้าวหมกไก่ 0.00, ขนมปัง 0.00, ซุปเห็ด 0.00, ก๋วยจั๊บ 0.00, 3.3ms
# image 4925/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/930.jpg: 512x512 ปลากระพงนึ่งมะนาว 0.71, ยำหมูยอ 0.23, หมูมะนาว 0.06, ยำแซลมอน 0.00, บะหมี่แห้ง 0.00, 3.2ms
# image 4926/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/931.jpg: 512x512 เนื้อย่าง 1.00, เป็ดย่าง 0.00, ข้าวหน้าเนื้อ 0.00, สเต็กหมู 0.00, น้ำตกหมู 0.00, 4.7ms
# image 4927/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/932.jpg: 512x512 honey toast 1.00, ไส้อั่ว 0.00, เป็ดย่าง 0.00, ขนมปังปิ้ง 0.00, น้ำพริกไข่ปู 0.00, 4.3ms
# image 4928/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/933.jpg: 512x512 ก๋วยเตี๋ยวเรือ 1.00, น้ำตกหมู 0.00, ก๋วยจั๊บ 0.00, ต้มเลือดหมู 0.00, ก๋วยจั๊บญวน 0.00, 3.1ms
# image 4929/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/934.jpg: 512x512 เนื้อย่าง 0.98, เป็ดย่าง 0.02, ขาหมูเยอรมัน 0.00, สเต็กหมู 0.00, ชาบู 0.00, 3.1ms
# image 4930/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/935.jpg: 512x512 เนื้อย่าง 1.00, เป็ดย่าง 0.00, ข้าวหน้าเนื้อ 0.00, ขาหมูเยอรมัน 0.00, น้ำตกหมู 0.00, 3.2ms
# image 4931/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/936.jpg: 512x512 ไส้อั่ว 0.87, เนื้อย่าง 0.13, สเต็กหมู 0.00, น้ำตกหมู 0.00, เป็ดย่าง 0.00, 3.0ms
# image 4932/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/937.jpg: 512x512 บะหมี่แห้ง 1.00, สปาเก็ตตี้คาโบนาร่า 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, ก๋วยเตี๋ยวเรือ 0.00, 3.1ms
# image 4933/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/938.jpg: 512x512 แกงส้มชะอมกุ้ง 1.00, ก๋วยจั๊บ 0.00, ปูผัดผงกะหรี่ 0.00, ไส้อั่ว 0.00, เกี๊ยวทอด 0.00, 3.1ms
# image 4934/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/939.jpg: 512x512 ปูนิ่มทอดกระเทียม 1.00, ขาหมูเยอรมัน 0.00, ข้าวหมกไก่ 0.00, ออส่วน 0.00, ยำปลาดุกฟู 0.00, 3.1ms
# image 4935/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/94.jpg: 512x512 กระเพาะปลา 1.00, น้ำพริกไข่ปู 0.00, แกงส้มชะอมกุ้ง 0.00, เป็ดพะโล้ 0.00, ต้มเลือดหมู 0.00, 3.1ms
# image 4936/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/940.jpg: 512x512 ยำสาหร่าย 1.00, ยำปลาดุกฟู 0.00, ยำถั่วพลู 0.00, สเต็กหมู 0.00, ซุปเห็ด 0.00, 3.0ms
# image 4937/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/941.jpg: 512x512 ข้าวหน้าเป็ด 0.74, ข้าวหมูกรอบ 0.23, ข้าวหน้าเนื้อ 0.03, ต้มเลือดหมู 0.00, สเต็กหมู 0.00, 3.1ms
# image 4938/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/942.jpg: 512x512 เนื้อย่าง 1.00, เป็ดย่าง 0.00, ข้าวหน้าเนื้อ 0.00, น้ำตกหมู 0.00, เป็ดพะโล้ 0.00, 3.8ms
# image 4939/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/943.jpg: 512x512 ฮะเก๋า 1.00, กระเพาะปลา 0.00, เนื้อย่าง 0.00, honey toast 0.00, ชาบู 0.00, 5.9ms
# image 4940/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/944.jpg: 512x512 สเต็กหมู 1.00, หมูมะนาว 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, ขาหมูเยอรมัน 0.00, เนื้อย่าง 0.00, 3.4ms
# image 4941/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/945.jpg: 512x512 ยำสาหร่าย 1.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, ยำแซลมอน 0.00, ข้าวหน้าเนื้อ 0.00, ยำปลาดุกฟู 0.00, 3.0ms
# image 4942/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/946.jpg: 512x512 ทาโกะยากิ 1.00, ยำแซลมอน 0.00, สเต็กหมู 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, ข้าวหน้าเนื้อ 0.00, 3.0ms
# image 4943/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/947.jpg: 512x512 ปูม้านึ่ง 1.00, ปูนิ่มทอดกระเทียม 0.00, น้ำพริกไข่ปู 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ปูผัดผงกะหรี่ 0.00, 3.3ms
# image 4944/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/948.jpg: 512x512 ต้มเลือดหมู 0.50, ก๋วยจั๊บ 0.39, ก๋วยจั๊บญวน 0.07, แกงส้มชะอมกุ้ง 0.01, ก๋วยเตี๋ยวเรือ 0.01, 3.2ms
# image 4945/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/949.jpg: 512x512 ขาหมูเยอรมัน 0.97, ปูนิ่มทอดกระเทียม 0.02, ข้าวหมูกรอบ 0.00, ปอเปี๊ยะทอด 0.00, ออส่วน 0.00, 4.3ms
# image 4946/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/95.jpg: 512x512 ปูผัดผงกะหรี่ 1.00, ออส่วน 0.00, ปูนิ่มทอดกระเทียม 0.00, ข้าวหน้าเนื้อ 0.00, แกงคั่วหอยขม 0.00, 3.2ms
# image 4947/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/950.jpg: 512x512 เกี๊ยวทอด 1.00, บะหมี่แห้ง 0.00, ยำหมูยอ 0.00, ขนมปัง 0.00, ก๋วยจั๊บ 0.00, 3.2ms
# image 4948/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/951.jpg: 512x512 ชาบู 1.00, เนื้อย่าง 0.00, ข้าวผัดกระเทียม 0.00, สเต็กหมู 0.00, ข้าวหน้าเนื้อ 0.00, 3.3ms
# image 4949/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/952.jpg: 512x512 เนื้อย่าง 0.43, ข้าวหมูกรอบ 0.23, เป็ดย่าง 0.11, ไส้อั่ว 0.08, หมูมะนาว 0.08, 3.1ms
# image 4950/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/953.jpg: 512x512 น้ำตกหมู 1.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ยำหมูยอ 0.00, ซุปเห็ด 0.00, ปูผัดผงกะหรี่ 0.00, 3.0ms
# image 4951/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/954.jpg: 512x512 ออส่วน 1.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ปูผัดผงกะหรี่ 0.00, ไข่ตุ๋น 0.00, บะหมี่แห้ง 0.00, 4.5ms
# image 4952/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/955.jpg: 512x512 ชาบู 0.85, ไข่ตุ๋น 0.06, ข้าวหน้าเนื้อ 0.04, ยำแซลมอน 0.02, ซุปเห็ด 0.01, 4.1ms
# image 4953/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/956.jpg: 512x512 แกงคั่วหอยขม 1.00, ปลากระพงนึ่งมะนาว 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, ซุปเห็ด 0.00, สเต็กหมู 0.00, 3.2ms
# image 4954/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/957.jpg: 512x512 เป็ดย่าง 0.94, เป็ดพะโล้ 0.05, ข้าวหน้าเป็ด 0.01, เนื้อย่าง 0.00, น้ำตกหมู 0.00, 3.1ms
# image 4955/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/958.jpg: 512x512 เป็ดพะโล้ 1.00, ข้าวหน้าเป็ด 0.00, เนื้อย่าง 0.00, เป็ดย่าง 0.00, น้ำตกหมู 0.00, 3.0ms
# image 4956/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/959.jpg: 512x512 ต้มเลือดหมู 1.00, ก๋วยจั๊บญวน 0.00, ก๋วยจั๊บ 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, กระเพาะปลา 0.00, 3.1ms
# image 4957/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/96.jpg: 512x512 ขนมปังสังขยา 1.00, ขนมปังปิ้ง 0.00, ขนมปัง 0.00, ปอเปี๊ยะทอด 0.00, น้ำพริกไข่ปู 0.00, 3.1ms
# image 4958/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/960.jpg: 512x512 ปูนิ่มทอดกระเทียม 1.00, ไส้อั่ว 0.00, ปูผัดผงกะหรี่ 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ขาหมูเยอรมัน 0.00, 3.1ms
# image 4959/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/961.jpg: 512x512 ชาบู 0.58, สปาเก็ตตี้คาโบนาร่า 0.26, เป็ดย่าง 0.06, ขาหมูเยอรมัน 0.03, เค้ก 0.02, 3.1ms
# image 4960/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/962.jpg: 512x512 ไข่ตุ๋น 0.95, เค้ก 0.04, ชาบู 0.00, ขนมปัง 0.00, ซุปเห็ด 0.00, 3.2ms
# image 4961/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/963.jpg: 512x512 ปูผัดผงกะหรี่ 1.00, ออส่วน 0.00, แกงคั่วหอยขม 0.00, แกงส้มชะอมกุ้ง 0.00, ข้าวหน้าเนื้อ 0.00, 3.2ms
# image 4962/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/964.jpg: 512x512 ชาบู 1.00, เนื้อย่าง 0.00, สเต็กหมู 0.00, เค้ก 0.00, honey toast 0.00, 3.1ms
# image 4963/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/965.jpg: 512x512 ปอเปี๊ยะทอด 1.00, ไส้อั่ว 0.00, ปูนิ่มทอดกระเทียม 0.00, ทาโกะยากิ 0.00, แกงส้มชะอมกุ้ง 0.00, 3.4ms
# image 4964/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/966.jpg: 512x512 honey toast 1.00, ฮะเก๋า 0.00, ขนมปังปิ้ง 0.00, ขนมปัง 0.00, สเต็กหมู 0.00, 3.2ms
# image 4965/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/967.jpg: 512x512 หมูมะนาว 0.99, ปลากระพงนึ่งมะนาว 0.00, ยำถั่วพลู 0.00, ยำแซลมอน 0.00, ปูผัดผงกะหรี่ 0.00, 3.1ms
# image 4966/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/968.jpg: 512x512 ปอเปี๊ยะทอด 1.00, ขนมปังปิ้ง 0.00, ขนมปัง 0.00, honey toast 0.00, เกี๊ยวทอด 0.00, 3.0ms
# image 4967/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/969.jpg: 512x512 ปลากระพงนึ่งมะนาว 1.00, ก๋วยจั๊บ 0.00, ก๋วยจั๊บญวน 0.00, ชาบู 0.00, กระเพาะปลา 0.00, 3.2ms
# image 4968/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/97.jpg: 512x512 ก๋วยจั๊บญวน 0.95, ก๋วยจั๊บ 0.04, ไข่ตุ๋น 0.01, บะหมี่แห้ง 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, 3.0ms
# image 4969/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/970.jpg: 512x512 ข้าวหน้าเป็ด 1.00, ข้าวหมูกรอบ 0.00, ข้าวหน้าเนื้อ 0.00, ต้มเลือดหมู 0.00, กระเพาะปลา 0.00, 3.2ms
# image 4970/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/971.jpg: 512x512 สปาเก็ตตี้คาโบนาร่า 1.00, ซุปเห็ด 0.00, ไข่ตุ๋น 0.00, เกี๊ยวทอด 0.00, สปาเก็ตตี้ขี้เมาทะเล 0.00, 3.0ms
# image 4971/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/972.jpg: 512x512 ก๋วยเตี๋ยวคั่วไก่ 1.00, สเต็กหมู 0.00, ปอเปี๊ยะทอด 0.00, ข้าวหน้าเป็ด 0.00, เป็ดพะโล้ 0.00, 3.1ms
# image 4972/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/973.jpg: 512x512 ปูม้านึ่ง 1.00, ปูผัดผงกะหรี่ 0.00, เกี๊ยวทอด 0.00, ปูนิ่มทอดกระเทียม 0.00, น้ำพริกไข่ปู 0.00, 3.1ms
# image 4973/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/974.jpg: 512x512 เป็ดพะโล้ 0.85, ข้าวหน้าเป็ด 0.15, ก๋วยจั๊บ 0.00, เป็ดย่าง 0.00, ต้มเลือดหมู 0.00, 3.3ms
# image 4974/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/975.jpg: 512x512 ซุปเห็ด 1.00, แกงคั่วหอยขม 0.00, ไข่ตุ๋น 0.00, ก๋วยจั๊บญวน 0.00, สปาเก็ตตี้คาโบนาร่า 0.00, 3.2ms
# image 4975/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/976.jpg: 512x512 ข้าวหน้าเป็ด 1.00, เป็ดย่าง 0.00, ข้าวหมูกรอบ 0.00, ข้าวหน้าเนื้อ 0.00, ปูผัดผงกะหรี่ 0.00, 3.2ms
# image 4976/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/977.jpg: 512x512 บะหมี่แห้ง 1.00, ก๋วยเตี๋ยวเรือ 0.00, ไข่กระทะ 0.00, เกี๊ยวทอด 0.00, ก๋วยจั๊บ 0.00, 4.3ms
# image 4977/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/978.jpg: 512x512 เกี๊ยวทอด 1.00, ยำหมูยอ 0.00, เป็ดพะโล้ 0.00, บะหมี่แห้ง 0.00, ปอเปี๊ยะทอด 0.00, 3.1ms
# image 4978/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/979.jpg: 512x512 เป็ดย่าง 1.00, ข้าวหน้าเป็ด 0.00, เนื้อย่าง 0.00, honey toast 0.00, สเต็กหมู 0.00, 3.4ms
# image 4979/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/98.jpg: 512x512 เค้ก 1.00, ขนมปัง 0.00, honey toast 0.00, ขนมปังปิ้ง 0.00, เป็ดย่าง 0.00, 3.2ms
# image 4980/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/980.jpg: 512x512 เนื้อย่าง 1.00, หมูมะนาว 0.00, สเต็กหมู 0.00, ขาหมูเยอรมัน 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, 3.2ms
# image 4981/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/981.jpg: 512x512 ยำหมูยอ 1.00, ไข่กระทะ 0.00, น้ำตกหมู 0.00, ก๋วยจั๊บ 0.00, เป็ดย่าง 0.00, 3.2ms
# image 4982/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/982.jpg: 512x512 ก๋วยเตี๋ยวเรือ 1.00, ยำสาหร่าย 0.00, น้ำตกหมู 0.00, กระเพาะปลา 0.00, ก๋วยจั๊บ 0.00, 3.3ms
# image 4983/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/983.jpg: 512x512 ยำถั่วพลู 1.00, ก๋วยจั๊บญวน 0.00, ชาบู 0.00, บะหมี่แห้ง 0.00, ก๋วยจั๊บ 0.00, 3.2ms
# image 4984/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/984.jpg: 512x512 ขนมปังปิ้ง 0.91, ไอศกรีม 0.05, ขนมปัง 0.04, เค้ก 0.00, ซุปเห็ด 0.00, 3.4ms
# image 4985/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/985.jpg: 512x512 แกงส้มชะอมกุ้ง 1.00, แกงคั่วหอยขม 0.00, น้ำพริกไข่ปู 0.00, ปูม้านึ่ง 0.00, ปูผัดผงกะหรี่ 0.00, 3.2ms
# image 4986/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/986.jpg: 512x512 แกงคั่วหอยขม 1.00, ปูผัดผงกะหรี่ 0.00, แกงส้มชะอมกุ้ง 0.00, น้ำพริกไข่ปู 0.00, น้ำตกหมู 0.00, 6.0ms
# image 4987/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/987.jpg: 512x512 ชาบู 1.00, แกงส้มชะอมกุ้ง 0.00, ไข่กระทะ 0.00, ปลากระพงนึ่งมะนาว 0.00, ไข่ตุ๋น 0.00, 3.2ms
# image 4988/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/988.jpg: 512x512 เป็ดย่าง 1.00, ข้าวหน้าเป็ด 0.00, เป็ดพะโล้ 0.00, เนื้อย่าง 0.00, ไส้อั่ว 0.00, 3.2ms
# image 4989/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/989.jpg: 512x512 ข้าวหมกไก่ 1.00, ข้าวหน้าเป็ด 0.00, ปูนิ่มทอดกระเทียม 0.00, ขาหมูเยอรมัน 0.00, ออส่วน 0.00, 3.1ms
# image 4990/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/99.jpg: 512x512 กระเพาะปลา 1.00, แกงส้มชะอมกุ้ง 0.00, ก๋วยจั๊บ 0.00, ต้มเลือดหมู 0.00, ก๋วยจั๊บญวน 0.00, 3.0ms
# image 4991/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/990.jpg: 512x512 ก๋วยเตี๋ยวคั่วไก่ 0.80, ปูนิ่มทอดกระเทียม 0.19, ออส่วน 0.00, ขาหมูเยอรมัน 0.00, ข้าวหมกไก่ 0.00, 3.1ms
# image 4992/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/991.jpg: 512x512 น้ำตกหมู 0.70, เนื้อย่าง 0.28, สเต็กหมู 0.01, ข้าวหน้าเนื้อ 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, 3.1ms
# image 4993/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/992.jpg: 512x512 honey toast 0.98, ขนมปังปิ้ง 0.02, เค้ก 0.01, ไอศกรีม 0.00, ซุปเห็ด 0.00, 3.1ms
# image 4994/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/993.jpg: 512x512 ไส้อั่ว 1.00, เป็ดย่าง 0.00, ทาโกะยากิ 0.00, ปอเปี๊ยะทอด 0.00, เนื้อย่าง 0.00, 3.1ms
# image 4995/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/994.jpg: 512x512 ทาโกะยากิ 1.00, ขนมปัง 0.00, ซุปเห็ด 0.00, เป็ดย่าง 0.00, สเต็กหมู 0.00, 3.3ms
# image 4996/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/995.jpg: 512x512 ข้าวผัดกระเทียม 1.00, ขนมปัง 0.00, ข้าวหน้าเนื้อ 0.00, ไข่ตุ๋น 0.00, เกี๊ยวทอด 0.00, 3.1ms
# image 4997/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/996.jpg: 512x512 ยำแซลมอน 1.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, ปอเปี๊ยะทอด 0.00, หมูมะนาว 0.00, ยำสาหร่าย 0.00, 3.0ms
# image 4998/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/997.jpg: 512x512 ออส่วน 1.00, ปูผัดผงกะหรี่ 0.00, ไข่ตุ๋น 0.00, ก๋วยเตี๋ยวคั่วไก่ 0.00, แกงคั่วหอยขม 0.00, 3.0ms
# image 4999/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/998.jpg: 512x512 ปอเปี๊ยะทอด 1.00, เกี๊ยวทอด 0.00, ขาหมูเยอรมัน 0.00, ขนมปัง 0.00, ขนมปังปิ้ง 0.00, 3.6ms
# image 5000/5000 /home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/999.jpg: 512x512 ขนมปังสังขยา 1.00, ขนมปังปิ้ง 0.00, honey toast 0.00, ซุปเห็ด 0.00, ขนมปัง 0.00, 3.0ms
# Speed: 1.8ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 512)
# 0

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Example Result JSON <br>
# resultDict = {
#   'studentID': 555555555521,
#   'results':{
#     '1.jpg':'ต้มเลือดหมู',
#     '2.jpg':'บะหมี่แห้ง',
#     ...
#   }
# }

# %%
print(len(res))
resultDict = {}
path = '/home/andre/Desktop/CU_submission/chulacv2023/Lab8/test/'
print(len(path))
# for i in res:
    
# print(res[0])
# print(res[0].path.strip(path))
# print(res[0].names[res[0].probs.top1])
for i in res:
    # name = i.path.strip(path)
    name = i.path[len(path):]
    resultDict[name] = i.names[i.probs.top1]
    # print(i.path)
    # print(name)
# Out:
# 5000
# 56

# %%
print('{')
print('    "studentID": 6432085221,')
print('    "results": {')
for key, value in resultDict.items():
    print('        "' + key + '": "' + value + '",')
print('    }')
print('}')
# Out:
# {
#     "studentID": 6432085221,
#     "results": {
#         "1.jpg": "honey toast",
#         "10.jpg": "ข้าวหมูกรอบ",
#         "100.jpg": "ทาโกะยากิ",
#         "1000.jpg": "น้ำตกหมู",
#         "1001.jpg": "ก๋วยจั๊บ",
#         "1002.jpg": "ปูผัดผงกะหรี่",
#         "1003.jpg": "ยำสาหร่าย",
#         "1004.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1005.jpg": "ข้าวผัดกระเทียม",
#         "1006.jpg": "ข้าวหมูกรอบ",
#         "1007.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1008.jpg": "ปูผัดผงกะหรี่",
#         "1009.jpg": "ขนมถ้วย",
#         "101.jpg": "แกงส้มชะอมกุ้ง",
#         "1010.jpg": "ยำแซลมอน",
#         "1011.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1012.jpg": "ข้าวผัดกระเทียม",
#         "1013.jpg": "ไส้อั่ว",
#         "1014.jpg": "ข้าวหมกไก่",
#         "1015.jpg": "เป็ดพะโล้",
#         "1016.jpg": "เป็ดย่าง",
#         "1017.jpg": "แกงคั่วหอยขม",
#         "1018.jpg": "ต้มเลือดหมู",
#         "1019.jpg": "ชาบู",
#         "102.jpg": "ไข่กระทะ",
#         "1020.jpg": "ไข่กระทะ",
#         "1021.jpg": "ปูนิ่มทอดกระเทียม",
#         "1022.jpg": "ปลากระพงนึ่งมะนาว",
#         "1023.jpg": "เป็ดพะโล้",
#         "1024.jpg": "ข้าวหน้าเนื้อ",
#         "1025.jpg": "น้ำตกหมู",
#         "1026.jpg": "ฮะเก๋า",
#         "1027.jpg": "ขนมปัง",
#         "1028.jpg": "ขนมถ้วย",
#         "1029.jpg": "เกี๊ยวทอด",
#         "103.jpg": "บะหมี่แห้ง",
#         "1030.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1031.jpg": "ขนมปังปิ้ง",
#         "1032.jpg": "เนื้อย่าง",
#         "1033.jpg": "แกงคั่วหอยขม",
#         "1034.jpg": "ไอศกรีม",
#         "1035.jpg": "ต้มเลือดหมู",
#         "1036.jpg": "ฮะเก๋า",
#         "1037.jpg": "ปูม้านึ่ง",
#         "1038.jpg": "ปลากระพงนึ่งมะนาว",
#         "1039.jpg": "ขาหมูเยอรมัน",
#         "104.jpg": "ยำแซลมอน",
#         "1040.jpg": "กระเพาะปลา",
#         "1041.jpg": "กระเพาะปลา",
#         "1042.jpg": "ปอเปี๊ยะทอด",
#         "1043.jpg": "ยำถั่วพลู",
#         "1044.jpg": "ยำสาหร่าย",
#         "1045.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1046.jpg": "ฮะเก๋า",
#         "1047.jpg": "ต้มเลือดหมู",
#         "1048.jpg": "ยำหมูยอ",
#         "1049.jpg": "น้ำพริกไข่ปู",
#         "105.jpg": "ยำถั่วพลู",
#         "1050.jpg": "ข้าวหมกไก่",
#         "1051.jpg": "ซุปเห็ด",
#         "1052.jpg": "ซุปเห็ด",
#         "1053.jpg": "ไข่ตุ๋น",
#         "1054.jpg": "ยำแซลมอน",
#         "1055.jpg": "ขนมปังสังขยา",
#         "1056.jpg": "ขนมปัง",
#         "1057.jpg": "สเต็กหมู",
#         "1058.jpg": "เค้ก",
#         "1059.jpg": "ยำแซลมอน",
#         "106.jpg": "แกงคั่วหอยขม",
#         "1060.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1061.jpg": "ข้าวหมกไก่",
#         "1062.jpg": "ขนมปังปิ้ง",
#         "1063.jpg": "ไข่ตุ๋น",
#         "1064.jpg": "ขนมถ้วย",
#         "1065.jpg": "กระเพาะปลา",
#         "1066.jpg": "ขนมปังปิ้ง",
#         "1067.jpg": "บะหมี่แห้ง",
#         "1068.jpg": "ปูม้านึ่ง",
#         "1069.jpg": "ขนมปังสังขยา",
#         "107.jpg": "ขนมปังสังขยา",
#         "1070.jpg": "ทาโกะยากิ",
#         "1071.jpg": "ฮะเก๋า",
#         "1072.jpg": "เป็ดพะโล้",
#         "1073.jpg": "ยำหมูยอ",
#         "1074.jpg": "ข้าวหมกไก่",
#         "1075.jpg": "แกงส้มชะอมกุ้ง",
#         "1076.jpg": "แกงส้มชะอมกุ้ง",
#         "1077.jpg": "เกี๊ยวทอด",
#         "1078.jpg": "ปลากระพงนึ่งมะนาว",
#         "1079.jpg": "สเต็กหมู",
#         "108.jpg": "แกงคั่วหอยขม",
#         "1080.jpg": "ปูผัดผงกะหรี่",
#         "1081.jpg": "ยำหมูยอ",
#         "1082.jpg": "ยำถั่วพลู",
#         "1083.jpg": "ข้าวหน้าเป็ด",
#         "1084.jpg": "ปลากระพงนึ่งมะนาว",
#         "1085.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1086.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1087.jpg": "ชาบู",
#         "1088.jpg": "ชาบู",
#         "1089.jpg": "ปูนิ่มทอดกระเทียม",
#         "109.jpg": "เนื้อย่าง",
#         "1090.jpg": "ข้าวหมกไก่",
#         "1091.jpg": "ก๋วยจั๊บ",
#         "1092.jpg": "ยำปลาดุกฟู",
#         "1093.jpg": "เค้ก",
#         "1094.jpg": "เป็ดย่าง",
#         "1095.jpg": "ปูนิ่มทอดกระเทียม",
#         "1096.jpg": "ขนมปังปิ้ง",
#         "1097.jpg": "ข้าวหน้าเนื้อ",
#         "1098.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1099.jpg": "ขนมปัง",
#         "11.jpg": "ปอเปี๊ยะทอด",
#         "110.jpg": "ออส่วน",
#         "1100.jpg": "ขนมปัง",
#         "1101.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1102.jpg": "บะหมี่แห้ง",
#         "1103.jpg": "ขาหมูเยอรมัน",
#         "1104.jpg": "ข้าวหน้าเป็ด",
#         "1105.jpg": "เป็ดพะโล้",
#         "1106.jpg": "ข้าวหมูกรอบ",
#         "1107.jpg": "ไข่กระทะ",
#         "1108.jpg": "ข้าวหน้าเนื้อ",
#         "1109.jpg": "ขนมปังปิ้ง",
#         "111.jpg": "ยำแซลมอน",
#         "1110.jpg": "ไอศกรีม",
#         "1111.jpg": "บะหมี่แห้ง",
#         "1112.jpg": "กระเพาะปลา",
#         "1113.jpg": "บะหมี่แห้ง",
#         "1114.jpg": "แกงส้มชะอมกุ้ง",
#         "1115.jpg": "ก๋วยจั๊บ",
#         "1116.jpg": "ขนมปังปิ้ง",
#         "1117.jpg": "ไส้อั่ว",
#         "1118.jpg": "ยำหมูยอ",
#         "1119.jpg": "ออส่วน",
#         "112.jpg": "น้ำพริกไข่ปู",
#         "1120.jpg": "ขนมปังปิ้ง",
#         "1121.jpg": "ข้าวหน้าเป็ด",
#         "1122.jpg": "ข้าวหมกไก่",
#         "1123.jpg": "เกี๊ยวทอด",
#         "1124.jpg": "แกงคั่วหอยขม",
#         "1125.jpg": "เป็ดย่าง",
#         "1126.jpg": "ยำปลาดุกฟู",
#         "1127.jpg": "น้ำตกหมู",
#         "1128.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1129.jpg": "ก๋วยเตี๋ยวเรือ",
#         "113.jpg": "ไข่ตุ๋น",
#         "1130.jpg": "ไข่กระทะ",
#         "1131.jpg": "ข้าวหน้าเนื้อ",
#         "1132.jpg": "ไอศกรีม",
#         "1133.jpg": "ออส่วน",
#         "1134.jpg": "ต้มเลือดหมู",
#         "1135.jpg": "honey toast",
#         "1136.jpg": "ข้าวผัดกระเทียม",
#         "1137.jpg": "เนื้อย่าง",
#         "1138.jpg": "ยำแซลมอน",
#         "1139.jpg": "แกงส้มชะอมกุ้ง",
#         "114.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1140.jpg": "เนื้อย่าง",
#         "1141.jpg": "ข้าวหมูกรอบ",
#         "1142.jpg": "ขนมปัง",
#         "1143.jpg": "ปอเปี๊ยะทอด",
#         "1144.jpg": "ก๋วยจั๊บญวน",
#         "1145.jpg": "ขนมถ้วย",
#         "1146.jpg": "ข้าวหน้าเป็ด",
#         "1147.jpg": "ปูนิ่มทอดกระเทียม",
#         "1148.jpg": "เนื้อย่าง",
#         "1149.jpg": "ไอศกรีม",
#         "115.jpg": "ยำถั่วพลู",
#         "1150.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1151.jpg": "ขนมถ้วย",
#         "1152.jpg": "ยำถั่วพลู",
#         "1153.jpg": "บะหมี่แห้ง",
#         "1154.jpg": "ปูผัดผงกะหรี่",
#         "1155.jpg": "ก๋วยจั๊บ",
#         "1156.jpg": "ข้าวหน้าเนื้อ",
#         "1157.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1158.jpg": "สเต็กหมู",
#         "1159.jpg": "ปอเปี๊ยะทอด",
#         "116.jpg": "ปลากระพงนึ่งมะนาว",
#         "1160.jpg": "ยำปลาดุกฟู",
#         "1161.jpg": "ไข่ตุ๋น",
#         "1162.jpg": "ปูนิ่มทอดกระเทียม",
#         "1163.jpg": "ขนมปังปิ้ง",
#         "1164.jpg": "ปูผัดผงกะหรี่",
#         "1165.jpg": "ขาหมูเยอรมัน",
#         "1166.jpg": "เป็ดย่าง",
#         "1167.jpg": "ข้าวหน้าเป็ด",
#         "1168.jpg": "สเต็กหมู",
#         "1169.jpg": "ปอเปี๊ยะทอด",
#         "117.jpg": "ทาโกะยากิ",
#         "1170.jpg": "เนื้อย่าง",
#         "1171.jpg": "ยำถั่วพลู",
#         "1172.jpg": "บะหมี่แห้ง",
#         "1173.jpg": "ขาหมูเยอรมัน",
#         "1174.jpg": "สเต็กหมู",
#         "1175.jpg": "ก๋วยจั๊บญวน",
#         "1176.jpg": "ออส่วน",
#         "1177.jpg": "ออส่วน",
#         "1178.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1179.jpg": "ขนมปังสังขยา",
#         "118.jpg": "กระเพาะปลา",
#         "1180.jpg": "ชาบู",
#         "1181.jpg": "ยำปลาดุกฟู",
#         "1182.jpg": "น้ำพริกไข่ปู",
#         "1183.jpg": "เป็ดพะโล้",
#         "1184.jpg": "ยำถั่วพลู",
#         "1185.jpg": "ปอเปี๊ยะทอด",
#         "1186.jpg": "ยำปลาดุกฟู",
#         "1187.jpg": "แกงส้มชะอมกุ้ง",
#         "1188.jpg": "ปูม้านึ่ง",
#         "1189.jpg": "เกี๊ยวทอด",
#         "119.jpg": "ขนมถ้วย",
#         "1190.jpg": "ปูผัดผงกะหรี่",
#         "1191.jpg": "ออส่วน",
#         "1192.jpg": "ขนมถ้วย",
#         "1193.jpg": "ปูผัดผงกะหรี่",
#         "1194.jpg": "ปูม้านึ่ง",
#         "1195.jpg": "เป็ดพะโล้",
#         "1196.jpg": "เป็ดพะโล้",
#         "1197.jpg": "ก๋วยจั๊บญวน",
#         "1198.jpg": "ยำสาหร่าย",
#         "1199.jpg": "ขนมปังสังขยา",
#         "12.jpg": "ชาบู",
#         "120.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1200.jpg": "เกี๊ยวทอด",
#         "1201.jpg": "บะหมี่แห้ง",
#         "1202.jpg": "ต้มเลือดหมู",
#         "1203.jpg": "น้ำตกหมู",
#         "1204.jpg": "เป็ดพะโล้",
#         "1205.jpg": "กระเพาะปลา",
#         "1206.jpg": "ขนมปัง",
#         "1207.jpg": "ข้าวหน้าเป็ด",
#         "1208.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1209.jpg": "ออส่วน",
#         "121.jpg": "ยำหมูยอ",
#         "1210.jpg": "ขาหมูเยอรมัน",
#         "1211.jpg": "หมูมะนาว",
#         "1212.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1213.jpg": "ข้าวหน้าเนื้อ",
#         "1214.jpg": "ก๋วยจั๊บ",
#         "1215.jpg": "ขนมปังปิ้ง",
#         "1216.jpg": "เกี๊ยวทอด",
#         "1217.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1218.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1219.jpg": "แกงส้มชะอมกุ้ง",
#         "122.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1220.jpg": "ข้าวหมูกรอบ",
#         "1221.jpg": "ฮะเก๋า",
#         "1222.jpg": "ปูม้านึ่ง",
#         "1223.jpg": "เป็ดย่าง",
#         "1224.jpg": "ยำหมูยอ",
#         "1225.jpg": "เค้ก",
#         "1226.jpg": "น้ำตกหมู",
#         "1227.jpg": "น้ำพริกไข่ปู",
#         "1228.jpg": "ยำถั่วพลู",
#         "1229.jpg": "ยำแซลมอน",
#         "123.jpg": "ยำหมูยอ",
#         "1230.jpg": "ซุปเห็ด",
#         "1231.jpg": "ยำแซลมอน",
#         "1232.jpg": "ยำสาหร่าย",
#         "1233.jpg": "น้ำตกหมู",
#         "1234.jpg": "ปอเปี๊ยะทอด",
#         "1235.jpg": "ข้าวหมูกรอบ",
#         "1236.jpg": "ข้าวผัดกระเทียม",
#         "1237.jpg": "น้ำพริกไข่ปู",
#         "1238.jpg": "น้ำพริกไข่ปู",
#         "1239.jpg": "เป็ดพะโล้",
#         "124.jpg": "ปอเปี๊ยะทอด",
#         "1240.jpg": "ออส่วน",
#         "1241.jpg": "ขนมปัง",
#         "1242.jpg": "ข้าวหน้าเนื้อ",
#         "1243.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1244.jpg": "ข้าวหน้าเป็ด",
#         "1245.jpg": "ปอเปี๊ยะทอด",
#         "1246.jpg": "ข้าวหมูกรอบ",
#         "1247.jpg": "ไข่ตุ๋น",
#         "1248.jpg": "บะหมี่แห้ง",
#         "1249.jpg": "ขาหมูเยอรมัน",
#         "125.jpg": "ชาบู",
#         "1250.jpg": "ปูม้านึ่ง",
#         "1251.jpg": "กระเพาะปลา",
#         "1252.jpg": "ซุปเห็ด",
#         "1253.jpg": "สเต็กหมู",
#         "1254.jpg": "ทาโกะยากิ",
#         "1255.jpg": "ปูม้านึ่ง",
#         "1256.jpg": "honey toast",
#         "1257.jpg": "ไส้อั่ว",
#         "1258.jpg": "ปูนิ่มทอดกระเทียม",
#         "1259.jpg": "เนื้อย่าง",
#         "126.jpg": "เป็ดย่าง",
#         "1260.jpg": "บะหมี่แห้ง",
#         "1261.jpg": "เค้ก",
#         "1262.jpg": "ปูผัดผงกะหรี่",
#         "1263.jpg": "เป็ดย่าง",
#         "1264.jpg": "สเต็กหมู",
#         "1265.jpg": "ขนมถ้วย",
#         "1266.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1267.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1268.jpg": "หมูมะนาว",
#         "1269.jpg": "ข้าวหน้าเนื้อ",
#         "127.jpg": "ฮะเก๋า",
#         "1270.jpg": "ทาโกะยากิ",
#         "1271.jpg": "ยำหมูยอ",
#         "1272.jpg": "ชาบู",
#         "1273.jpg": "เนื้อย่าง",
#         "1274.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1275.jpg": "honey toast",
#         "1276.jpg": "ต้มเลือดหมู",
#         "1277.jpg": "ปูนิ่มทอดกระเทียม",
#         "1278.jpg": "ข้าวหมูกรอบ",
#         "1279.jpg": "ยำปลาดุกฟู",
#         "128.jpg": "honey toast",
#         "1280.jpg": "ไส้อั่ว",
#         "1281.jpg": "ยำสาหร่าย",
#         "1282.jpg": "ข้าวหน้าเนื้อ",
#         "1283.jpg": "ยำถั่วพลู",
#         "1284.jpg": "ปูผัดผงกะหรี่",
#         "1285.jpg": "ข้าวหมกไก่",
#         "1286.jpg": "ขนมปังปิ้ง",
#         "1287.jpg": "ต้มเลือดหมู",
#         "1288.jpg": "ก๋วยจั๊บญวน",
#         "1289.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "129.jpg": "ปลากระพงนึ่งมะนาว",
#         "1290.jpg": "ขนมปังปิ้ง",
#         "1291.jpg": "เกี๊ยวทอด",
#         "1292.jpg": "ข้าวหมกไก่",
#         "1293.jpg": "ขนมถ้วย",
#         "1294.jpg": "สเต็กหมู",
#         "1295.jpg": "น้ำพริกไข่ปู",
#         "1296.jpg": "ข้าวหน้าเป็ด",
#         "1297.jpg": "กระเพาะปลา",
#         "1298.jpg": "ยำถั่วพลู",
#         "1299.jpg": "ข้าวผัดกระเทียม",
#         "13.jpg": "ก๋วยจั๊บญวน",
#         "130.jpg": "ปูนิ่มทอดกระเทียม",
#         "1300.jpg": "ชาบู",
#         "1301.jpg": "เกี๊ยวทอด",
#         "1302.jpg": "ยำหมูยอ",
#         "1303.jpg": "ยำสาหร่าย",
#         "1304.jpg": "ข้าวหน้าเป็ด",
#         "1305.jpg": "เกี๊ยวทอด",
#         "1306.jpg": "ทาโกะยากิ",
#         "1307.jpg": "น้ำพริกไข่ปู",
#         "1308.jpg": "ไข่ตุ๋น",
#         "1309.jpg": "ข้าวหน้าเป็ด",
#         "131.jpg": "เป็ดพะโล้",
#         "1310.jpg": "ข้าวผัดกระเทียม",
#         "1311.jpg": "ปูม้านึ่ง",
#         "1312.jpg": "ข้าวหมกไก่",
#         "1313.jpg": "เกี๊ยวทอด",
#         "1314.jpg": "ไส้อั่ว",
#         "1315.jpg": "ยำหมูยอ",
#         "1316.jpg": "แกงคั่วหอยขม",
#         "1317.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1318.jpg": "ข้าวหน้าเป็ด",
#         "1319.jpg": "ยำแซลมอน",
#         "132.jpg": "ขาหมูเยอรมัน",
#         "1320.jpg": "ขนมถ้วย",
#         "1321.jpg": "เป็ดพะโล้",
#         "1322.jpg": "บะหมี่แห้ง",
#         "1323.jpg": "เป็ดย่าง",
#         "1324.jpg": "ไข่ตุ๋น",
#         "1325.jpg": "น้ำพริกไข่ปู",
#         "1326.jpg": "ปูนิ่มทอดกระเทียม",
#         "1327.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1328.jpg": "เนื้อย่าง",
#         "1329.jpg": "ปูผัดผงกะหรี่",
#         "133.jpg": "เป็ดพะโล้",
#         "1330.jpg": "ก๋วยจั๊บ",
#         "1331.jpg": "ขนมปังปิ้ง",
#         "1332.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1333.jpg": "เกี๊ยวทอด",
#         "1334.jpg": "ขนมปังปิ้ง",
#         "1335.jpg": "ขนมปังสังขยา",
#         "1336.jpg": "บะหมี่แห้ง",
#         "1337.jpg": "เกี๊ยวทอด",
#         "1338.jpg": "ขาหมูเยอรมัน",
#         "1339.jpg": "ข้าวหมกไก่",
#         "134.jpg": "ออส่วน",
#         "1340.jpg": "ขนมถ้วย",
#         "1341.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1342.jpg": "เกี๊ยวทอด",
#         "1343.jpg": "ต้มเลือดหมู",
#         "1344.jpg": "ขนมปัง",
#         "1345.jpg": "ยำสาหร่าย",
#         "1346.jpg": "กระเพาะปลา",
#         "1347.jpg": "บะหมี่แห้ง",
#         "1348.jpg": "ข้าวหมูกรอบ",
#         "1349.jpg": "แกงส้มชะอมกุ้ง",
#         "135.jpg": "ปลากระพงนึ่งมะนาว",
#         "1350.jpg": "ปูม้านึ่ง",
#         "1351.jpg": "ปอเปี๊ยะทอด",
#         "1352.jpg": "หมูมะนาว",
#         "1353.jpg": "ยำถั่วพลู",
#         "1354.jpg": "ซุปเห็ด",
#         "1355.jpg": "ข้าวหมูกรอบ",
#         "1356.jpg": "ข้าวหมูกรอบ",
#         "1357.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1358.jpg": "ปูนิ่มทอดกระเทียม",
#         "1359.jpg": "ปอเปี๊ยะทอด",
#         "136.jpg": "น้ำตกหมู",
#         "1360.jpg": "ต้มเลือดหมู",
#         "1361.jpg": "ยำปลาดุกฟู",
#         "1362.jpg": "ยำสาหร่าย",
#         "1363.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1364.jpg": "เป็ดพะโล้",
#         "1365.jpg": "honey toast",
#         "1366.jpg": "ออส่วน",
#         "1367.jpg": "ทาโกะยากิ",
#         "1368.jpg": "ขนมปังปิ้ง",
#         "1369.jpg": "ไอศกรีม",
#         "137.jpg": "แกงส้มชะอมกุ้ง",
#         "1370.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1371.jpg": "ปูผัดผงกะหรี่",
#         "1372.jpg": "ฮะเก๋า",
#         "1373.jpg": "ข้าวหน้าเนื้อ",
#         "1374.jpg": "ปูนิ่มทอดกระเทียม",
#         "1375.jpg": "บะหมี่แห้ง",
#         "1376.jpg": "ทาโกะยากิ",
#         "1377.jpg": "ยำสาหร่าย",
#         "1378.jpg": "ไข่ตุ๋น",
#         "1379.jpg": "ขนมปังปิ้ง",
#         "138.jpg": "ขนมปังปิ้ง",
#         "1380.jpg": "ไข่ตุ๋น",
#         "1381.jpg": "ยำหมูยอ",
#         "1382.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1383.jpg": "กระเพาะปลา",
#         "1384.jpg": "ขนมถ้วย",
#         "1385.jpg": "ขนมถ้วย",
#         "1386.jpg": "ปลากระพงนึ่งมะนาว",
#         "1387.jpg": "ยำปลาดุกฟู",
#         "1388.jpg": "เกี๊ยวทอด",
#         "1389.jpg": "ไข่ตุ๋น",
#         "139.jpg": "ขนมปังสังขยา",
#         "1390.jpg": "ทาโกะยากิ",
#         "1391.jpg": "ข้าวหน้าเป็ด",
#         "1392.jpg": "แกงส้มชะอมกุ้ง",
#         "1393.jpg": "ไอศกรีม",
#         "1394.jpg": "ขนมปังปิ้ง",
#         "1395.jpg": "ขนมปังสังขยา",
#         "1396.jpg": "ขนมปังสังขยา",
#         "1397.jpg": "ขนมปังปิ้ง",
#         "1398.jpg": "ข้าวหมกไก่",
#         "1399.jpg": "ยำหมูยอ",
#         "14.jpg": "ไข่กระทะ",
#         "140.jpg": "ข้าวผัดกระเทียม",
#         "1400.jpg": "เป็ดย่าง",
#         "1401.jpg": "ยำหมูยอ",
#         "1402.jpg": "ขนมถ้วย",
#         "1403.jpg": "ขนมถ้วย",
#         "1404.jpg": "เป็ดย่าง",
#         "1405.jpg": "ปอเปี๊ยะทอด",
#         "1406.jpg": "ขาหมูเยอรมัน",
#         "1407.jpg": "ขาหมูเยอรมัน",
#         "1408.jpg": "น้ำตกหมู",
#         "1409.jpg": "ไอศกรีม",
#         "141.jpg": "ไอศกรีม",
#         "1410.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1411.jpg": "ปูม้านึ่ง",
#         "1412.jpg": "ไข่กระทะ",
#         "1413.jpg": "ฮะเก๋า",
#         "1414.jpg": "ไข่ตุ๋น",
#         "1415.jpg": "น้ำตกหมู",
#         "1416.jpg": "ขนมปังสังขยา",
#         "1417.jpg": "ข้าวผัดกระเทียม",
#         "1418.jpg": "ไข่กระทะ",
#         "1419.jpg": "ซุปเห็ด",
#         "142.jpg": "ไข่ตุ๋น",
#         "1420.jpg": "เนื้อย่าง",
#         "1421.jpg": "ไข่กระทะ",
#         "1422.jpg": "ข้าวผัดกระเทียม",
#         "1423.jpg": "ไอศกรีม",
#         "1424.jpg": "ชาบู",
#         "1425.jpg": "ขนมปังสังขยา",
#         "1426.jpg": "ปอเปี๊ยะทอด",
#         "1427.jpg": "ปลากระพงนึ่งมะนาว",
#         "1428.jpg": "หมูมะนาว",
#         "1429.jpg": "กระเพาะปลา",
#         "143.jpg": "ข้าวหมกไก่",
#         "1430.jpg": "บะหมี่แห้ง",
#         "1431.jpg": "เกี๊ยวทอด",
#         "1432.jpg": "ขนมปัง",
#         "1433.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1434.jpg": "แกงคั่วหอยขม",
#         "1435.jpg": "ยำหมูยอ",
#         "1436.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1437.jpg": "ออส่วน",
#         "1438.jpg": "ขนมถ้วย",
#         "1439.jpg": "น้ำตกหมู",
#         "144.jpg": "ไอศกรีม",
#         "1440.jpg": "แกงคั่วหอยขม",
#         "1441.jpg": "เกี๊ยวทอด",
#         "1442.jpg": "ขนมถ้วย",
#         "1443.jpg": "ยำสาหร่าย",
#         "1444.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1445.jpg": "เค้ก",
#         "1446.jpg": "น้ำพริกไข่ปู",
#         "1447.jpg": "กระเพาะปลา",
#         "1448.jpg": "ไข่ตุ๋น",
#         "1449.jpg": "ซุปเห็ด",
#         "145.jpg": "เป็ดย่าง",
#         "1450.jpg": "ยำถั่วพลู",
#         "1451.jpg": "แกงคั่วหอยขม",
#         "1452.jpg": "น้ำตกหมู",
#         "1453.jpg": "ชาบู",
#         "1454.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1455.jpg": "ข้าวผัดกระเทียม",
#         "1456.jpg": "ก๋วยจั๊บญวน",
#         "1457.jpg": "ขนมปังปิ้ง",
#         "1458.jpg": "เป็ดพะโล้",
#         "1459.jpg": "ชาบู",
#         "146.jpg": "ทาโกะยากิ",
#         "1460.jpg": "honey toast",
#         "1461.jpg": "ไอศกรีม",
#         "1462.jpg": "เกี๊ยวทอด",
#         "1463.jpg": "ยำสาหร่าย",
#         "1464.jpg": "ข้าวผัดกระเทียม",
#         "1465.jpg": "ก๋วยจั๊บญวน",
#         "1466.jpg": "บะหมี่แห้ง",
#         "1467.jpg": "ข้าวหมูกรอบ",
#         "1468.jpg": "เป็ดพะโล้",
#         "1469.jpg": "ขนมถ้วย",
#         "147.jpg": "ฮะเก๋า",
#         "1470.jpg": "ก๋วยจั๊บ",
#         "1471.jpg": "ทาโกะยากิ",
#         "1472.jpg": "ขนมถ้วย",
#         "1473.jpg": "ข้าวหมกไก่",
#         "1474.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1475.jpg": "ไส้อั่ว",
#         "1476.jpg": "honey toast",
#         "1477.jpg": "honey toast",
#         "1478.jpg": "ยำแซลมอน",
#         "1479.jpg": "ปลากระพงนึ่งมะนาว",
#         "148.jpg": "ขนมปังปิ้ง",
#         "1480.jpg": "ต้มเลือดหมู",
#         "1481.jpg": "เค้ก",
#         "1482.jpg": "ขนมปังปิ้ง",
#         "1483.jpg": "แกงส้มชะอมกุ้ง",
#         "1484.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1485.jpg": "ปูผัดผงกะหรี่",
#         "1486.jpg": "สเต็กหมู",
#         "1487.jpg": "ขนมปัง",
#         "1488.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1489.jpg": "ข้าวผัดกระเทียม",
#         "149.jpg": "ข้าวผัดกระเทียม",
#         "1490.jpg": "ออส่วน",
#         "1491.jpg": "ขาหมูเยอรมัน",
#         "1492.jpg": "ปูม้านึ่ง",
#         "1493.jpg": "เค้ก",
#         "1494.jpg": "ซุปเห็ด",
#         "1495.jpg": "ข้าวผัดกระเทียม",
#         "1496.jpg": "ออส่วน",
#         "1497.jpg": "ขาหมูเยอรมัน",
#         "1498.jpg": "ปูผัดผงกะหรี่",
#         "1499.jpg": "ข้าวหมูกรอบ",
#         "15.jpg": "น้ำตกหมู",
#         "150.jpg": "เนื้อย่าง",
#         "1500.jpg": "น้ำพริกไข่ปู",
#         "1501.jpg": "ก๋วยจั๊บ",
#         "1502.jpg": "ขาหมูเยอรมัน",
#         "1503.jpg": "ข้าวผัดกระเทียม",
#         "1504.jpg": "เป็ดย่าง",
#         "1505.jpg": "ก๋วยจั๊บ",
#         "1506.jpg": "น้ำพริกไข่ปู",
#         "1507.jpg": "ข้าวหมูกรอบ",
#         "1508.jpg": "ไอศกรีม",
#         "1509.jpg": "ทาโกะยากิ",
#         "151.jpg": "ก๋วยจั๊บญวน",
#         "1510.jpg": "ยำแซลมอน",
#         "1511.jpg": "หมูมะนาว",
#         "1512.jpg": "ไข่กระทะ",
#         "1513.jpg": "น้ำตกหมู",
#         "1514.jpg": "ไข่กระทะ",
#         "1515.jpg": "ยำถั่วพลู",
#         "1516.jpg": "ขนมปังสังขยา",
#         "1517.jpg": "แกงคั่วหอยขม",
#         "1518.jpg": "ขนมปังสังขยา",
#         "1519.jpg": "กระเพาะปลา",
#         "152.jpg": "ซุปเห็ด",
#         "1520.jpg": "ยำสาหร่าย",
#         "1521.jpg": "ยำถั่วพลู",
#         "1522.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1523.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1524.jpg": "กระเพาะปลา",
#         "1525.jpg": "ขาหมูเยอรมัน",
#         "1526.jpg": "ข้าวผัดกระเทียม",
#         "1527.jpg": "ยำแซลมอน",
#         "1528.jpg": "ไข่กระทะ",
#         "1529.jpg": "ข้าวผัดกระเทียม",
#         "153.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1530.jpg": "ข้าวหมูกรอบ",
#         "1531.jpg": "ขนมถ้วย",
#         "1532.jpg": "เนื้อย่าง",
#         "1533.jpg": "ปอเปี๊ยะทอด",
#         "1534.jpg": "กระเพาะปลา",
#         "1535.jpg": "เป็ดย่าง",
#         "1536.jpg": "ปลากระพงนึ่งมะนาว",
#         "1537.jpg": "ออส่วน",
#         "1538.jpg": "ไส้อั่ว",
#         "1539.jpg": "ก๋วยจั๊บญวน",
#         "154.jpg": "ไข่กระทะ",
#         "1540.jpg": "ต้มเลือดหมู",
#         "1541.jpg": "ไส้อั่ว",
#         "1542.jpg": "เป็ดพะโล้",
#         "1543.jpg": "เค้ก",
#         "1544.jpg": "ไข่ตุ๋น",
#         "1545.jpg": "ต้มเลือดหมู",
#         "1546.jpg": "ต้มเลือดหมู",
#         "1547.jpg": "น้ำพริกไข่ปู",
#         "1548.jpg": "ขนมปังปิ้ง",
#         "1549.jpg": "เป็ดย่าง",
#         "155.jpg": "ขนมปัง",
#         "1550.jpg": "ฮะเก๋า",
#         "1551.jpg": "ข้าวผัดกระเทียม",
#         "1552.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1553.jpg": "ไข่ตุ๋น",
#         "1554.jpg": "ไข่ตุ๋น",
#         "1555.jpg": "น้ำตกหมู",
#         "1556.jpg": "ยำถั่วพลู",
#         "1557.jpg": "ยำหมูยอ",
#         "1558.jpg": "ยำสาหร่าย",
#         "1559.jpg": "ออส่วน",
#         "156.jpg": "ไข่กระทะ",
#         "1560.jpg": "น้ำตกหมู",
#         "1561.jpg": "ปลากระพงนึ่งมะนาว",
#         "1562.jpg": "กระเพาะปลา",
#         "1563.jpg": "เกี๊ยวทอด",
#         "1564.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1565.jpg": "ก๋วยจั๊บญวน",
#         "1566.jpg": "ยำสาหร่าย",
#         "1567.jpg": "บะหมี่แห้ง",
#         "1568.jpg": "ข้าวหมูกรอบ",
#         "1569.jpg": "ยำปลาดุกฟู",
#         "157.jpg": "ชาบู",
#         "1570.jpg": "ขาหมูเยอรมัน",
#         "1571.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1572.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1573.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1574.jpg": "ก๋วยจั๊บญวน",
#         "1575.jpg": "ปูม้านึ่ง",
#         "1576.jpg": "ขนมปังสังขยา",
#         "1577.jpg": "ยำแซลมอน",
#         "1578.jpg": "ชาบู",
#         "1579.jpg": "แกงส้มชะอมกุ้ง",
#         "158.jpg": "ข้าวหน้าเป็ด",
#         "1580.jpg": "สเต็กหมู",
#         "1581.jpg": "สเต็กหมู",
#         "1582.jpg": "บะหมี่แห้ง",
#         "1583.jpg": "ขนมปังสังขยา",
#         "1584.jpg": "ขนมปังปิ้ง",
#         "1585.jpg": "ยำปลาดุกฟู",
#         "1586.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1587.jpg": "ปลากระพงนึ่งมะนาว",
#         "1588.jpg": "ปูม้านึ่ง",
#         "1589.jpg": "ชาบู",
#         "159.jpg": "กระเพาะปลา",
#         "1590.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1591.jpg": "น้ำพริกไข่ปู",
#         "1592.jpg": "บะหมี่แห้ง",
#         "1593.jpg": "ซุปเห็ด",
#         "1594.jpg": "เกี๊ยวทอด",
#         "1595.jpg": "ข้าวหมกไก่",
#         "1596.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1597.jpg": "ข้าวผัดกระเทียม",
#         "1598.jpg": "ขนมปังปิ้ง",
#         "1599.jpg": "หมูมะนาว",
#         "16.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "160.jpg": "ไข่ตุ๋น",
#         "1600.jpg": "แกงส้มชะอมกุ้ง",
#         "1601.jpg": "หมูมะนาว",
#         "1602.jpg": "honey toast",
#         "1603.jpg": "น้ำพริกไข่ปู",
#         "1604.jpg": "ก๋วยจั๊บ",
#         "1605.jpg": "เป็ดพะโล้",
#         "1606.jpg": "ขาหมูเยอรมัน",
#         "1607.jpg": "ไข่กระทะ",
#         "1608.jpg": "ปูนิ่มทอดกระเทียม",
#         "1609.jpg": "ซุปเห็ด",
#         "161.jpg": "ข้าวหมกไก่",
#         "1610.jpg": "ก๋วยจั๊บ",
#         "1611.jpg": "เค้ก",
#         "1612.jpg": "ก๋วยจั๊บ",
#         "1613.jpg": "เกี๊ยวทอด",
#         "1614.jpg": "ออส่วน",
#         "1615.jpg": "ก๋วยจั๊บ",
#         "1616.jpg": "ก๋วยจั๊บญวน",
#         "1617.jpg": "ปูนิ่มทอดกระเทียม",
#         "1618.jpg": "ข้าวผัดกระเทียม",
#         "1619.jpg": "น้ำพริกไข่ปู",
#         "162.jpg": "ไส้อั่ว",
#         "1620.jpg": "ไข่ตุ๋น",
#         "1621.jpg": "ข้าวหน้าเป็ด",
#         "1622.jpg": "บะหมี่แห้ง",
#         "1623.jpg": "ข้าวหน้าเป็ด",
#         "1624.jpg": "สเต็กหมู",
#         "1625.jpg": "ขนมปัง",
#         "1626.jpg": "ยำสาหร่าย",
#         "1627.jpg": "ขนมปังปิ้ง",
#         "1628.jpg": "ข้าวหน้าเป็ด",
#         "1629.jpg": "ฮะเก๋า",
#         "163.jpg": "ขนมปัง",
#         "1630.jpg": "ข้าวหน้าเนื้อ",
#         "1631.jpg": "แกงส้มชะอมกุ้ง",
#         "1632.jpg": "สเต็กหมู",
#         "1633.jpg": "ปลากระพงนึ่งมะนาว",
#         "1634.jpg": "น้ำพริกไข่ปู",
#         "1635.jpg": "ขนมปังสังขยา",
#         "1636.jpg": "ยำปลาดุกฟู",
#         "1637.jpg": "ออส่วน",
#         "1638.jpg": "ต้มเลือดหมู",
#         "1639.jpg": "หมูมะนาว",
#         "164.jpg": "ยำปลาดุกฟู",
#         "1640.jpg": "ยำสาหร่าย",
#         "1641.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1642.jpg": "ฮะเก๋า",
#         "1643.jpg": "ก๋วยจั๊บญวน",
#         "1644.jpg": "ยำแซลมอน",
#         "1645.jpg": "กระเพาะปลา",
#         "1646.jpg": "ขนมถ้วย",
#         "1647.jpg": "ข้าวหน้าเป็ด",
#         "1648.jpg": "ไข่กระทะ",
#         "1649.jpg": "ออส่วน",
#         "165.jpg": "ข้าวหมกไก่",
#         "1650.jpg": "หมูมะนาว",
#         "1651.jpg": "ยำหมูยอ",
#         "1652.jpg": "เป็ดย่าง",
#         "1653.jpg": "เป็ดย่าง",
#         "1654.jpg": "ข้าวหน้าเป็ด",
#         "1655.jpg": "ฮะเก๋า",
#         "1656.jpg": "ไข่ตุ๋น",
#         "1657.jpg": "ยำแซลมอน",
#         "1658.jpg": "ขนมถ้วย",
#         "1659.jpg": "ปลากระพงนึ่งมะนาว",
#         "166.jpg": "ก๋วยจั๊บญวน",
#         "1660.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1661.jpg": "ปูนิ่มทอดกระเทียม",
#         "1662.jpg": "น้ำตกหมู",
#         "1663.jpg": "ไข่กระทะ",
#         "1664.jpg": "honey toast",
#         "1665.jpg": "ข้าวหมูกรอบ",
#         "1666.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1667.jpg": "น้ำพริกไข่ปู",
#         "1668.jpg": "แกงส้มชะอมกุ้ง",
#         "1669.jpg": "ข้าวหมกไก่",
#         "167.jpg": "เป็ดย่าง",
#         "1670.jpg": "ทาโกะยากิ",
#         "1671.jpg": "ออส่วน",
#         "1672.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1673.jpg": "ปอเปี๊ยะทอด",
#         "1674.jpg": "ทาโกะยากิ",
#         "1675.jpg": "ขนมปัง",
#         "1676.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1677.jpg": "ทาโกะยากิ",
#         "1678.jpg": "ข้าวผัดกระเทียม",
#         "1679.jpg": "ขนมปังปิ้ง",
#         "168.jpg": "ขนมถ้วย",
#         "1680.jpg": "ไอศกรีม",
#         "1681.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1682.jpg": "ทาโกะยากิ",
#         "1683.jpg": "กระเพาะปลา",
#         "1684.jpg": "ขาหมูเยอรมัน",
#         "1685.jpg": "ชาบู",
#         "1686.jpg": "เกี๊ยวทอด",
#         "1687.jpg": "ปูม้านึ่ง",
#         "1688.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1689.jpg": "ยำแซลมอน",
#         "169.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1690.jpg": "ขนมปังสังขยา",
#         "1691.jpg": "ไส้อั่ว",
#         "1692.jpg": "ปูนิ่มทอดกระเทียม",
#         "1693.jpg": "ชาบู",
#         "1694.jpg": "ขนมปังปิ้ง",
#         "1695.jpg": "ยำสาหร่าย",
#         "1696.jpg": "ขนมปังปิ้ง",
#         "1697.jpg": "บะหมี่แห้ง",
#         "1698.jpg": "เกี๊ยวทอด",
#         "1699.jpg": "กระเพาะปลา",
#         "17.jpg": "ไอศกรีม",
#         "170.jpg": "หมูมะนาว",
#         "1700.jpg": "ข้าวหมูกรอบ",
#         "1701.jpg": "ขนมปังสังขยา",
#         "1702.jpg": "ข้าวหน้าเป็ด",
#         "1703.jpg": "ปูนิ่มทอดกระเทียม",
#         "1704.jpg": "เป็ดย่าง",
#         "1705.jpg": "ปอเปี๊ยะทอด",
#         "1706.jpg": "ข้าวหมูกรอบ",
#         "1707.jpg": "เนื้อย่าง",
#         "1708.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1709.jpg": "ก๋วยเตี๋ยวเรือ",
#         "171.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1710.jpg": "ปูม้านึ่ง",
#         "1711.jpg": "ขาหมูเยอรมัน",
#         "1712.jpg": "เนื้อย่าง",
#         "1713.jpg": "ไอศกรีม",
#         "1714.jpg": "ปูนิ่มทอดกระเทียม",
#         "1715.jpg": "ซุปเห็ด",
#         "1716.jpg": "แกงส้มชะอมกุ้ง",
#         "1717.jpg": "หมูมะนาว",
#         "1718.jpg": "ข้าวหน้าเนื้อ",
#         "1719.jpg": "กระเพาะปลา",
#         "172.jpg": "แกงคั่วหอยขม",
#         "1720.jpg": "ก๋วยจั๊บญวน",
#         "1721.jpg": "ชาบู",
#         "1722.jpg": "บะหมี่แห้ง",
#         "1723.jpg": "ปอเปี๊ยะทอด",
#         "1724.jpg": "แกงส้มชะอมกุ้ง",
#         "1725.jpg": "แกงส้มชะอมกุ้ง",
#         "1726.jpg": "เค้ก",
#         "1727.jpg": "ขนมปังสังขยา",
#         "1728.jpg": "ขาหมูเยอรมัน",
#         "1729.jpg": "ปูผัดผงกะหรี่",
#         "173.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1730.jpg": "บะหมี่แห้ง",
#         "1731.jpg": "ข้าวผัดกระเทียม",
#         "1732.jpg": "ข้าวหมูกรอบ",
#         "1733.jpg": "ข้าวผัดกระเทียม",
#         "1734.jpg": "ออส่วน",
#         "1735.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1736.jpg": "ขนมปังปิ้ง",
#         "1737.jpg": "ขนมถ้วย",
#         "1738.jpg": "แกงส้มชะอมกุ้ง",
#         "1739.jpg": "ขนมถ้วย",
#         "174.jpg": "ยำสาหร่าย",
#         "1740.jpg": "สเต็กหมู",
#         "1741.jpg": "ขาหมูเยอรมัน",
#         "1742.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1743.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1744.jpg": "ยำแซลมอน",
#         "1745.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1746.jpg": "ข้าวหน้าเนื้อ",
#         "1747.jpg": "ทาโกะยากิ",
#         "1748.jpg": "ไข่กระทะ",
#         "1749.jpg": "ต้มเลือดหมู",
#         "175.jpg": "ข้าวหมกไก่",
#         "1750.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1751.jpg": "ชาบู",
#         "1752.jpg": "ซุปเห็ด",
#         "1753.jpg": "เนื้อย่าง",
#         "1754.jpg": "ฮะเก๋า",
#         "1755.jpg": "ปูม้านึ่ง",
#         "1756.jpg": "เกี๊ยวทอด",
#         "1757.jpg": "ข้าวผัดกระเทียม",
#         "1758.jpg": "ยำปลาดุกฟู",
#         "1759.jpg": "ทาโกะยากิ",
#         "176.jpg": "ขาหมูเยอรมัน",
#         "1760.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1761.jpg": "ข้าวหมกไก่",
#         "1762.jpg": "ขนมปัง",
#         "1763.jpg": "ข้าวหน้าเป็ด",
#         "1764.jpg": "ข้าวหน้าเนื้อ",
#         "1765.jpg": "ยำปลาดุกฟู",
#         "1766.jpg": "ขนมปังสังขยา",
#         "1767.jpg": "สเต็กหมู",
#         "1768.jpg": "น้ำพริกไข่ปู",
#         "1769.jpg": "ข้าวหมกไก่",
#         "177.jpg": "ยำสาหร่าย",
#         "1770.jpg": "ก๋วยจั๊บญวน",
#         "1771.jpg": "ขนมปังสังขยา",
#         "1772.jpg": "ออส่วน",
#         "1773.jpg": "เค้ก",
#         "1774.jpg": "ข้าวผัดกระเทียม",
#         "1775.jpg": "ทาโกะยากิ",
#         "1776.jpg": "ทาโกะยากิ",
#         "1777.jpg": "ชาบู",
#         "1778.jpg": "honey toast",
#         "1779.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "178.jpg": "honey toast",
#         "1780.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1781.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1782.jpg": "ขนมปังสังขยา",
#         "1783.jpg": "ไข่ตุ๋น",
#         "1784.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1785.jpg": "ฮะเก๋า",
#         "1786.jpg": "ขนมปัง",
#         "1787.jpg": "ยำหมูยอ",
#         "1788.jpg": "ขนมปังปิ้ง",
#         "1789.jpg": "ไข่กระทะ",
#         "179.jpg": "กระเพาะปลา",
#         "1790.jpg": "ต้มเลือดหมู",
#         "1791.jpg": "ก๋วยจั๊บ",
#         "1792.jpg": "ข้าวหน้าเนื้อ",
#         "1793.jpg": "เนื้อย่าง",
#         "1794.jpg": "น้ำพริกไข่ปู",
#         "1795.jpg": "ไข่กระทะ",
#         "1796.jpg": "เป็ดย่าง",
#         "1797.jpg": "กระเพาะปลา",
#         "1798.jpg": "ขนมปัง",
#         "1799.jpg": "ยำปลาดุกฟู",
#         "18.jpg": "ยำปลาดุกฟู",
#         "180.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1800.jpg": "ยำหมูยอ",
#         "1801.jpg": "เนื้อย่าง",
#         "1802.jpg": "บะหมี่แห้ง",
#         "1803.jpg": "ยำถั่วพลู",
#         "1804.jpg": "ยำปลาดุกฟู",
#         "1805.jpg": "ซุปเห็ด",
#         "1806.jpg": "แกงส้มชะอมกุ้ง",
#         "1807.jpg": "ออส่วน",
#         "1808.jpg": "ขนมปังปิ้ง",
#         "1809.jpg": "กระเพาะปลา",
#         "181.jpg": "ยำแซลมอน",
#         "1810.jpg": "กระเพาะปลา",
#         "1811.jpg": "ทาโกะยากิ",
#         "1812.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1813.jpg": "ต้มเลือดหมู",
#         "1814.jpg": "เป็ดย่าง",
#         "1815.jpg": "เป็ดพะโล้",
#         "1816.jpg": "ยำสาหร่าย",
#         "1817.jpg": "ออส่วน",
#         "1818.jpg": "ยำปลาดุกฟู",
#         "1819.jpg": "เค้ก",
#         "182.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1820.jpg": "ซุปเห็ด",
#         "1821.jpg": "ปูผัดผงกะหรี่",
#         "1822.jpg": "ซุปเห็ด",
#         "1823.jpg": "ปูผัดผงกะหรี่",
#         "1824.jpg": "ไอศกรีม",
#         "1825.jpg": "กระเพาะปลา",
#         "1826.jpg": "ยำหมูยอ",
#         "1827.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1828.jpg": "ยำหมูยอ",
#         "1829.jpg": "ยำสาหร่าย",
#         "183.jpg": "น้ำตกหมู",
#         "1830.jpg": "ยำปลาดุกฟู",
#         "1831.jpg": "หมูมะนาว",
#         "1832.jpg": "ปูนิ่มทอดกระเทียม",
#         "1833.jpg": "แกงส้มชะอมกุ้ง",
#         "1834.jpg": "ยำสาหร่าย",
#         "1835.jpg": "honey toast",
#         "1836.jpg": "ข้าวผัดกระเทียม",
#         "1837.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1838.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1839.jpg": "ปลากระพงนึ่งมะนาว",
#         "184.jpg": "บะหมี่แห้ง",
#         "1840.jpg": "ต้มเลือดหมู",
#         "1841.jpg": "ปูนิ่มทอดกระเทียม",
#         "1842.jpg": "ไข่กระทะ",
#         "1843.jpg": "ยำถั่วพลู",
#         "1844.jpg": "น้ำตกหมู",
#         "1845.jpg": "ปลากระพงนึ่งมะนาว",
#         "1846.jpg": "น้ำตกหมู",
#         "1847.jpg": "สเต็กหมู",
#         "1848.jpg": "แกงส้มชะอมกุ้ง",
#         "1849.jpg": "ไส้อั่ว",
#         "185.jpg": "แกงส้มชะอมกุ้ง",
#         "1850.jpg": "ปลากระพงนึ่งมะนาว",
#         "1851.jpg": "น้ำพริกไข่ปู",
#         "1852.jpg": "ยำหมูยอ",
#         "1853.jpg": "ข้าวหน้าเนื้อ",
#         "1854.jpg": "ยำถั่วพลู",
#         "1855.jpg": "ชาบู",
#         "1856.jpg": "ขนมปัง",
#         "1857.jpg": "น้ำพริกไข่ปู",
#         "1858.jpg": "ปูผัดผงกะหรี่",
#         "1859.jpg": "ก๋วยจั๊บ",
#         "186.jpg": "ปูนิ่มทอดกระเทียม",
#         "1860.jpg": "ไข่กระทะ",
#         "1861.jpg": "ปูม้านึ่ง",
#         "1862.jpg": "เป็ดพะโล้",
#         "1863.jpg": "น้ำพริกไข่ปู",
#         "1864.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1865.jpg": "ก๋วยจั๊บ",
#         "1866.jpg": "ปูผัดผงกะหรี่",
#         "1867.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1868.jpg": "แกงส้มชะอมกุ้ง",
#         "1869.jpg": "ไอศกรีม",
#         "187.jpg": "ขาหมูเยอรมัน",
#         "1870.jpg": "ก๋วยจั๊บ",
#         "1871.jpg": "ไอศกรีม",
#         "1872.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1873.jpg": "ฮะเก๋า",
#         "1874.jpg": "ขนมถ้วย",
#         "1875.jpg": "เป็ดพะโล้",
#         "1876.jpg": "honey toast",
#         "1877.jpg": "ก๋วยจั๊บ",
#         "1878.jpg": "ขนมปังสังขยา",
#         "1879.jpg": "ไส้อั่ว",
#         "188.jpg": "ไข่กระทะ",
#         "1880.jpg": "ปูผัดผงกะหรี่",
#         "1881.jpg": "ไข่กระทะ",
#         "1882.jpg": "เค้ก",
#         "1883.jpg": "ซุปเห็ด",
#         "1884.jpg": "ไข่กระทะ",
#         "1885.jpg": "ก๋วยจั๊บญวน",
#         "1886.jpg": "ต้มเลือดหมู",
#         "1887.jpg": "ไอศกรีม",
#         "1888.jpg": "บะหมี่แห้ง",
#         "1889.jpg": "น้ำตกหมู",
#         "189.jpg": "ข้าวหน้าเป็ด",
#         "1890.jpg": "ข้าวหน้าเนื้อ",
#         "1891.jpg": "เนื้อย่าง",
#         "1892.jpg": "ขนมปังสังขยา",
#         "1893.jpg": "ปอเปี๊ยะทอด",
#         "1894.jpg": "ก๋วยจั๊บ",
#         "1895.jpg": "honey toast",
#         "1896.jpg": "ต้มเลือดหมู",
#         "1897.jpg": "ต้มเลือดหมู",
#         "1898.jpg": "ซุปเห็ด",
#         "1899.jpg": "ชาบู",
#         "19.jpg": "ก๋วยจั๊บ",
#         "190.jpg": "ยำปลาดุกฟู",
#         "1900.jpg": "ก๋วยจั๊บญวน",
#         "1901.jpg": "หมูมะนาว",
#         "1902.jpg": "ยำหมูยอ",
#         "1903.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1904.jpg": "ปอเปี๊ยะทอด",
#         "1905.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1906.jpg": "ข้าวหมกไก่",
#         "1907.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "1908.jpg": "น้ำตกหมู",
#         "1909.jpg": "ขนมปัง",
#         "191.jpg": "บะหมี่แห้ง",
#         "1910.jpg": "น้ำตกหมู",
#         "1911.jpg": "ยำสาหร่าย",
#         "1912.jpg": "กระเพาะปลา",
#         "1913.jpg": "honey toast",
#         "1914.jpg": "honey toast",
#         "1915.jpg": "ชาบู",
#         "1916.jpg": "ข้าวหน้าเนื้อ",
#         "1917.jpg": "ข้าวหน้าเป็ด",
#         "1918.jpg": "ขนมปังปิ้ง",
#         "1919.jpg": "ขาหมูเยอรมัน",
#         "192.jpg": "ขนมปังปิ้ง",
#         "1920.jpg": "ยำปลาดุกฟู",
#         "1921.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1922.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1923.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1924.jpg": "ชาบู",
#         "1925.jpg": "ขาหมูเยอรมัน",
#         "1926.jpg": "ไอศกรีม",
#         "1927.jpg": "ก๋วยจั๊บญวน",
#         "1928.jpg": "ไส้อั่ว",
#         "1929.jpg": "ขนมปังสังขยา",
#         "193.jpg": "ก๋วยเตี๋ยวเรือ",
#         "1930.jpg": "ต้มเลือดหมู",
#         "1931.jpg": "ยำหมูยอ",
#         "1932.jpg": "บะหมี่แห้ง",
#         "1933.jpg": "เนื้อย่าง",
#         "1934.jpg": "ปูผัดผงกะหรี่",
#         "1935.jpg": "ยำปลาดุกฟู",
#         "1936.jpg": "สเต็กหมู",
#         "1937.jpg": "ชาบู",
#         "1938.jpg": "ข้าวหน้าเป็ด",
#         "1939.jpg": "เค้ก",
#         "194.jpg": "ทาโกะยากิ",
#         "1940.jpg": "หมูมะนาว",
#         "1941.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1942.jpg": "เกี๊ยวทอด",
#         "1943.jpg": "ขนมปังสังขยา",
#         "1944.jpg": "เกี๊ยวทอด",
#         "1945.jpg": "ปูม้านึ่ง",
#         "1946.jpg": "ไอศกรีม",
#         "1947.jpg": "ปลากระพงนึ่งมะนาว",
#         "1948.jpg": "ทาโกะยากิ",
#         "1949.jpg": "ขนมปังปิ้ง",
#         "195.jpg": "น้ำพริกไข่ปู",
#         "1950.jpg": "เกี๊ยวทอด",
#         "1951.jpg": "ออส่วน",
#         "1952.jpg": "ต้มเลือดหมู",
#         "1953.jpg": "honey toast",
#         "1954.jpg": "ปลากระพงนึ่งมะนาว",
#         "1955.jpg": "ออส่วน",
#         "1956.jpg": "honey toast",
#         "1957.jpg": "ข้าวหน้าเนื้อ",
#         "1958.jpg": "ไอศกรีม",
#         "1959.jpg": "ปลากระพงนึ่งมะนาว",
#         "196.jpg": "กระเพาะปลา",
#         "1960.jpg": "ขนมปังสังขยา",
#         "1961.jpg": "เป็ดย่าง",
#         "1962.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "1963.jpg": "ไส้อั่ว",
#         "1964.jpg": "ข้าวหน้าเนื้อ",
#         "1965.jpg": "เกี๊ยวทอด",
#         "1966.jpg": "บะหมี่แห้ง",
#         "1967.jpg": "ข้าวหมูกรอบ",
#         "1968.jpg": "ข้าวหมกไก่",
#         "1969.jpg": "ก๋วยจั๊บญวน",
#         "197.jpg": "เป็ดพะโล้",
#         "1970.jpg": "ข้าวผัดกระเทียม",
#         "1971.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "1972.jpg": "ก๋วยจั๊บญวน",
#         "1973.jpg": "แกงส้มชะอมกุ้ง",
#         "1974.jpg": "แกงส้มชะอมกุ้ง",
#         "1975.jpg": "เป็ดพะโล้",
#         "1976.jpg": "ยำปลาดุกฟู",
#         "1977.jpg": "ต้มเลือดหมู",
#         "1978.jpg": "น้ำตกหมู",
#         "1979.jpg": "ยำแซลมอน",
#         "198.jpg": "ไส้อั่ว",
#         "1980.jpg": "เป็ดย่าง",
#         "1981.jpg": "ยำสาหร่าย",
#         "1982.jpg": "ก๋วยจั๊บญวน",
#         "1983.jpg": "ปูม้านึ่ง",
#         "1984.jpg": "ต้มเลือดหมู",
#         "1985.jpg": "ยำแซลมอน",
#         "1986.jpg": "ข้าวหมกไก่",
#         "1987.jpg": "กระเพาะปลา",
#         "1988.jpg": "ขาหมูเยอรมัน",
#         "1989.jpg": "น้ำพริกไข่ปู",
#         "199.jpg": "น้ำพริกไข่ปู",
#         "1990.jpg": "ปูม้านึ่ง",
#         "1991.jpg": "เค้ก",
#         "1992.jpg": "กระเพาะปลา",
#         "1993.jpg": "เป็ดย่าง",
#         "1994.jpg": "ข้าวหมูกรอบ",
#         "1995.jpg": "ขนมปังสังขยา",
#         "1996.jpg": "ขนมปังปิ้ง",
#         "1997.jpg": "เกี๊ยวทอด",
#         "1998.jpg": "น้ำพริกไข่ปู",
#         "1999.jpg": "ปอเปี๊ยะทอด",
#         "2.jpg": "ชาบู",
#         "20.jpg": "ยำถั่วพลู",
#         "200.jpg": "ไข่ตุ๋น",
#         "2000.jpg": "ปูม้านึ่ง",
#         "2001.jpg": "หมูมะนาว",
#         "2002.jpg": "ซุปเห็ด",
#         "2003.jpg": "honey toast",
#         "2004.jpg": "ไส้อั่ว",
#         "2005.jpg": "ต้มเลือดหมู",
#         "2006.jpg": "ไอศกรีม",
#         "2007.jpg": "ขนมปังสังขยา",
#         "2008.jpg": "ก๋วยจั๊บ",
#         "2009.jpg": "ข้าวผัดกระเทียม",
#         "201.jpg": "ขาหมูเยอรมัน",
#         "2010.jpg": "ต้มเลือดหมู",
#         "2011.jpg": "ก๋วยจั๊บ",
#         "2012.jpg": "น้ำพริกไข่ปู",
#         "2013.jpg": "ปลากระพงนึ่งมะนาว",
#         "2014.jpg": "ก๋วยจั๊บญวน",
#         "2015.jpg": "ปูม้านึ่ง",
#         "2016.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "2017.jpg": "หมูมะนาว",
#         "2018.jpg": "ยำหมูยอ",
#         "2019.jpg": "สเต็กหมู",
#         "202.jpg": "กระเพาะปลา",
#         "2020.jpg": "กระเพาะปลา",
#         "2021.jpg": "น้ำตกหมู",
#         "2022.jpg": "ขาหมูเยอรมัน",
#         "2023.jpg": "เป็ดย่าง",
#         "2024.jpg": "ข้าวผัดกระเทียม",
#         "2025.jpg": "เป็ดพะโล้",
#         "2026.jpg": "ยำหมูยอ",
#         "2027.jpg": "ออส่วน",
#         "2028.jpg": "ขนมถ้วย",
#         "2029.jpg": "ขนมปัง",
#         "203.jpg": "ข้าวหมกไก่",
#         "2030.jpg": "ซุปเห็ด",
#         "2031.jpg": "สเต็กหมู",
#         "2032.jpg": "ขนมปังปิ้ง",
#         "2033.jpg": "ยำสาหร่าย",
#         "2034.jpg": "ฮะเก๋า",
#         "2035.jpg": "ขนมปัง",
#         "2036.jpg": "ซุปเห็ด",
#         "2037.jpg": "ยำหมูยอ",
#         "2038.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "2039.jpg": "ไส้อั่ว",
#         "204.jpg": "ไข่ตุ๋น",
#         "2040.jpg": "ยำสาหร่าย",
#         "2041.jpg": "สเต็กหมู",
#         "2042.jpg": "ปลากระพงนึ่งมะนาว",
#         "2043.jpg": "ก๋วยจั๊บ",
#         "2044.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "2045.jpg": "ฮะเก๋า",
#         "2046.jpg": "เค้ก",
#         "2047.jpg": "แกงคั่วหอยขม",
#         "2048.jpg": "ก๋วยจั๊บญวน",
#         "2049.jpg": "ข้าวหมกไก่",
#         "205.jpg": "บะหมี่แห้ง",
#         "2050.jpg": "honey toast",
#         "2051.jpg": "ซุปเห็ด",
#         "2052.jpg": "honey toast",
#         "2053.jpg": "ฮะเก๋า",
#         "2054.jpg": "ปูม้านึ่ง",
#         "2055.jpg": "เกี๊ยวทอด",
#         "2056.jpg": "ยำปลาดุกฟู",
#         "2057.jpg": "ก๋วยเตี๋ยวเรือ",
#         "2058.jpg": "หมูมะนาว",
#         "2059.jpg": "แกงส้มชะอมกุ้ง",
#         "206.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "2060.jpg": "honey toast",
#         "2061.jpg": "ปูม้านึ่ง",
#         "2062.jpg": "ข้าวผัดกระเทียม",
#         "2063.jpg": "ซุปเห็ด",
#         "2064.jpg": "บะหมี่แห้ง",
#         "2065.jpg": "บะหมี่แห้ง",
#         "2066.jpg": "ข้าวผัดกระเทียม",
#         "2067.jpg": "ข้าวหน้าเนื้อ",
#         "2068.jpg": "ก๋วยจั๊บ",
#         "2069.jpg": "ขาหมูเยอรมัน",
#         "207.jpg": "ข้าวหมูกรอบ",
#         "2070.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "2071.jpg": "ซุปเห็ด",
#         "2072.jpg": "ยำหมูยอ",
#         "2073.jpg": "ไส้อั่ว",
#         "2074.jpg": "สเต็กหมู",
#         "2075.jpg": "กระเพาะปลา",
#         "2076.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "2077.jpg": "ขาหมูเยอรมัน",
#         "2078.jpg": "เกี๊ยวทอด",
#         "2079.jpg": "ต้มเลือดหมู",
#         "208.jpg": "เป็ดพะโล้",
#         "2080.jpg": "หมูมะนาว",
#         "2081.jpg": "ไส้อั่ว",
#         "2082.jpg": "น้ำตกหมู",
#         "2083.jpg": "ไข่กระทะ",
#         "2084.jpg": "แกงส้มชะอมกุ้ง",
#         "2085.jpg": "ข้าวหน้าเป็ด",
#         "2086.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "2087.jpg": "เนื้อย่าง",
#         "2088.jpg": "เนื้อย่าง",
#         "2089.jpg": "เนื้อย่าง",
#         "209.jpg": "ไส้อั่ว",
#         "2090.jpg": "ข้าวหน้าเนื้อ",
#         "2091.jpg": "ทาโกะยากิ",
#         "2092.jpg": "ปูม้านึ่ง",
#         "2093.jpg": "ปูม้านึ่ง",
#         "2094.jpg": "ชาบู",
#         "2095.jpg": "กระเพาะปลา",
#         "2096.jpg": "ขนมปังปิ้ง",
#         "2097.jpg": "เกี๊ยวทอด",
#         "2098.jpg": "ยำถั่วพลู",
#         "2099.jpg": "เค้ก",
#         "21.jpg": "ไอศกรีม",
#         "210.jpg": "ยำสาหร่าย",
#         "2100.jpg": "ก๋วยเตี๋ยวเรือ",
#         "2101.jpg": "ยำแซลมอน",
#         "2102.jpg": "ทาโกะยากิ",
#         "2103.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "2104.jpg": "ขนมปังสังขยา",
#         "2105.jpg": "เนื้อย่าง",
#         "2106.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "2107.jpg": "ชาบู",
#         "2108.jpg": "ยำแซลมอน",
#         "2109.jpg": "ยำสาหร่าย",
#         "211.jpg": "ขนมปังปิ้ง",
#         "2110.jpg": "เป็ดพะโล้",
#         "2111.jpg": "ขนมปังสังขยา",
#         "2112.jpg": "เป็ดพะโล้",
#         "2113.jpg": "ขาหมูเยอรมัน",
#         "2114.jpg": "ขนมปังสังขยา",
#         "2115.jpg": "ข้าวผัดกระเทียม",
#         "2116.jpg": "ข้าวหมูกรอบ",
#         "2117.jpg": "honey toast",
#         "2118.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "2119.jpg": "น้ำตกหมู",
#         "212.jpg": "หมูมะนาว",
#         "2120.jpg": "ปูผัดผงกะหรี่",
#         "2121.jpg": "ยำปลาดุกฟู",
#         "2122.jpg": "ทาโกะยากิ",
#         "2123.jpg": "ทาโกะยากิ",
#         "2124.jpg": "ซุปเห็ด",
#         "2125.jpg": "ต้มเลือดหมู",
#         "2126.jpg": "honey toast",
#         "2127.jpg": "ยำแซลมอน",
#         "2128.jpg": "ขนมปังปิ้ง",
#         "2129.jpg": "ไข่กระทะ",
#         "213.jpg": "ขาหมูเยอรมัน",
#         "2130.jpg": "ยำแซลมอน",
#         "2131.jpg": "ฮะเก๋า",
#         "2132.jpg": "เค้ก",
#         "2133.jpg": "ปอเปี๊ยะทอด",
#         "2134.jpg": "ข้าวผัดกระเทียม",
#         "2135.jpg": "ขนมปังปิ้ง",
#         "2136.jpg": "ต้มเลือดหมู",
#         "2137.jpg": "สเต็กหมู",
#         "2138.jpg": "ยำถั่วพลู",
#         "2139.jpg": "เกี๊ยวทอด",
#         "214.jpg": "ยำแซลมอน",
#         "2140.jpg": "ขนมถ้วย",
#         "2141.jpg": "ก๋วยจั๊บญวน",
#         "2142.jpg": "ขนมปัง",
#         "2143.jpg": "แกงคั่วหอยขม",
#         "2144.jpg": "ชาบู",
#         "2145.jpg": "ปูนิ่มทอดกระเทียม",
#         "2146.jpg": "ก๋วยจั๊บ",
#         "2147.jpg": "ข้าวหน้าเป็ด",
#         "2148.jpg": "แกงคั่วหอยขม",
#         "2149.jpg": "เนื้อย่าง",
#         "215.jpg": "ขนมปัง",
#         "2150.jpg": "ต้มเลือดหมู",
#         "2151.jpg": "ไอศกรีม",
#         "2152.jpg": "ไส้อั่ว",
#         "2153.jpg": "เป็ดย่าง",
#         "2154.jpg": "ไอศกรีม",
#         "2155.jpg": "ข้าวหมูกรอบ",
#         "2156.jpg": "ยำปลาดุกฟู",
#         "2157.jpg": "ออส่วน",
#         "2158.jpg": "ขนมถ้วย",
#         "2159.jpg": "แกงคั่วหอยขม",
#         "216.jpg": "ปอเปี๊ยะทอด",
#         "2160.jpg": "เค้ก",
#         "2161.jpg": "เนื้อย่าง",
#         "2162.jpg": "ขนมปัง",
#         "2163.jpg": "ข้าวหน้าเนื้อ",
#         "2164.jpg": "เกี๊ยวทอด",
#         "2165.jpg": "ข้าวหมกไก่",
#         "2166.jpg": "ยำแซลมอน",
#         "2167.jpg": "honey toast",
#         "2168.jpg": "เนื้อย่าง",
#         "2169.jpg": "ขนมปังสังขยา",
#         "217.jpg": "ต้มเลือดหมู",
#         "2170.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "2171.jpg": "เค้ก",
#         "2172.jpg": "ซุปเห็ด",
#         "2173.jpg": "เนื้อย่าง",
#         "2174.jpg": "เกี๊ยวทอด",
#         "2175.jpg": "ขนมปังสังขยา",
#         "2176.jpg": "ขนมปัง",
#         "2177.jpg": "ออส่วน",
#         "2178.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "2179.jpg": "ไข่กระทะ",
#         "218.jpg": "ไส้อั่ว",
#         "2180.jpg": "ก๋วยเตี๋ยวเรือ",
#         "2181.jpg": "แกงคั่วหอยขม",
#         "2182.jpg": "ก๋วยจั๊บญวน",
#         "2183.jpg": "ก๋วยเตี๋ยวเรือ",
#         "2184.jpg": "ขนมถ้วย",
#         "2185.jpg": "เนื้อย่าง",
#         "2186.jpg": "ขาหมูเยอรมัน",
#         "2187.jpg": "ก๋วยจั๊บ",
#         "2188.jpg": "น้ำพริกไข่ปู",
#         "2189.jpg": "ซุปเห็ด",
#         "219.jpg": "น้ำพริกไข่ปู",
#         "2190.jpg": "หมูมะนาว",
#         "2191.jpg": "เป็ดพะโล้",
#         "2192.jpg": "ขนมถ้วย",
#         "2193.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "2194.jpg": "ไอศกรีม",
#         "2195.jpg": "honey toast",
#         "2196.jpg": "สเต็กหมู",
#         "2197.jpg": "ยำปลาดุกฟู",
#         "2198.jpg": "ยำถั่วพลู",
#         "2199.jpg": "ขนมถ้วย",
#         "22.jpg": "ฮะเก๋า",
#         "220.jpg": "ขาหมูเยอรมัน",
#         "2200.jpg": "ข้าวหน้าเนื้อ",
#         "2201.jpg": "ไข่กระทะ",
#         "2202.jpg": "ขนมปัง",
#         "2203.jpg": "หมูมะนาว",
#         "2204.jpg": "ยำถั่วพลู",
#         "2205.jpg": "ขนมถ้วย",
#         "2206.jpg": "แกงส้มชะอมกุ้ง",
#         "2207.jpg": "ขนมปัง",
#         "2208.jpg": "ขนมปังปิ้ง",
#         "2209.jpg": "ยำแซลมอน",
#         "221.jpg": "ขนมปังสังขยา",
#         "2210.jpg": "ปูม้านึ่ง",
#         "2211.jpg": "ข้าวผัดกระเทียม",
#         "2212.jpg": "ไข่กระทะ",
#         "2213.jpg": "ออส่วน",
#         "2214.jpg": "ยำถั่วพลู",
#         "2215.jpg": "ข้าวหน้าเป็ด",
#         "2216.jpg": "ไส้อั่ว",
#         "2217.jpg": "ยำถั่วพลู",
#         "2218.jpg": "ปูนิ่มทอดกระเทียม",
#         "2219.jpg": "แกงส้มชะอมกุ้ง",
#         "222.jpg": "เนื้อย่าง",
#         "2220.jpg": "ข้าวหมูกรอบ",
#         "2221.jpg": "ก๋วยจั๊บ",
#         "2222.jpg": "ก๋วยจั๊บ",
#         "2223.jpg": "ขาหมูเยอรมัน",
#         "2224.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "2225.jpg": "ข้าวหน้าเนื้อ",
#         "2226.jpg": "บะหมี่แห้ง",
#         "2227.jpg": "ปอเปี๊ยะทอด",
#         "2228.jpg": "ฮะเก๋า",
#         "2229.jpg": "ปอเปี๊ยะทอด",
#         "223.jpg": "ปอเปี๊ยะทอด",
#         "2230.jpg": "ข้าวหน้าเป็ด",
#         "2231.jpg": "ปูผัดผงกะหรี่",
#         "2232.jpg": "สเต็กหมู",
#         "2233.jpg": "ข้าวหมูกรอบ",
#         "2234.jpg": "ขนมปังสังขยา",
#         "2235.jpg": "ยำแซลมอน",
#         "2236.jpg": "ปลากระพงนึ่งมะนาว",
#         "2237.jpg": "กระเพาะปลา",
#         "2238.jpg": "ปูม้านึ่ง",
#         "2239.jpg": "หมูมะนาว",
#         "224.jpg": "ยำสาหร่าย",
#         "2240.jpg": "ก๋วยจั๊บญวน",
#         "2241.jpg": "หมูมะนาว",
#         "2242.jpg": "ก๋วยจั๊บญวน",
#         "2243.jpg": "เป็ดพะโล้",
#         "2244.jpg": "ฮะเก๋า",
#         "2245.jpg": "ปูม้านึ่ง",
#         "2246.jpg": "ปลากระพงนึ่งมะนาว",
#         "2247.jpg": "ข้าวหน้าเนื้อ",
#         "2248.jpg": "ไข่ตุ๋น",
#         "2249.jpg": "ไข่กระทะ",
#         "225.jpg": "ชาบู",
#         "2250.jpg": "เป็ดพะโล้",
#         "2251.jpg": "น้ำตกหมู",
#         "2252.jpg": "ข้าวผัดกระเทียม",
#         "2253.jpg": "ขนมถ้วย",
#         "2254.jpg": "ข้าวหน้าเนื้อ",
#         "2255.jpg": "แกงคั่วหอยขม",
#         "2256.jpg": "ชาบู",
#         "2257.jpg": "ขาหมูเยอรมัน",
#         "2258.jpg": "ปลากระพงนึ่งมะนาว",
#         "2259.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "226.jpg": "ขนมปังปิ้ง",
# ...
#         "565.jpg": "สเต็กหมู",
#         "566.jpg": "ซุปเห็ด",
#         "567.jpg": "ยำแซลมอน",
#         "568.jpg": "ก๋วยเตี๋ยวเรือ",
#         "569.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "57.jpg": "ข้าวหน้าเป็ด",
#         "570.jpg": "เป็ดพะโล้",
#         "571.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "572.jpg": "ไข่ตุ๋น",
#         "573.jpg": "น้ำตกหมู",
#         "574.jpg": "ออส่วน",
#         "575.jpg": "ปอเปี๊ยะทอด",
#         "576.jpg": "หมูมะนาว",
#         "577.jpg": "ชาบู",
#         "578.jpg": "ก๋วยจั๊บญวน",
#         "579.jpg": "ปอเปี๊ยะทอด",
#         "58.jpg": "ปลากระพงนึ่งมะนาว",
#         "580.jpg": "น้ำพริกไข่ปู",
#         "581.jpg": "ก๋วยจั๊บ",
#         "582.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "583.jpg": "ซุปเห็ด",
#         "584.jpg": "ปอเปี๊ยะทอด",
#         "585.jpg": "ฮะเก๋า",
#         "586.jpg": "ข้าวหน้าเป็ด",
#         "587.jpg": "แกงส้มชะอมกุ้ง",
#         "588.jpg": "ก๋วยจั๊บ",
#         "589.jpg": "ชาบู",
#         "59.jpg": "ฮะเก๋า",
#         "590.jpg": "เกี๊ยวทอด",
#         "591.jpg": "น้ำพริกไข่ปู",
#         "592.jpg": "ฮะเก๋า",
#         "593.jpg": "ยำปลาดุกฟู",
#         "594.jpg": "ปลากระพงนึ่งมะนาว",
#         "595.jpg": "ยำถั่วพลู",
#         "596.jpg": "เป็ดพะโล้",
#         "597.jpg": "ยำถั่วพลู",
#         "598.jpg": "ไอศกรีม",
#         "599.jpg": "ข้าวหน้าเป็ด",
#         "6.jpg": "กระเพาะปลา",
#         "60.jpg": "ฮะเก๋า",
#         "600.jpg": "ยำสาหร่าย",
#         "601.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "602.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "603.jpg": "สเต็กหมู",
#         "604.jpg": "ขาหมูเยอรมัน",
#         "605.jpg": "ยำปลาดุกฟู",
#         "606.jpg": "เนื้อย่าง",
#         "607.jpg": "ไอศกรีม",
#         "608.jpg": "ปูนิ่มทอดกระเทียม",
#         "609.jpg": "กระเพาะปลา",
#         "61.jpg": "ข้าวหมกไก่",
#         "610.jpg": "honey toast",
#         "611.jpg": "เป็ดย่าง",
#         "612.jpg": "ไข่กระทะ",
#         "613.jpg": "เป็ดย่าง",
#         "614.jpg": "ต้มเลือดหมู",
#         "615.jpg": "ไอศกรีม",
#         "616.jpg": "เนื้อย่าง",
#         "617.jpg": "ยำถั่วพลู",
#         "618.jpg": "ขนมถ้วย",
#         "619.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "62.jpg": "honey toast",
#         "620.jpg": "น้ำตกหมู",
#         "621.jpg": "ไส้อั่ว",
#         "622.jpg": "แกงส้มชะอมกุ้ง",
#         "623.jpg": "แกงส้มชะอมกุ้ง",
#         "624.jpg": "ยำถั่วพลู",
#         "625.jpg": "ปูนิ่มทอดกระเทียม",
#         "626.jpg": "กระเพาะปลา",
#         "627.jpg": "ก๋วยเตี๋ยวเรือ",
#         "628.jpg": "ขนมถ้วย",
#         "629.jpg": "เป็ดพะโล้",
#         "63.jpg": "ปลากระพงนึ่งมะนาว",
#         "630.jpg": "กระเพาะปลา",
#         "631.jpg": "ปูนิ่มทอดกระเทียม",
#         "632.jpg": "แกงส้มชะอมกุ้ง",
#         "633.jpg": "เป็ดย่าง",
#         "634.jpg": "เค้ก",
#         "635.jpg": "ไอศกรีม",
#         "636.jpg": "ก๋วยเตี๋ยวเรือ",
#         "637.jpg": "ไอศกรีม",
#         "638.jpg": "ยำปลาดุกฟู",
#         "639.jpg": "น้ำพริกไข่ปู",
#         "64.jpg": "น้ำตกหมู",
#         "640.jpg": "ไอศกรีม",
#         "641.jpg": "ยำปลาดุกฟู",
#         "642.jpg": "ไข่ตุ๋น",
#         "643.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "644.jpg": "ขนมปังสังขยา",
#         "645.jpg": "ไข่กระทะ",
#         "646.jpg": "ไข่กระทะ",
#         "647.jpg": "กระเพาะปลา",
#         "648.jpg": "ยำถั่วพลู",
#         "649.jpg": "ข้าวหมกไก่",
#         "65.jpg": "ปอเปี๊ยะทอด",
#         "650.jpg": "ยำแซลมอน",
#         "651.jpg": "เป็ดพะโล้",
#         "652.jpg": "ข้าวหมูกรอบ",
#         "653.jpg": "ข้าวผัดกระเทียม",
#         "654.jpg": "ข้าวหน้าเนื้อ",
#         "655.jpg": "หมูมะนาว",
#         "656.jpg": "ขาหมูเยอรมัน",
#         "657.jpg": "ปูผัดผงกะหรี่",
#         "658.jpg": "ปูผัดผงกะหรี่",
#         "659.jpg": "เนื้อย่าง",
#         "66.jpg": "honey toast",
#         "660.jpg": "ข้าวหมกไก่",
#         "661.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "662.jpg": "สเต็กหมู",
#         "663.jpg": "แกงส้มชะอมกุ้ง",
#         "664.jpg": "ก๋วยเตี๋ยวเรือ",
#         "665.jpg": "ขนมปังปิ้ง",
#         "666.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "667.jpg": "น้ำพริกไข่ปู",
#         "668.jpg": "เป็ดพะโล้",
#         "669.jpg": "ออส่วน",
#         "67.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "670.jpg": "ขาหมูเยอรมัน",
#         "671.jpg": "ข้าวหน้าเนื้อ",
#         "672.jpg": "ข้าวหมกไก่",
#         "673.jpg": "เป็ดย่าง",
#         "674.jpg": "ออส่วน",
#         "675.jpg": "ปูม้านึ่ง",
#         "676.jpg": "ก๋วยจั๊บ",
#         "677.jpg": "ยำสาหร่าย",
#         "678.jpg": "บะหมี่แห้ง",
#         "679.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "68.jpg": "ขนมปัง",
#         "680.jpg": "แกงคั่วหอยขม",
#         "681.jpg": "ข้าวหมูกรอบ",
#         "682.jpg": "เป็ดพะโล้",
#         "683.jpg": "สเต็กหมู",
#         "684.jpg": "ปูนิ่มทอดกระเทียม",
#         "685.jpg": "ทาโกะยากิ",
#         "686.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "687.jpg": "ข้าวผัดกระเทียม",
#         "688.jpg": "เกี๊ยวทอด",
#         "689.jpg": "ปูผัดผงกะหรี่",
#         "69.jpg": "ออส่วน",
#         "690.jpg": "ข้าวหมูกรอบ",
#         "691.jpg": "ทาโกะยากิ",
#         "692.jpg": "ซุปเห็ด",
#         "693.jpg": "ขนมปัง",
#         "694.jpg": "แกงส้มชะอมกุ้ง",
#         "695.jpg": "กระเพาะปลา",
#         "696.jpg": "สเต็กหมู",
#         "697.jpg": "ปอเปี๊ยะทอด",
#         "698.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "699.jpg": "เค้ก",
#         "7.jpg": "ปูนิ่มทอดกระเทียม",
#         "70.jpg": "เป็ดพะโล้",
#         "700.jpg": "ข้าวหน้าเป็ด",
#         "701.jpg": "ขาหมูเยอรมัน",
#         "702.jpg": "ยำแซลมอน",
#         "703.jpg": "ออส่วน",
#         "704.jpg": "ขาหมูเยอรมัน",
#         "705.jpg": "ไส้อั่ว",
#         "706.jpg": "ยำหมูยอ",
#         "707.jpg": "ขนมถ้วย",
#         "708.jpg": "ก๋วยจั๊บญวน",
#         "709.jpg": "ยำสาหร่าย",
#         "71.jpg": "เนื้อย่าง",
#         "710.jpg": "เนื้อย่าง",
#         "711.jpg": "ขาหมูเยอรมัน",
#         "712.jpg": "ขนมปังปิ้ง",
#         "713.jpg": "ยำหมูยอ",
#         "714.jpg": "ซุปเห็ด",
#         "715.jpg": "ข้าวหน้าเป็ด",
#         "716.jpg": "แกงคั่วหอยขม",
#         "717.jpg": "หมูมะนาว",
#         "718.jpg": "สเต็กหมู",
#         "719.jpg": "ยำถั่วพลู",
#         "72.jpg": "ฮะเก๋า",
#         "720.jpg": "ไส้อั่ว",
#         "721.jpg": "ไข่ตุ๋น",
#         "722.jpg": "ออส่วน",
#         "723.jpg": "ก๋วยเตี๋ยวเรือ",
#         "724.jpg": "ต้มเลือดหมู",
#         "725.jpg": "ไข่ตุ๋น",
#         "726.jpg": "ข้าวหมูกรอบ",
#         "727.jpg": "ข้าวผัดกระเทียม",
#         "728.jpg": "ก๋วยจั๊บ",
#         "729.jpg": "กระเพาะปลา",
#         "73.jpg": "เป็ดย่าง",
#         "730.jpg": "ก๋วยจั๊บ",
#         "731.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "732.jpg": "ขนมปังปิ้ง",
#         "733.jpg": "กระเพาะปลา",
#         "734.jpg": "เกี๊ยวทอด",
#         "735.jpg": "น้ำตกหมู",
#         "736.jpg": "ปลากระพงนึ่งมะนาว",
#         "737.jpg": "สเต็กหมู",
#         "738.jpg": "ไข่ตุ๋น",
#         "739.jpg": "ปูผัดผงกะหรี่",
#         "74.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "740.jpg": "หมูมะนาว",
#         "741.jpg": "หมูมะนาว",
#         "742.jpg": "ข้าวหมกไก่",
#         "743.jpg": "ข้าวหน้าเนื้อ",
#         "744.jpg": "ข้าวผัดกระเทียม",
#         "745.jpg": "ต้มเลือดหมู",
#         "746.jpg": "honey toast",
#         "747.jpg": "ปูม้านึ่ง",
#         "748.jpg": "ขนมถ้วย",
#         "749.jpg": "ขนมปังปิ้ง",
#         "75.jpg": "ข้าวหน้าเนื้อ",
#         "750.jpg": "ไข่ตุ๋น",
#         "751.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "752.jpg": "กระเพาะปลา",
#         "753.jpg": "ไอศกรีม",
#         "754.jpg": "ยำสาหร่าย",
#         "755.jpg": "แกงส้มชะอมกุ้ง",
#         "756.jpg": "ขนมปังปิ้ง",
#         "757.jpg": "ขนมปังปิ้ง",
#         "758.jpg": "ยำสาหร่าย",
#         "759.jpg": "ขาหมูเยอรมัน",
#         "76.jpg": "honey toast",
#         "760.jpg": "ข้าวหมูกรอบ",
#         "761.jpg": "ยำสาหร่าย",
#         "762.jpg": "ขนมปัง",
#         "763.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "764.jpg": "ไส้อั่ว",
#         "765.jpg": "สเต็กหมู",
#         "766.jpg": "เกี๊ยวทอด",
#         "767.jpg": "ออส่วน",
#         "768.jpg": "ยำถั่วพลู",
#         "769.jpg": "ขนมปัง",
#         "77.jpg": "น้ำพริกไข่ปู",
#         "770.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "771.jpg": "หมูมะนาว",
#         "772.jpg": "ข้าวหน้าเนื้อ",
#         "773.jpg": "ยำแซลมอน",
#         "774.jpg": "เนื้อย่าง",
#         "775.jpg": "เป็ดย่าง",
#         "776.jpg": "ขาหมูเยอรมัน",
#         "777.jpg": "ข้าวหมูกรอบ",
#         "778.jpg": "ไส้อั่ว",
#         "779.jpg": "หมูมะนาว",
#         "78.jpg": "เกี๊ยวทอด",
#         "780.jpg": "ขาหมูเยอรมัน",
#         "781.jpg": "บะหมี่แห้ง",
#         "782.jpg": "กระเพาะปลา",
#         "783.jpg": "ซุปเห็ด",
#         "784.jpg": "ยำถั่วพลู",
#         "785.jpg": "ข้าวหมกไก่",
#         "786.jpg": "น้ำตกหมู",
#         "787.jpg": "ก๋วยจั๊บ",
#         "788.jpg": "honey toast",
#         "789.jpg": "ไส้อั่ว",
#         "79.jpg": "ข้าวหมกไก่",
#         "790.jpg": "ไข่กระทะ",
#         "791.jpg": "ซุปเห็ด",
#         "792.jpg": "เนื้อย่าง",
#         "793.jpg": "ต้มเลือดหมู",
#         "794.jpg": "ข้าวหน้าเป็ด",
#         "795.jpg": "กระเพาะปลา",
#         "796.jpg": "ปอเปี๊ยะทอด",
#         "797.jpg": "ปูม้านึ่ง",
#         "798.jpg": "สเต็กหมู",
#         "799.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "8.jpg": "ไข่ตุ๋น",
#         "80.jpg": "ยำปลาดุกฟู",
#         "800.jpg": "ยำหมูยอ",
#         "801.jpg": "ยำปลาดุกฟู",
#         "802.jpg": "สเต็กหมู",
#         "803.jpg": "ยำปลาดุกฟู",
#         "804.jpg": "ขาหมูเยอรมัน",
#         "805.jpg": "เค้ก",
#         "806.jpg": "ปลากระพงนึ่งมะนาว",
#         "807.jpg": "ยำหมูยอ",
#         "808.jpg": "honey toast",
#         "809.jpg": "สเต็กหมู",
#         "81.jpg": "ยำหมูยอ",
#         "810.jpg": "ชาบู",
#         "811.jpg": "น้ำพริกไข่ปู",
#         "812.jpg": "แกงส้มชะอมกุ้ง",
#         "813.jpg": "honey toast",
#         "814.jpg": "ปลากระพงนึ่งมะนาว",
#         "815.jpg": "กระเพาะปลา",
#         "816.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "817.jpg": "เกี๊ยวทอด",
#         "818.jpg": "แกงคั่วหอยขม",
#         "819.jpg": "น้ำตกหมู",
#         "82.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "820.jpg": "ทาโกะยากิ",
#         "821.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "822.jpg": "ยำหมูยอ",
#         "823.jpg": "ปลากระพงนึ่งมะนาว",
#         "824.jpg": "ไอศกรีม",
#         "825.jpg": "ขนมถ้วย",
#         "826.jpg": "กระเพาะปลา",
#         "827.jpg": "ปอเปี๊ยะทอด",
#         "828.jpg": "น้ำพริกไข่ปู",
#         "829.jpg": "ปอเปี๊ยะทอด",
#         "83.jpg": "ออส่วน",
#         "830.jpg": "กระเพาะปลา",
#         "831.jpg": "ปูม้านึ่ง",
#         "832.jpg": "ทาโกะยากิ",
#         "833.jpg": "ขนมปังสังขยา",
#         "834.jpg": "ยำปลาดุกฟู",
#         "835.jpg": "เป็ดย่าง",
#         "836.jpg": "น้ำตกหมู",
#         "837.jpg": "honey toast",
#         "838.jpg": "ไส้อั่ว",
#         "839.jpg": "ปลากระพงนึ่งมะนาว",
#         "84.jpg": "บะหมี่แห้ง",
#         "840.jpg": "ข้าวหมกไก่",
#         "841.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "842.jpg": "ขนมถ้วย",
#         "843.jpg": "เกี๊ยวทอด",
#         "844.jpg": "ออส่วน",
#         "845.jpg": "ฮะเก๋า",
#         "846.jpg": "ปอเปี๊ยะทอด",
#         "847.jpg": "ซุปเห็ด",
#         "848.jpg": "ยำสาหร่าย",
#         "849.jpg": "หมูมะนาว",
#         "85.jpg": "แกงส้มชะอมกุ้ง",
#         "850.jpg": "ข้าวหมกไก่",
#         "851.jpg": "น้ำตกหมู",
#         "852.jpg": "ขาหมูเยอรมัน",
#         "853.jpg": "ไส้อั่ว",
#         "854.jpg": "ซุปเห็ด",
#         "855.jpg": "เป็ดพะโล้",
#         "856.jpg": "กระเพาะปลา",
#         "857.jpg": "ขนมปังปิ้ง",
#         "858.jpg": "ข้าวหมกไก่",
#         "859.jpg": "ปอเปี๊ยะทอด",
#         "86.jpg": "เป็ดย่าง",
#         "860.jpg": "แกงส้มชะอมกุ้ง",
#         "861.jpg": "ชาบู",
#         "862.jpg": "ยำถั่วพลู",
#         "863.jpg": "ไข่กระทะ",
#         "864.jpg": "หมูมะนาว",
#         "865.jpg": "ต้มเลือดหมู",
#         "866.jpg": "เค้ก",
#         "867.jpg": "ไอศกรีม",
#         "868.jpg": "สเต็กหมู",
#         "869.jpg": "ออส่วน",
#         "87.jpg": "ยำถั่วพลู",
#         "870.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "871.jpg": "ไข่กระทะ",
#         "872.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "873.jpg": "ไข่กระทะ",
#         "874.jpg": "หมูมะนาว",
#         "875.jpg": "ก๋วยจั๊บญวน",
#         "876.jpg": "ข้าวหน้าเนื้อ",
#         "877.jpg": "ข้าวหมูกรอบ",
#         "878.jpg": "ข้าวหน้าเนื้อ",
#         "879.jpg": "เค้ก",
#         "88.jpg": "ไข่ตุ๋น",
#         "880.jpg": "ก๋วยจั๊บ",
#         "881.jpg": "ฮะเก๋า",
#         "882.jpg": "น้ำพริกไข่ปู",
#         "883.jpg": "เป็ดย่าง",
#         "884.jpg": "ปลากระพงนึ่งมะนาว",
#         "885.jpg": "ยำปลาดุกฟู",
#         "886.jpg": "ไข่ตุ๋น",
#         "887.jpg": "ขนมปังสังขยา",
#         "888.jpg": "ออส่วน",
#         "889.jpg": "ปูผัดผงกะหรี่",
#         "89.jpg": "ไข่กระทะ",
#         "890.jpg": "ปูม้านึ่ง",
#         "891.jpg": "ขาหมูเยอรมัน",
#         "892.jpg": "กระเพาะปลา",
#         "893.jpg": "ปลากระพงนึ่งมะนาว",
#         "894.jpg": "สเต็กหมู",
#         "895.jpg": "สเต็กหมู",
#         "896.jpg": "ชาบู",
#         "897.jpg": "honey toast",
#         "898.jpg": "ข้าวหน้าเนื้อ",
#         "899.jpg": "ข้าวหมกไก่",
#         "9.jpg": "ก๋วยเตี๋ยวเรือ",
#         "90.jpg": "เป็ดย่าง",
#         "900.jpg": "แกงส้มชะอมกุ้ง",
#         "901.jpg": "ฮะเก๋า",
#         "902.jpg": "ปูม้านึ่ง",
#         "903.jpg": "ออส่วน",
#         "904.jpg": "แกงส้มชะอมกุ้ง",
#         "905.jpg": "ข้าวหน้าเนื้อ",
#         "906.jpg": "ข้าวหมกไก่",
#         "907.jpg": "เค้ก",
#         "908.jpg": "ยำสาหร่าย",
#         "909.jpg": "ข้าวหน้าเนื้อ",
#         "91.jpg": "ก๋วยจั๊บ",
#         "910.jpg": "ต้มเลือดหมู",
#         "911.jpg": "ข้าวหน้าเป็ด",
#         "912.jpg": "ขนมถ้วย",
#         "913.jpg": "ข้าวหมูกรอบ",
#         "914.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "915.jpg": "ชาบู",
#         "916.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "917.jpg": "ข้าวหน้าเนื้อ",
#         "918.jpg": "ก๋วยเตี๋ยวเรือ",
#         "919.jpg": "เป็ดพะโล้",
#         "92.jpg": "เป็ดย่าง",
#         "920.jpg": "น้ำตกหมู",
#         "921.jpg": "บะหมี่แห้ง",
#         "922.jpg": "ข้าวหมกไก่",
#         "923.jpg": "ออส่วน",
#         "924.jpg": "สปาเก็ตตี้ขี้เมาทะเล",
#         "925.jpg": "หมูมะนาว",
#         "926.jpg": "ข้าวหน้าเป็ด",
#         "927.jpg": "ขนมปังสังขยา",
#         "928.jpg": "ข้าวหมกไก่",
#         "929.jpg": "น้ำพริกไข่ปู",
#         "93.jpg": "ยำปลาดุกฟู",
#         "930.jpg": "ยำหมูยอ",
#         "931.jpg": "เนื้อย่าง",
#         "932.jpg": "honey toast",
#         "933.jpg": "ก๋วยเตี๋ยวเรือ",
#         "934.jpg": "เนื้อย่าง",
#         "935.jpg": "เนื้อย่าง",
#         "936.jpg": "เนื้อย่าง",
#         "937.jpg": "บะหมี่แห้ง",
#         "938.jpg": "แกงส้มชะอมกุ้ง",
#         "939.jpg": "ปูนิ่มทอดกระเทียม",
#         "94.jpg": "กระเพาะปลา",
#         "940.jpg": "ยำสาหร่าย",
#         "941.jpg": "ข้าวหน้าเนื้อ",
#         "942.jpg": "เนื้อย่าง",
#         "943.jpg": "ฮะเก๋า",
#         "944.jpg": "หมูมะนาว",
#         "945.jpg": "ยำสาหร่าย",
#         "946.jpg": "ทาโกะยากิ",
#         "947.jpg": "ปูม้านึ่ง",
#         "948.jpg": "ก๋วยจั๊บ",
#         "949.jpg": "ปูนิ่มทอดกระเทียม",
#         "95.jpg": "ปูผัดผงกะหรี่",
#         "950.jpg": "เกี๊ยวทอด",
#         "951.jpg": "ชาบู",
#         "952.jpg": "หมูมะนาว",
#         "953.jpg": "น้ำตกหมู",
#         "954.jpg": "ออส่วน",
#         "955.jpg": "ชาบู",
#         "956.jpg": "แกงคั่วหอยขม",
#         "957.jpg": "เป็ดย่าง",
#         "958.jpg": "เป็ดพะโล้",
#         "959.jpg": "ต้มเลือดหมู",
#         "96.jpg": "ขนมปังสังขยา",
#         "960.jpg": "ปูนิ่มทอดกระเทียม",
#         "961.jpg": "ก๋วยเตี๋ยวเรือ",
#         "962.jpg": "ไข่ตุ๋น",
#         "963.jpg": "ปูผัดผงกะหรี่",
#         "964.jpg": "ชาบู",
#         "965.jpg": "ปอเปี๊ยะทอด",
#         "966.jpg": "honey toast",
#         "967.jpg": "หมูมะนาว",
#         "968.jpg": "ปอเปี๊ยะทอด",
#         "969.jpg": "ปลากระพงนึ่งมะนาว",
#         "97.jpg": "ก๋วยจั๊บญวน",
#         "970.jpg": "ข้าวหน้าเป็ด",
#         "971.jpg": "สปาเก็ตตี้คาโบนาร่า",
#         "972.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "973.jpg": "ปูม้านึ่ง",
#         "974.jpg": "ข้าวหน้าเป็ด",
#         "975.jpg": "ซุปเห็ด",
#         "976.jpg": "ข้าวหน้าเป็ด",
#         "977.jpg": "บะหมี่แห้ง",
#         "978.jpg": "เกี๊ยวทอด",
#         "979.jpg": "เป็ดย่าง",
#         "98.jpg": "เค้ก",
#         "980.jpg": "เนื้อย่าง",
#         "981.jpg": "ยำหมูยอ",
#         "982.jpg": "ก๋วยเตี๋ยวเรือ",
#         "983.jpg": "ยำถั่วพลู",
#         "984.jpg": "ขนมปังปิ้ง",
#         "985.jpg": "แกงส้มชะอมกุ้ง",
#         "986.jpg": "แกงคั่วหอยขม",
#         "987.jpg": "ชาบู",
#         "988.jpg": "เป็ดย่าง",
#         "989.jpg": "ข้าวหมกไก่",
#         "99.jpg": "กระเพาะปลา",
#         "990.jpg": "ก๋วยเตี๋ยวคั่วไก่",
#         "991.jpg": "เนื้อย่าง",
#         "992.jpg": "honey toast",
#         "993.jpg": "ไส้อั่ว",
#         "994.jpg": "ทาโกะยากิ",
#         "995.jpg": "ข้าวผัดกระเทียม",
#         "996.jpg": "ยำแซลมอน",
#         "997.jpg": "ออส่วน",
#         "998.jpg": "ปอเปี๊ยะทอด",
#         "999.jpg": "ขนมปังสังขยา",
#     }
# }

# %%
for i in range (1,5001):
    print(i, resultDict[str(i) + '.jpg'])
    assert(len(resultDict[str(i) + '.jpg']) >= 4)
# Out:
# 1 honey toast
# 2 ชาบู
# 3 เป็ดพะโล้
# 4 น้ำพริกไข่ปู
# 5 ปอเปี๊ยะทอด
# 6 กระเพาะปลา
# 7 ปูนิ่มทอดกระเทียม
# 8 ไข่ตุ๋น
# 9 ก๋วยเตี๋ยวเรือ
# 10 ข้าวหมูกรอบ
# 11 ปอเปี๊ยะทอด
# 12 ชาบู
# 13 ก๋วยจั๊บญวน
# 14 ไข่กระทะ
# 15 น้ำตกหมู
# 16 สปาเก็ตตี้คาโบนาร่า
# 17 ไอศกรีม
# 18 ยำปลาดุกฟู
# 19 ก๋วยจั๊บ
# 20 ยำถั่วพลู
# 21 ไอศกรีม
# 22 ฮะเก๋า
# 23 ปูม้านึ่ง
# 24 สเต็กหมู
# 25 ขนมปัง
# 26 ข้าวผัดกระเทียม
# 27 ยำปลาดุกฟู
# 28 น้ำพริกไข่ปู
# 29 ก๋วยเตี๋ยวเรือ
# 30 สเต็กหมู
# 31 ข้าวหมกไก่
# 32 ปลากระพงนึ่งมะนาว
# 33 ไส้อั่ว
# 34 ปลากระพงนึ่งมะนาว
# 35 เกี๊ยวทอด
# 36 ต้มเลือดหมู
# 37 ก๋วยจั๊บญวน
# 38 ขนมปังสังขยา
# 39 ยำสาหร่าย
# 40 สปาเก็ตตี้คาโบนาร่า
# 41 สเต็กหมู
# 42 ก๋วยเตี๋ยวเรือ
# 43 ก๋วยเตี๋ยวคั่วไก่
# 44 ไอศกรีม
# 45 กระเพาะปลา
# 46 หมูมะนาว
# 47 เกี๊ยวทอด
# 48 ข้าวหน้าเนื้อ
# 49 ไข่ตุ๋น
# 50 ก๋วยจั๊บ
# 51 ขนมปังสังขยา
# 52 สปาเก็ตตี้ขี้เมาทะเล
# 53 ออส่วน
# 54 ต้มเลือดหมู
# 55 ยำหมูยอ
# 56 สปาเก็ตตี้คาโบนาร่า
# 57 ข้าวหน้าเป็ด
# 58 ปลากระพงนึ่งมะนาว
# 59 ฮะเก๋า
# 60 ฮะเก๋า
# 61 ข้าวหมกไก่
# 62 honey toast
# 63 ปลากระพงนึ่งมะนาว
# 64 น้ำตกหมู
# 65 ปอเปี๊ยะทอด
# 66 honey toast
# 67 สปาเก็ตตี้ขี้เมาทะเล
# 68 ขนมปัง
# 69 ออส่วน
# 70 เป็ดพะโล้
# 71 เนื้อย่าง
# 72 ฮะเก๋า
# 73 เป็ดย่าง
# 74 สปาเก็ตตี้ขี้เมาทะเล
# 75 ข้าวหน้าเนื้อ
# 76 honey toast
# 77 น้ำพริกไข่ปู
# 78 เกี๊ยวทอด
# 79 ข้าวหมกไก่
# 80 ยำปลาดุกฟู
# 81 ยำหมูยอ
# 82 สปาเก็ตตี้ขี้เมาทะเล
# 83 ออส่วน
# 84 บะหมี่แห้ง
# 85 แกงส้มชะอมกุ้ง
# 86 เป็ดย่าง
# 87 ยำถั่วพลู
# 88 ไข่ตุ๋น
# 89 ไข่กระทะ
# 90 เป็ดย่าง
# 91 ก๋วยจั๊บ
# 92 เป็ดย่าง
# 93 ยำปลาดุกฟู
# 94 กระเพาะปลา
# 95 ปูผัดผงกะหรี่
# 96 ขนมปังสังขยา
# 97 ก๋วยจั๊บญวน
# 98 เค้ก
# 99 กระเพาะปลา
# 100 ทาโกะยากิ
# 101 แกงส้มชะอมกุ้ง
# 102 ไข่กระทะ
# 103 บะหมี่แห้ง
# 104 ยำแซลมอน
# 105 ยำถั่วพลู
# 106 แกงคั่วหอยขม
# 107 ขนมปังสังขยา
# 108 แกงคั่วหอยขม
# 109 เนื้อย่าง
# 110 ออส่วน
# 111 ยำแซลมอน
# 112 น้ำพริกไข่ปู
# 113 ไข่ตุ๋น
# 114 สปาเก็ตตี้ขี้เมาทะเล
# 115 ยำถั่วพลู
# 116 ปลากระพงนึ่งมะนาว
# 117 ทาโกะยากิ
# 118 กระเพาะปลา
# 119 ขนมถ้วย
# 120 สปาเก็ตตี้ขี้เมาทะเล
# 121 ยำหมูยอ
# 122 สปาเก็ตตี้ขี้เมาทะเล
# 123 ยำหมูยอ
# 124 ปอเปี๊ยะทอด
# 125 ชาบู
# 126 เป็ดย่าง
# 127 ฮะเก๋า
# 128 honey toast
# 129 ปลากระพงนึ่งมะนาว
# 130 ปูนิ่มทอดกระเทียม
# 131 เป็ดพะโล้
# 132 ขาหมูเยอรมัน
# 133 เป็ดพะโล้
# 134 ออส่วน
# 135 ปลากระพงนึ่งมะนาว
# 136 น้ำตกหมู
# 137 แกงส้มชะอมกุ้ง
# 138 ขนมปังปิ้ง
# 139 ขนมปังสังขยา
# 140 ข้าวผัดกระเทียม
# 141 ไอศกรีม
# 142 ไข่ตุ๋น
# 143 ข้าวหมกไก่
# 144 ไอศกรีม
# 145 เป็ดย่าง
# 146 ทาโกะยากิ
# 147 ฮะเก๋า
# 148 ขนมปังปิ้ง
# 149 ข้าวผัดกระเทียม
# 150 เนื้อย่าง
# 151 ก๋วยจั๊บญวน
# 152 ซุปเห็ด
# 153 ก๋วยเตี๋ยวคั่วไก่
# 154 ไข่กระทะ
# 155 ขนมปัง
# 156 ไข่กระทะ
# 157 ชาบู
# 158 ข้าวหน้าเป็ด
# 159 กระเพาะปลา
# 160 ไข่ตุ๋น
# 161 ข้าวหมกไก่
# 162 ไส้อั่ว
# 163 ขนมปัง
# 164 ยำปลาดุกฟู
# 165 ข้าวหมกไก่
# 166 ก๋วยจั๊บญวน
# 167 เป็ดย่าง
# 168 ขนมถ้วย
# 169 ก๋วยเตี๋ยวเรือ
# 170 หมูมะนาว
# 171 สปาเก็ตตี้คาโบนาร่า
# 172 แกงคั่วหอยขม
# 173 สปาเก็ตตี้คาโบนาร่า
# 174 ยำสาหร่าย
# 175 ข้าวหมกไก่
# 176 ขาหมูเยอรมัน
# 177 ยำสาหร่าย
# 178 honey toast
# 179 กระเพาะปลา
# 180 สปาเก็ตตี้คาโบนาร่า
# 181 ยำแซลมอน
# 182 สปาเก็ตตี้ขี้เมาทะเล
# 183 น้ำตกหมู
# 184 บะหมี่แห้ง
# 185 แกงส้มชะอมกุ้ง
# 186 ปูนิ่มทอดกระเทียม
# 187 ขาหมูเยอรมัน
# 188 ไข่กระทะ
# 189 ข้าวหน้าเป็ด
# 190 ยำปลาดุกฟู
# 191 บะหมี่แห้ง
# 192 ขนมปังปิ้ง
# 193 ก๋วยเตี๋ยวเรือ
# 194 ทาโกะยากิ
# 195 น้ำพริกไข่ปู
# 196 กระเพาะปลา
# 197 เป็ดพะโล้
# 198 ไส้อั่ว
# 199 น้ำพริกไข่ปู
# 200 ไข่ตุ๋น
# 201 ขาหมูเยอรมัน
# 202 กระเพาะปลา
# 203 ข้าวหมกไก่
# 204 ไข่ตุ๋น
# 205 บะหมี่แห้ง
# 206 สปาเก็ตตี้ขี้เมาทะเล
# 207 ข้าวหมูกรอบ
# 208 เป็ดพะโล้
# 209 ไส้อั่ว
# 210 ยำสาหร่าย
# 211 ขนมปังปิ้ง
# 212 หมูมะนาว
# 213 ขาหมูเยอรมัน
# 214 ยำแซลมอน
# 215 ขนมปัง
# 216 ปอเปี๊ยะทอด
# 217 ต้มเลือดหมู
# 218 ไส้อั่ว
# 219 น้ำพริกไข่ปู
# 220 ขาหมูเยอรมัน
# 221 ขนมปังสังขยา
# 222 เนื้อย่าง
# 223 ปอเปี๊ยะทอด
# 224 ยำสาหร่าย
# 225 ชาบู
# 226 ขนมปังปิ้ง
# 227 สปาเก็ตตี้คาโบนาร่า
# 228 ปลากระพงนึ่งมะนาว
# 229 ขนมปังปิ้ง
# 230 ฮะเก๋า
# 231 ข้าวหน้าเนื้อ
# 232 ยำแซลมอน
# 233 ก๋วยจั๊บญวน
# 234 ข้าวผัดกระเทียม
# 235 ข้าวผัดกระเทียม
# 236 ยำแซลมอน
# 237 กระเพาะปลา
# 238 ขนมปังสังขยา
# 239 ข้าวหมกไก่
# 240 ยำถั่วพลู
# 241 ยำถั่วพลู
# 242 ข้าวผัดกระเทียม
# 243 ก๋วยจั๊บ
# 244 ก๋วยเตี๋ยวเรือ
# 245 ขนมปังสังขยา
# 246 ไอศกรีม
# 247 ขนมปัง
# 248 น้ำตกหมู
# 249 honey toast
# 250 ข้าวหมกไก่
# 251 ยำแซลมอน
# 252 ยำหมูยอ
# 253 ยำสาหร่าย
# 254 ทาโกะยากิ
# 255 สปาเก็ตตี้ขี้เมาทะเล
# 256 ชาบู
# 257 สปาเก็ตตี้คาโบนาร่า
# 258 ก๋วยจั๊บ
# 259 ไข่ตุ๋น
# 260 ไส้อั่ว
# 261 แกงคั่วหอยขม
# 262 ทาโกะยากิ
# 263 ข้าวหมกไก่
# 264 เนื้อย่าง
# 265 เนื้อย่าง
# 266 ปูผัดผงกะหรี่
# 267 ซุปเห็ด
# 268 แกงส้มชะอมกุ้ง
# 269 ข้าวหน้าเป็ด
# 270 ไอศกรีม
# 271 ไข่ตุ๋น
# 272 ปลากระพงนึ่งมะนาว
# 273 ปูนิ่มทอดกระเทียม
# 274 ไข่กระทะ
# 275 ก๋วยจั๊บ
# 276 ไส้อั่ว
# 277 ข้าวหน้าเนื้อ
# 278 หมูมะนาว
# 279 ข้าวหน้าเป็ด
# 280 สปาเก็ตตี้คาโบนาร่า
# 281 ทาโกะยากิ
# 282 ชาบู
# 283 ปูม้านึ่ง
# 284 ข้าวหน้าเนื้อ
# 285 ฮะเก๋า
# 286 ยำแซลมอน
# 287 สปาเก็ตตี้ขี้เมาทะเล
# 288 honey toast
# 289 ซุปเห็ด
# 290 ยำแซลมอน
# 291 ฮะเก๋า
# 292 บะหมี่แห้ง
# 293 ไส้อั่ว
# 294 ข้าวหน้าเป็ด
# 295 สเต็กหมู
# 296 ไอศกรีม
# 297 เนื้อย่าง
# 298 บะหมี่แห้ง
# 299 ไข่กระทะ
# 300 ข้าวหมูกรอบ
# 301 ปลากระพงนึ่งมะนาว
# 302 ต้มเลือดหมู
# 303 ยำสาหร่าย
# 304 ขนมปัง
# 305 ข้าวหมูกรอบ
# 306 ขนมถ้วย
# 307 ก๋วยจั๊บญวน
# 308 กระเพาะปลา
# 309 ทาโกะยากิ
# 310 honey toast
# 311 ไอศกรีม
# 312 ออส่วน
# 313 ไข่ตุ๋น
# 314 หมูมะนาว
# 315 ขนมถ้วย
# 316 ขนมปัง
# 317 ปอเปี๊ยะทอด
# 318 ข้าวผัดกระเทียม
# 319 ก๋วยเตี๋ยวเรือ
# 320 ฮะเก๋า
# 321 บะหมี่แห้ง
# 322 ไส้อั่ว
# 323 ไข่กระทะ
# 324 ปูนิ่มทอดกระเทียม
# 325 ก๋วยเตี๋ยวเรือ
# 326 หมูมะนาว
# 327 ยำปลาดุกฟู
# 328 น้ำพริกไข่ปู
# 329 เกี๊ยวทอด
# 330 ขนมปังสังขยา
# 331 ไข่กระทะ
# 332 หมูมะนาว
# 333 ขนมปังปิ้ง
# 334 เค้ก
# 335 แกงคั่วหอยขม
# 336 honey toast
# 337 แกงคั่วหอยขม
# 338 เนื้อย่าง
# 339 ขนมถ้วย
# 340 สปาเก็ตตี้ขี้เมาทะเล
# 341 ปูผัดผงกะหรี่
# 342 ไอศกรีม
# 343 เป็ดพะโล้
# 344 ข้าวผัดกระเทียม
# 345 ข้าวหมกไก่
# 346 ก๋วยเตี๋ยวเรือ
# 347 ขนมปัง
# 348 ขนมถ้วย
# 349 ซุปเห็ด
# 350 ขนมปังปิ้ง
# 351 ขนมปังปิ้ง
# 352 แกงส้มชะอมกุ้ง
# 353 สปาเก็ตตี้คาโบนาร่า
# 354 น้ำตกหมู
# 355 ข้าวหน้าเนื้อ
# 356 กระเพาะปลา
# 357 ขนมปังปิ้ง
# 358 ไข่กระทะ
# 359 เป็ดพะโล้
# 360 ชาบู
# 361 ก๋วยจั๊บญวน
# 362 ข้าวผัดกระเทียม
# 363 ก๋วยจั๊บญวน
# 364 กระเพาะปลา
# 365 น้ำพริกไข่ปู
# 366 กระเพาะปลา
# 367 ขนมปัง
# 368 ก๋วยจั๊บ
# 369 ข้าวหมูกรอบ
# 370 ขนมปังปิ้ง
# 371 ก๋วยเตี๋ยวคั่วไก่
# 372 เป็ดย่าง
# 373 ต้มเลือดหมู
# 374 ข้าวหมกไก่
# 375 ก๋วยเตี๋ยวเรือ
# 376 ไอศกรีม
# 377 ไอศกรีม
# 378 honey toast
# 379 เป็ดพะโล้
# 380 ขาหมูเยอรมัน
# 381 ขนมปังสังขยา
# 382 แกงคั่วหอยขม
# 383 เป็ดย่าง
# 384 ก๋วยจั๊บญวน
# 385 ยำแซลมอน
# 386 น้ำตกหมู
# 387 ปูม้านึ่ง
# 388 honey toast
# 389 ยำปลาดุกฟู
# 390 ก๋วยเตี๋ยวเรือ
# 391 แกงส้มชะอมกุ้ง
# 392 ยำสาหร่าย
# 393 ขาหมูเยอรมัน
# 394 ข้าวหมกไก่
# 395 ยำถั่วพลู
# 396 ไส้อั่ว
# 397 honey toast
# 398 ไส้อั่ว
# 399 เป็ดพะโล้
# 400 ยำแซลมอน
# 401 ก๋วยเตี๋ยวเรือ
# 402 ปูนิ่มทอดกระเทียม
# 403 ฮะเก๋า
# 404 แกงคั่วหอยขม
# 405 ยำปลาดุกฟู
# 406 ปูม้านึ่ง
# 407 ปูผัดผงกะหรี่
# 408 แกงส้มชะอมกุ้ง
# 409 เนื้อย่าง
# 410 ปลากระพงนึ่งมะนาว
# 411 บะหมี่แห้ง
# 412 ไข่ตุ๋น
# 413 ก๋วยจั๊บญวน
# 414 ยำสาหร่าย
# 415 เนื้อย่าง
# 416 ปูม้านึ่ง
# 417 บะหมี่แห้ง
# 418 ก๋วยเตี๋ยวคั่วไก่
# 419 ปูผัดผงกะหรี่
# 420 ซุปเห็ด
# 421 ยำแซลมอน
# 422 ปอเปี๊ยะทอด
# 423 ก๋วยเตี๋ยวเรือ
# 424 เค้ก
# 425 ก๋วยเตี๋ยวคั่วไก่
# 426 ยำปลาดุกฟู
# 427 ก๋วยเตี๋ยวเรือ
# 428 หมูมะนาว
# 429 ไข่กระทะ
# 430 กระเพาะปลา
# 431 เค้ก
# 432 สปาเก็ตตี้คาโบนาร่า
# 433 ข้าวหมูกรอบ
# 434 ยำสาหร่าย
# 435 ขนมปัง
# 436 ก๋วยจั๊บ
# 437 ยำสาหร่าย
# 438 แกงส้มชะอมกุ้ง
# 439 หมูมะนาว
# 440 ยำหมูยอ
# 441 ออส่วน
# 442 ขนมปังปิ้ง
# 443 ก๋วยจั๊บญวน
# 444 เกี๊ยวทอด
# 445 ก๋วยเตี๋ยวเรือ
# 446 ก๋วยจั๊บญวน
# 447 ก๋วยเตี๋ยวเรือ
# 448 แกงคั่วหอยขม
# 449 แกงส้มชะอมกุ้ง
# 450 ชาบู
# 451 ก๋วยจั๊บญวน
# 452 ขนมปัง
# 453 หมูมะนาว
# 454 แกงส้มชะอมกุ้ง
# 455 ก๋วยเตี๋ยวเรือ
# 456 ไข่ตุ๋น
# 457 ต้มเลือดหมู
# 458 หมูมะนาว
# 459 แกงคั่วหอยขม
# 460 ก๋วยจั๊บ
# 461 ข้าวหมกไก่
# 462 น้ำพริกไข่ปู
# 463 ขนมถ้วย
# 464 ยำสาหร่าย
# 465 ยำหมูยอ
# 466 สปาเก็ตตี้คาโบนาร่า
# 467 ขาหมูเยอรมัน
# 468 ขาหมูเยอรมัน
# 469 น้ำตกหมู
# 470 ไส้อั่ว
# 471 ออส่วน
# 472 ปูม้านึ่ง
# 473 ไอศกรีม
# 474 ฮะเก๋า
# 475 ต้มเลือดหมู
# 476 ฮะเก๋า
# 477 ขนมปังปิ้ง
# 478 ไส้อั่ว
# 479 ไส้อั่ว
# 480 กระเพาะปลา
# 481 ปูม้านึ่ง
# 482 ขาหมูเยอรมัน
# 483 เป็ดย่าง
# 484 ขนมถ้วย
# 485 สปาเก็ตตี้ขี้เมาทะเล
# 486 ยำสาหร่าย
# 487 ข้าวหน้าเนื้อ
# 488 ไข่กระทะ
# 489 ต้มเลือดหมู
# 490 ก๋วยจั๊บญวน
# 491 ขนมปังสังขยา
# 492 บะหมี่แห้ง
# 493 ข้าวหน้าเนื้อ
# 494 ข้าวหมูกรอบ
# 495 น้ำพริกไข่ปู
# 496 ก๋วยเตี๋ยวเรือ
# 497 เป็ดพะโล้
# 498 ยำถั่วพลู
# 499 ไส้อั่ว
# 500 ยำแซลมอน
# 501 สปาเก็ตตี้ขี้เมาทะเล
# 502 เกี๊ยวทอด
# 503 ซุปเห็ด
# 504 ยำหมูยอ
# 505 ขนมปังปิ้ง
# 506 ยำแซลมอน
# 507 ไข่กระทะ
# 508 เป็ดย่าง
# 509 เป็ดย่าง
# 510 ยำถั่วพลู
# 511 สปาเก็ตตี้ขี้เมาทะเล
# 512 เค้ก
# 513 แกงคั่วหอยขม
# 514 ชาบู
# 515 น้ำตกหมู
# 516 ก๋วยเตี๋ยวคั่วไก่
# 517 ต้มเลือดหมู
# 518 ก๋วยจั๊บญวน
# 519 ขนมปังสังขยา
# 520 ขนมถ้วย
# 521 ไส้อั่ว
# 522 ปอเปี๊ยะทอด
# 523 ต้มเลือดหมู
# 524 เป็ดย่าง
# 525 ข้าวหมกไก่
# 526 ยำสาหร่าย
# 527 ไอศกรีม
# 528 แกงส้มชะอมกุ้ง
# 529 สปาเก็ตตี้ขี้เมาทะเล
# 530 น้ำตกหมู
# 531 ก๋วยจั๊บญวน
# 532 ขนมถ้วย
# 533 เกี๊ยวทอด
# 534 เกี๊ยวทอด
# 535 ข้าวหน้าเนื้อ
# 536 ซุปเห็ด
# 537 ก๋วยเตี๋ยวคั่วไก่
# 538 สปาเก็ตตี้ขี้เมาทะเล
# 539 ไข่ตุ๋น
# 540 เนื้อย่าง
# 541 สเต็กหมู
# 542 ก๋วยเตี๋ยวเรือ
# 543 ข้าวหน้าเนื้อ
# 544 ข้าวหน้าเนื้อ
# 545 ไอศกรีม
# 546 ก๋วยจั๊บ
# 547 เกี๊ยวทอด
# 548 ข้าวหมกไก่
# 549 เนื้อย่าง
# 550 ฮะเก๋า
# 551 ยำถั่วพลู
# 552 ยำหมูยอ
# 553 สปาเก็ตตี้คาโบนาร่า
# 554 แกงคั่วหอยขม
# 555 เป็ดย่าง
# 556 น้ำตกหมู
# 557 ทาโกะยากิ
# 558 แกงคั่วหอยขม
# 559 ขาหมูเยอรมัน
# 560 ไอศกรีม
# 561 แกงส้มชะอมกุ้ง
# 562 ขนมถ้วย
# 563 ข้าวหน้าเป็ด
# 564 ขนมปัง
# 565 สเต็กหมู
# 566 ซุปเห็ด
# 567 ยำแซลมอน
# 568 ก๋วยเตี๋ยวเรือ
# 569 ก๋วยเตี๋ยวคั่วไก่
# 570 เป็ดพะโล้
# 571 สปาเก็ตตี้ขี้เมาทะเล
# 572 ไข่ตุ๋น
# 573 น้ำตกหมู
# 574 ออส่วน
# 575 ปอเปี๊ยะทอด
# 576 หมูมะนาว
# 577 ชาบู
# 578 ก๋วยจั๊บญวน
# 579 ปอเปี๊ยะทอด
# 580 น้ำพริกไข่ปู
# 581 ก๋วยจั๊บ
# 582 สปาเก็ตตี้คาโบนาร่า
# 583 ซุปเห็ด
# 584 ปอเปี๊ยะทอด
# 585 ฮะเก๋า
# 586 ข้าวหน้าเป็ด
# 587 แกงส้มชะอมกุ้ง
# 588 ก๋วยจั๊บ
# 589 ชาบู
# 590 เกี๊ยวทอด
# 591 น้ำพริกไข่ปู
# 592 ฮะเก๋า
# 593 ยำปลาดุกฟู
# 594 ปลากระพงนึ่งมะนาว
# 595 ยำถั่วพลู
# 596 เป็ดพะโล้
# 597 ยำถั่วพลู
# 598 ไอศกรีม
# 599 ข้าวหน้าเป็ด
# 600 ยำสาหร่าย
# 601 สปาเก็ตตี้คาโบนาร่า
# 602 ก๋วยเตี๋ยวคั่วไก่
# 603 สเต็กหมู
# 604 ขาหมูเยอรมัน
# 605 ยำปลาดุกฟู
# 606 เนื้อย่าง
# 607 ไอศกรีม
# 608 ปูนิ่มทอดกระเทียม
# 609 กระเพาะปลา
# 610 honey toast
# 611 เป็ดย่าง
# 612 ไข่กระทะ
# 613 เป็ดย่าง
# 614 ต้มเลือดหมู
# 615 ไอศกรีม
# 616 เนื้อย่าง
# 617 ยำถั่วพลู
# 618 ขนมถ้วย
# 619 สปาเก็ตตี้ขี้เมาทะเล
# 620 น้ำตกหมู
# 621 ไส้อั่ว
# 622 แกงส้มชะอมกุ้ง
# 623 แกงส้มชะอมกุ้ง
# 624 ยำถั่วพลู
# 625 ปูนิ่มทอดกระเทียม
# 626 กระเพาะปลา
# 627 ก๋วยเตี๋ยวเรือ
# 628 ขนมถ้วย
# 629 เป็ดพะโล้
# 630 กระเพาะปลา
# 631 ปูนิ่มทอดกระเทียม
# 632 แกงส้มชะอมกุ้ง
# 633 เป็ดย่าง
# 634 เค้ก
# 635 ไอศกรีม
# 636 ก๋วยเตี๋ยวเรือ
# 637 ไอศกรีม
# 638 ยำปลาดุกฟู
# 639 น้ำพริกไข่ปู
# 640 ไอศกรีม
# 641 ยำปลาดุกฟู
# 642 ไข่ตุ๋น
# 643 ก๋วยเตี๋ยวคั่วไก่
# 644 ขนมปังสังขยา
# 645 ไข่กระทะ
# 646 ไข่กระทะ
# 647 กระเพาะปลา
# 648 ยำถั่วพลู
# 649 ข้าวหมกไก่
# 650 ยำแซลมอน
# 651 เป็ดพะโล้
# 652 ข้าวหมูกรอบ
# 653 ข้าวผัดกระเทียม
# 654 ข้าวหน้าเนื้อ
# 655 หมูมะนาว
# 656 ขาหมูเยอรมัน
# 657 ปูผัดผงกะหรี่
# 658 ปูผัดผงกะหรี่
# 659 เนื้อย่าง
# 660 ข้าวหมกไก่
# 661 สปาเก็ตตี้ขี้เมาทะเล
# 662 สเต็กหมู
# 663 แกงส้มชะอมกุ้ง
# 664 ก๋วยเตี๋ยวเรือ
# 665 ขนมปังปิ้ง
# 666 สปาเก็ตตี้คาโบนาร่า
# 667 น้ำพริกไข่ปู
# 668 เป็ดพะโล้
# 669 ออส่วน
# 670 ขาหมูเยอรมัน
# 671 ข้าวหน้าเนื้อ
# 672 ข้าวหมกไก่
# 673 เป็ดย่าง
# 674 ออส่วน
# 675 ปูม้านึ่ง
# 676 ก๋วยจั๊บ
# 677 ยำสาหร่าย
# 678 บะหมี่แห้ง
# 679 สปาเก็ตตี้ขี้เมาทะเล
# 680 แกงคั่วหอยขม
# 681 ข้าวหมูกรอบ
# 682 เป็ดพะโล้
# 683 สเต็กหมู
# 684 ปูนิ่มทอดกระเทียม
# 685 ทาโกะยากิ
# 686 สปาเก็ตตี้คาโบนาร่า
# 687 ข้าวผัดกระเทียม
# 688 เกี๊ยวทอด
# 689 ปูผัดผงกะหรี่
# 690 ข้าวหมูกรอบ
# 691 ทาโกะยากิ
# 692 ซุปเห็ด
# 693 ขนมปัง
# 694 แกงส้มชะอมกุ้ง
# 695 กระเพาะปลา
# 696 สเต็กหมู
# 697 ปอเปี๊ยะทอด
# 698 สปาเก็ตตี้ขี้เมาทะเล
# 699 เค้ก
# 700 ข้าวหน้าเป็ด
# 701 ขาหมูเยอรมัน
# 702 ยำแซลมอน
# 703 ออส่วน
# 704 ขาหมูเยอรมัน
# 705 ไส้อั่ว
# 706 ยำหมูยอ
# 707 ขนมถ้วย
# 708 ก๋วยจั๊บญวน
# 709 ยำสาหร่าย
# 710 เนื้อย่าง
# 711 ขาหมูเยอรมัน
# 712 ขนมปังปิ้ง
# 713 ยำหมูยอ
# 714 ซุปเห็ด
# 715 ข้าวหน้าเป็ด
# 716 แกงคั่วหอยขม
# 717 หมูมะนาว
# 718 สเต็กหมู
# 719 ยำถั่วพลู
# 720 ไส้อั่ว
# 721 ไข่ตุ๋น
# 722 ออส่วน
# 723 ก๋วยเตี๋ยวเรือ
# 724 ต้มเลือดหมู
# 725 ไข่ตุ๋น
# 726 ข้าวหมูกรอบ
# 727 ข้าวผัดกระเทียม
# 728 ก๋วยจั๊บ
# 729 กระเพาะปลา
# 730 ก๋วยจั๊บ
# 731 ก๋วยเตี๋ยวคั่วไก่
# 732 ขนมปังปิ้ง
# 733 กระเพาะปลา
# 734 เกี๊ยวทอด
# 735 น้ำตกหมู
# 736 ปลากระพงนึ่งมะนาว
# 737 สเต็กหมู
# 738 ไข่ตุ๋น
# 739 ปูผัดผงกะหรี่
# 740 หมูมะนาว
# 741 หมูมะนาว
# 742 ข้าวหมกไก่
# 743 ข้าวหน้าเนื้อ
# 744 ข้าวผัดกระเทียม
# 745 ต้มเลือดหมู
# 746 honey toast
# 747 ปูม้านึ่ง
# 748 ขนมถ้วย
# 749 ขนมปังปิ้ง
# 750 ไข่ตุ๋น
# 751 สปาเก็ตตี้ขี้เมาทะเล
# 752 กระเพาะปลา
# 753 ไอศกรีม
# 754 ยำสาหร่าย
# 755 แกงส้มชะอมกุ้ง
# 756 ขนมปังปิ้ง
# 757 ขนมปังปิ้ง
# 758 ยำสาหร่าย
# 759 ขาหมูเยอรมัน
# 760 ข้าวหมูกรอบ
# 761 ยำสาหร่าย
# 762 ขนมปัง
# 763 สปาเก็ตตี้ขี้เมาทะเล
# 764 ไส้อั่ว
# 765 สเต็กหมู
# 766 เกี๊ยวทอด
# 767 ออส่วน
# 768 ยำถั่วพลู
# 769 ขนมปัง
# 770 สปาเก็ตตี้ขี้เมาทะเล
# 771 หมูมะนาว
# 772 ข้าวหน้าเนื้อ
# 773 ยำแซลมอน
# 774 เนื้อย่าง
# 775 เป็ดย่าง
# 776 ขาหมูเยอรมัน
# 777 ข้าวหมูกรอบ
# 778 ไส้อั่ว
# 779 หมูมะนาว
# 780 ขาหมูเยอรมัน
# 781 บะหมี่แห้ง
# 782 กระเพาะปลา
# 783 ซุปเห็ด
# 784 ยำถั่วพลู
# 785 ข้าวหมกไก่
# 786 น้ำตกหมู
# 787 ก๋วยจั๊บ
# 788 honey toast
# 789 ไส้อั่ว
# 790 ไข่กระทะ
# 791 ซุปเห็ด
# 792 เนื้อย่าง
# 793 ต้มเลือดหมู
# 794 ข้าวหน้าเป็ด
# 795 กระเพาะปลา
# 796 ปอเปี๊ยะทอด
# 797 ปูม้านึ่ง
# 798 สเต็กหมู
# 799 ก๋วยเตี๋ยวคั่วไก่
# 800 ยำหมูยอ
# 801 ยำปลาดุกฟู
# 802 สเต็กหมู
# 803 ยำปลาดุกฟู
# 804 ขาหมูเยอรมัน
# 805 เค้ก
# 806 ปลากระพงนึ่งมะนาว
# 807 ยำหมูยอ
# 808 honey toast
# 809 สเต็กหมู
# 810 ชาบู
# 811 น้ำพริกไข่ปู
# 812 แกงส้มชะอมกุ้ง
# 813 honey toast
# 814 ปลากระพงนึ่งมะนาว
# 815 กระเพาะปลา
# 816 สปาเก็ตตี้คาโบนาร่า
# 817 เกี๊ยวทอด
# 818 แกงคั่วหอยขม
# 819 น้ำตกหมู
# 820 ทาโกะยากิ
# 821 สปาเก็ตตี้ขี้เมาทะเล
# 822 ยำหมูยอ
# 823 ปลากระพงนึ่งมะนาว
# 824 ไอศกรีม
# 825 ขนมถ้วย
# 826 กระเพาะปลา
# 827 ปอเปี๊ยะทอด
# 828 น้ำพริกไข่ปู
# 829 ปอเปี๊ยะทอด
# 830 กระเพาะปลา
# 831 ปูม้านึ่ง
# 832 ทาโกะยากิ
# 833 ขนมปังสังขยา
# 834 ยำปลาดุกฟู
# 835 เป็ดย่าง
# 836 น้ำตกหมู
# 837 honey toast
# 838 ไส้อั่ว
# 839 ปลากระพงนึ่งมะนาว
# 840 ข้าวหมกไก่
# 841 ก๋วยเตี๋ยวคั่วไก่
# 842 ขนมถ้วย
# 843 เกี๊ยวทอด
# 844 ออส่วน
# 845 ฮะเก๋า
# 846 ปอเปี๊ยะทอด
# 847 ซุปเห็ด
# 848 ยำสาหร่าย
# 849 หมูมะนาว
# 850 ข้าวหมกไก่
# 851 น้ำตกหมู
# 852 ขาหมูเยอรมัน
# 853 ไส้อั่ว
# 854 ซุปเห็ด
# 855 เป็ดพะโล้
# 856 กระเพาะปลา
# 857 ขนมปังปิ้ง
# 858 ข้าวหมกไก่
# 859 ปอเปี๊ยะทอด
# 860 แกงส้มชะอมกุ้ง
# 861 ชาบู
# 862 ยำถั่วพลู
# 863 ไข่กระทะ
# 864 หมูมะนาว
# 865 ต้มเลือดหมู
# 866 เค้ก
# 867 ไอศกรีม
# 868 สเต็กหมู
# 869 ออส่วน
# 870 ก๋วยเตี๋ยวคั่วไก่
# 871 ไข่กระทะ
# 872 ก๋วยเตี๋ยวคั่วไก่
# 873 ไข่กระทะ
# 874 หมูมะนาว
# 875 ก๋วยจั๊บญวน
# 876 ข้าวหน้าเนื้อ
# 877 ข้าวหมูกรอบ
# 878 ข้าวหน้าเนื้อ
# 879 เค้ก
# 880 ก๋วยจั๊บ
# 881 ฮะเก๋า
# 882 น้ำพริกไข่ปู
# 883 เป็ดย่าง
# 884 ปลากระพงนึ่งมะนาว
# 885 ยำปลาดุกฟู
# 886 ไข่ตุ๋น
# 887 ขนมปังสังขยา
# 888 ออส่วน
# 889 ปูผัดผงกะหรี่
# 890 ปูม้านึ่ง
# 891 ขาหมูเยอรมัน
# 892 กระเพาะปลา
# 893 ปลากระพงนึ่งมะนาว
# 894 สเต็กหมู
# 895 สเต็กหมู
# 896 ชาบู
# 897 honey toast
# 898 ข้าวหน้าเนื้อ
# 899 ข้าวหมกไก่
# 900 แกงส้มชะอมกุ้ง
# 901 ฮะเก๋า
# 902 ปูม้านึ่ง
# 903 ออส่วน
# 904 แกงส้มชะอมกุ้ง
# 905 ข้าวหน้าเนื้อ
# 906 ข้าวหมกไก่
# 907 เค้ก
# 908 ยำสาหร่าย
# 909 ข้าวหน้าเนื้อ
# 910 ต้มเลือดหมู
# 911 ข้าวหน้าเป็ด
# 912 ขนมถ้วย
# 913 ข้าวหมูกรอบ
# 914 สปาเก็ตตี้ขี้เมาทะเล
# 915 ชาบู
# 916 สปาเก็ตตี้คาโบนาร่า
# 917 ข้าวหน้าเนื้อ
# 918 ก๋วยเตี๋ยวเรือ
# 919 เป็ดพะโล้
# 920 น้ำตกหมู
# 921 บะหมี่แห้ง
# 922 ข้าวหมกไก่
# 923 ออส่วน
# 924 สปาเก็ตตี้ขี้เมาทะเล
# 925 หมูมะนาว
# 926 ข้าวหน้าเป็ด
# 927 ขนมปังสังขยา
# 928 ข้าวหมกไก่
# 929 น้ำพริกไข่ปู
# 930 ยำหมูยอ
# 931 เนื้อย่าง
# 932 honey toast
# 933 ก๋วยเตี๋ยวเรือ
# 934 เนื้อย่าง
# 935 เนื้อย่าง
# 936 เนื้อย่าง
# 937 บะหมี่แห้ง
# 938 แกงส้มชะอมกุ้ง
# 939 ปูนิ่มทอดกระเทียม
# 940 ยำสาหร่าย
# 941 ข้าวหน้าเนื้อ
# 942 เนื้อย่าง
# 943 ฮะเก๋า
# 944 หมูมะนาว
# 945 ยำสาหร่าย
# 946 ทาโกะยากิ
# 947 ปูม้านึ่ง
# 948 ก๋วยจั๊บ
# 949 ปูนิ่มทอดกระเทียม
# 950 เกี๊ยวทอด
# 951 ชาบู
# 952 หมูมะนาว
# 953 น้ำตกหมู
# 954 ออส่วน
# 955 ชาบู
# 956 แกงคั่วหอยขม
# 957 เป็ดย่าง
# 958 เป็ดพะโล้
# 959 ต้มเลือดหมู
# 960 ปูนิ่มทอดกระเทียม
# 961 ก๋วยเตี๋ยวเรือ
# 962 ไข่ตุ๋น
# 963 ปูผัดผงกะหรี่
# 964 ชาบู
# 965 ปอเปี๊ยะทอด
# 966 honey toast
# 967 หมูมะนาว
# 968 ปอเปี๊ยะทอด
# 969 ปลากระพงนึ่งมะนาว
# 970 ข้าวหน้าเป็ด
# 971 สปาเก็ตตี้คาโบนาร่า
# 972 ก๋วยเตี๋ยวคั่วไก่
# 973 ปูม้านึ่ง
# 974 ข้าวหน้าเป็ด
# 975 ซุปเห็ด
# 976 ข้าวหน้าเป็ด
# 977 บะหมี่แห้ง
# 978 เกี๊ยวทอด
# 979 เป็ดย่าง
# 980 เนื้อย่าง
# 981 ยำหมูยอ
# 982 ก๋วยเตี๋ยวเรือ
# 983 ยำถั่วพลู
# 984 ขนมปังปิ้ง
# 985 แกงส้มชะอมกุ้ง
# 986 แกงคั่วหอยขม
# 987 ชาบู
# 988 เป็ดย่าง
# 989 ข้าวหมกไก่
# 990 ก๋วยเตี๋ยวคั่วไก่
# 991 เนื้อย่าง
# 992 honey toast
# 993 ไส้อั่ว
# 994 ทาโกะยากิ
# 995 ข้าวผัดกระเทียม
# 996 ยำแซลมอน
# 997 ออส่วน
# 998 ปอเปี๊ยะทอด
# 999 ขนมปังสังขยา
# 1000 น้ำตกหมู
# 1001 ก๋วยจั๊บ
# 1002 ปูผัดผงกะหรี่
# 1003 ยำสาหร่าย
# 1004 ก๋วยเตี๋ยวคั่วไก่
# 1005 ข้าวผัดกระเทียม
# 1006 ข้าวหมูกรอบ
# 1007 ก๋วยเตี๋ยวคั่วไก่
# 1008 ปูผัดผงกะหรี่
# 1009 ขนมถ้วย
# 1010 ยำแซลมอน
# 1011 ก๋วยเตี๋ยวคั่วไก่
# 1012 ข้าวผัดกระเทียม
# 1013 ไส้อั่ว
# 1014 ข้าวหมกไก่
# 1015 เป็ดพะโล้
# 1016 เป็ดย่าง
# 1017 แกงคั่วหอยขม
# 1018 ต้มเลือดหมู
# 1019 ชาบู
# 1020 ไข่กระทะ
# 1021 ปูนิ่มทอดกระเทียม
# 1022 ปลากระพงนึ่งมะนาว
# 1023 เป็ดพะโล้
# 1024 ข้าวหน้าเนื้อ
# 1025 น้ำตกหมู
# 1026 ฮะเก๋า
# 1027 ขนมปัง
# 1028 ขนมถ้วย
# 1029 เกี๊ยวทอด
# 1030 สปาเก็ตตี้ขี้เมาทะเล
# 1031 ขนมปังปิ้ง
# 1032 เนื้อย่าง
# 1033 แกงคั่วหอยขม
# 1034 ไอศกรีม
# 1035 ต้มเลือดหมู
# 1036 ฮะเก๋า
# 1037 ปูม้านึ่ง
# 1038 ปลากระพงนึ่งมะนาว
# 1039 ขาหมูเยอรมัน
# 1040 กระเพาะปลา
# 1041 กระเพาะปลา
# 1042 ปอเปี๊ยะทอด
# 1043 ยำถั่วพลู
# 1044 ยำสาหร่าย
# 1045 สปาเก็ตตี้คาโบนาร่า
# 1046 ฮะเก๋า
# 1047 ต้มเลือดหมู
# 1048 ยำหมูยอ
# 1049 น้ำพริกไข่ปู
# 1050 ข้าวหมกไก่
# 1051 ซุปเห็ด
# 1052 ซุปเห็ด
# 1053 ไข่ตุ๋น
# 1054 ยำแซลมอน
# 1055 ขนมปังสังขยา
# 1056 ขนมปัง
# 1057 สเต็กหมู
# 1058 เค้ก
# 1059 ยำแซลมอน
# 1060 สปาเก็ตตี้ขี้เมาทะเล
# 1061 ข้าวหมกไก่
# 1062 ขนมปังปิ้ง
# 1063 ไข่ตุ๋น
# 1064 ขนมถ้วย
# 1065 กระเพาะปลา
# 1066 ขนมปังปิ้ง
# 1067 บะหมี่แห้ง
# 1068 ปูม้านึ่ง
# 1069 ขนมปังสังขยา
# 1070 ทาโกะยากิ
# 1071 ฮะเก๋า
# 1072 เป็ดพะโล้
# 1073 ยำหมูยอ
# 1074 ข้าวหมกไก่
# 1075 แกงส้มชะอมกุ้ง
# 1076 แกงส้มชะอมกุ้ง
# 1077 เกี๊ยวทอด
# 1078 ปลากระพงนึ่งมะนาว
# 1079 สเต็กหมู
# 1080 ปูผัดผงกะหรี่
# 1081 ยำหมูยอ
# 1082 ยำถั่วพลู
# 1083 ข้าวหน้าเป็ด
# 1084 ปลากระพงนึ่งมะนาว
# 1085 ก๋วยเตี๋ยวคั่วไก่
# 1086 ก๋วยเตี๋ยวคั่วไก่
# 1087 ชาบู
# 1088 ชาบู
# 1089 ปูนิ่มทอดกระเทียม
# 1090 ข้าวหมกไก่
# 1091 ก๋วยจั๊บ
# 1092 ยำปลาดุกฟู
# 1093 เค้ก
# 1094 เป็ดย่าง
# 1095 ปูนิ่มทอดกระเทียม
# 1096 ขนมปังปิ้ง
# 1097 ข้าวหน้าเนื้อ
# 1098 ก๋วยเตี๋ยวคั่วไก่
# 1099 ขนมปัง
# 1100 ขนมปัง
# 1101 สปาเก็ตตี้ขี้เมาทะเล
# 1102 บะหมี่แห้ง
# 1103 ขาหมูเยอรมัน
# 1104 ข้าวหน้าเป็ด
# 1105 เป็ดพะโล้
# 1106 ข้าวหมูกรอบ
# 1107 ไข่กระทะ
# 1108 ข้าวหน้าเนื้อ
# 1109 ขนมปังปิ้ง
# 1110 ไอศกรีม
# 1111 บะหมี่แห้ง
# 1112 กระเพาะปลา
# 1113 บะหมี่แห้ง
# 1114 แกงส้มชะอมกุ้ง
# 1115 ก๋วยจั๊บ
# 1116 ขนมปังปิ้ง
# 1117 ไส้อั่ว
# 1118 ยำหมูยอ
# 1119 ออส่วน
# 1120 ขนมปังปิ้ง
# 1121 ข้าวหน้าเป็ด
# 1122 ข้าวหมกไก่
# 1123 เกี๊ยวทอด
# 1124 แกงคั่วหอยขม
# 1125 เป็ดย่าง
# 1126 ยำปลาดุกฟู
# 1127 น้ำตกหมู
# 1128 ก๋วยเตี๋ยวคั่วไก่
# 1129 ก๋วยเตี๋ยวเรือ
# 1130 ไข่กระทะ
# 1131 ข้าวหน้าเนื้อ
# 1132 ไอศกรีม
# 1133 ออส่วน
# 1134 ต้มเลือดหมู
# 1135 honey toast
# 1136 ข้าวผัดกระเทียม
# 1137 เนื้อย่าง
# 1138 ยำแซลมอน
# 1139 แกงส้มชะอมกุ้ง
# 1140 เนื้อย่าง
# 1141 ข้าวหมูกรอบ
# 1142 ขนมปัง
# 1143 ปอเปี๊ยะทอด
# 1144 ก๋วยจั๊บญวน
# 1145 ขนมถ้วย
# 1146 ข้าวหน้าเป็ด
# 1147 ปูนิ่มทอดกระเทียม
# 1148 เนื้อย่าง
# 1149 ไอศกรีม
# 1150 สปาเก็ตตี้ขี้เมาทะเล
# 1151 ขนมถ้วย
# 1152 ยำถั่วพลู
# 1153 บะหมี่แห้ง
# 1154 ปูผัดผงกะหรี่
# 1155 ก๋วยจั๊บ
# 1156 ข้าวหน้าเนื้อ
# 1157 ก๋วยเตี๋ยวคั่วไก่
# 1158 สเต็กหมู
# 1159 ปอเปี๊ยะทอด
# 1160 ยำปลาดุกฟู
# 1161 ไข่ตุ๋น
# 1162 ปูนิ่มทอดกระเทียม
# 1163 ขนมปังปิ้ง
# 1164 ปูผัดผงกะหรี่
# 1165 ขาหมูเยอรมัน
# 1166 เป็ดย่าง
# 1167 ข้าวหน้าเป็ด
# 1168 สเต็กหมู
# 1169 ปอเปี๊ยะทอด
# 1170 เนื้อย่าง
# 1171 ยำถั่วพลู
# 1172 บะหมี่แห้ง
# 1173 ขาหมูเยอรมัน
# 1174 สเต็กหมู
# 1175 ก๋วยจั๊บญวน
# 1176 ออส่วน
# 1177 ออส่วน
# 1178 สปาเก็ตตี้คาโบนาร่า
# 1179 ขนมปังสังขยา
# 1180 ชาบู
# 1181 ยำปลาดุกฟู
# 1182 น้ำพริกไข่ปู
# 1183 เป็ดพะโล้
# 1184 ยำถั่วพลู
# 1185 ปอเปี๊ยะทอด
# 1186 ยำปลาดุกฟู
# 1187 แกงส้มชะอมกุ้ง
# 1188 ปูม้านึ่ง
# 1189 เกี๊ยวทอด
# 1190 ปูผัดผงกะหรี่
# 1191 ออส่วน
# 1192 ขนมถ้วย
# 1193 ปูผัดผงกะหรี่
# 1194 ปูม้านึ่ง
# 1195 เป็ดพะโล้
# 1196 เป็ดพะโล้
# 1197 ก๋วยจั๊บญวน
# 1198 ยำสาหร่าย
# 1199 ขนมปังสังขยา
# 1200 เกี๊ยวทอด
# 1201 บะหมี่แห้ง
# 1202 ต้มเลือดหมู
# 1203 น้ำตกหมู
# 1204 เป็ดพะโล้
# 1205 กระเพาะปลา
# 1206 ขนมปัง
# 1207 ข้าวหน้าเป็ด
# 1208 ก๋วยเตี๋ยวคั่วไก่
# 1209 ออส่วน
# 1210 ขาหมูเยอรมัน
# 1211 หมูมะนาว
# 1212 สปาเก็ตตี้ขี้เมาทะเล
# 1213 ข้าวหน้าเนื้อ
# 1214 ก๋วยจั๊บ
# 1215 ขนมปังปิ้ง
# 1216 เกี๊ยวทอด
# 1217 สปาเก็ตตี้คาโบนาร่า
# 1218 ก๋วยเตี๋ยวคั่วไก่
# 1219 แกงส้มชะอมกุ้ง
# 1220 ข้าวหมูกรอบ
# 1221 ฮะเก๋า
# 1222 ปูม้านึ่ง
# 1223 เป็ดย่าง
# 1224 ยำหมูยอ
# 1225 เค้ก
# 1226 น้ำตกหมู
# 1227 น้ำพริกไข่ปู
# 1228 ยำถั่วพลู
# 1229 ยำแซลมอน
# 1230 ซุปเห็ด
# 1231 ยำแซลมอน
# 1232 ยำสาหร่าย
# 1233 น้ำตกหมู
# 1234 ปอเปี๊ยะทอด
# 1235 ข้าวหมูกรอบ
# 1236 ข้าวผัดกระเทียม
# 1237 น้ำพริกไข่ปู
# 1238 น้ำพริกไข่ปู
# 1239 เป็ดพะโล้
# 1240 ออส่วน
# 1241 ขนมปัง
# 1242 ข้าวหน้าเนื้อ
# 1243 สปาเก็ตตี้คาโบนาร่า
# 1244 ข้าวหน้าเป็ด
# 1245 ปอเปี๊ยะทอด
# 1246 ข้าวหมูกรอบ
# 1247 ไข่ตุ๋น
# 1248 บะหมี่แห้ง
# 1249 ขาหมูเยอรมัน
# 1250 ปูม้านึ่ง
# 1251 กระเพาะปลา
# 1252 ซุปเห็ด
# 1253 สเต็กหมู
# 1254 ทาโกะยากิ
# 1255 ปูม้านึ่ง
# 1256 honey toast
# 1257 ไส้อั่ว
# 1258 ปูนิ่มทอดกระเทียม
# 1259 เนื้อย่าง
# 1260 บะหมี่แห้ง
# 1261 เค้ก
# 1262 ปูผัดผงกะหรี่
# 1263 เป็ดย่าง
# 1264 สเต็กหมู
# 1265 ขนมถ้วย
# 1266 สปาเก็ตตี้ขี้เมาทะเล
# 1267 ก๋วยเตี๋ยวเรือ
# 1268 หมูมะนาว
# 1269 ข้าวหน้าเนื้อ
# 1270 ทาโกะยากิ
# 1271 ยำหมูยอ
# 1272 ชาบู
# 1273 เนื้อย่าง
# 1274 ก๋วยเตี๋ยวคั่วไก่
# 1275 honey toast
# 1276 ต้มเลือดหมู
# 1277 ปูนิ่มทอดกระเทียม
# 1278 ข้าวหมูกรอบ
# 1279 ยำปลาดุกฟู
# 1280 ไส้อั่ว
# 1281 ยำสาหร่าย
# 1282 ข้าวหน้าเนื้อ
# 1283 ยำถั่วพลู
# 1284 ปูผัดผงกะหรี่
# 1285 ข้าวหมกไก่
# 1286 ขนมปังปิ้ง
# 1287 ต้มเลือดหมู
# 1288 ก๋วยจั๊บญวน
# 1289 ก๋วยเตี๋ยวคั่วไก่
# 1290 ขนมปังปิ้ง
# 1291 เกี๊ยวทอด
# 1292 ข้าวหมกไก่
# 1293 ขนมถ้วย
# 1294 สเต็กหมู
# 1295 น้ำพริกไข่ปู
# 1296 ข้าวหน้าเป็ด
# 1297 กระเพาะปลา
# 1298 ยำถั่วพลู
# 1299 ข้าวผัดกระเทียม
# 1300 ชาบู
# 1301 เกี๊ยวทอด
# 1302 ยำหมูยอ
# 1303 ยำสาหร่าย
# 1304 ข้าวหน้าเป็ด
# 1305 เกี๊ยวทอด
# 1306 ทาโกะยากิ
# 1307 น้ำพริกไข่ปู
# 1308 ไข่ตุ๋น
# 1309 ข้าวหน้าเป็ด
# 1310 ข้าวผัดกระเทียม
# 1311 ปูม้านึ่ง
# 1312 ข้าวหมกไก่
# 1313 เกี๊ยวทอด
# 1314 ไส้อั่ว
# 1315 ยำหมูยอ
# 1316 แกงคั่วหอยขม
# 1317 ก๋วยเตี๋ยวคั่วไก่
# 1318 ข้าวหน้าเป็ด
# 1319 ยำแซลมอน
# 1320 ขนมถ้วย
# 1321 เป็ดพะโล้
# 1322 บะหมี่แห้ง
# 1323 เป็ดย่าง
# 1324 ไข่ตุ๋น
# 1325 น้ำพริกไข่ปู
# 1326 ปูนิ่มทอดกระเทียม
# 1327 ก๋วยเตี๋ยวคั่วไก่
# 1328 เนื้อย่าง
# 1329 ปูผัดผงกะหรี่
# 1330 ก๋วยจั๊บ
# 1331 ขนมปังปิ้ง
# 1332 ก๋วยเตี๋ยวเรือ
# 1333 เกี๊ยวทอด
# 1334 ขนมปังปิ้ง
# 1335 ขนมปังสังขยา
# 1336 บะหมี่แห้ง
# 1337 เกี๊ยวทอด
# 1338 ขาหมูเยอรมัน
# 1339 ข้าวหมกไก่
# 1340 ขนมถ้วย
# 1341 สปาเก็ตตี้ขี้เมาทะเล
# 1342 เกี๊ยวทอด
# 1343 ต้มเลือดหมู
# 1344 ขนมปัง
# 1345 ยำสาหร่าย
# 1346 กระเพาะปลา
# 1347 บะหมี่แห้ง
# 1348 ข้าวหมูกรอบ
# 1349 แกงส้มชะอมกุ้ง
# 1350 ปูม้านึ่ง
# 1351 ปอเปี๊ยะทอด
# 1352 หมูมะนาว
# 1353 ยำถั่วพลู
# 1354 ซุปเห็ด
# 1355 ข้าวหมูกรอบ
# 1356 ข้าวหมูกรอบ
# 1357 สปาเก็ตตี้คาโบนาร่า
# 1358 ปูนิ่มทอดกระเทียม
# 1359 ปอเปี๊ยะทอด
# 1360 ต้มเลือดหมู
# 1361 ยำปลาดุกฟู
# 1362 ยำสาหร่าย
# 1363 สปาเก็ตตี้ขี้เมาทะเล
# 1364 เป็ดพะโล้
# 1365 honey toast
# 1366 ออส่วน
# 1367 ทาโกะยากิ
# 1368 ขนมปังปิ้ง
# 1369 ไอศกรีม
# 1370 ก๋วยเตี๋ยวคั่วไก่
# 1371 ปูผัดผงกะหรี่
# 1372 ฮะเก๋า
# 1373 ข้าวหน้าเนื้อ
# 1374 ปูนิ่มทอดกระเทียม
# 1375 บะหมี่แห้ง
# 1376 ทาโกะยากิ
# 1377 ยำสาหร่าย
# 1378 ไข่ตุ๋น
# 1379 ขนมปังปิ้ง
# 1380 ไข่ตุ๋น
# 1381 ยำหมูยอ
# 1382 สปาเก็ตตี้ขี้เมาทะเล
# 1383 กระเพาะปลา
# 1384 ขนมถ้วย
# 1385 ขนมถ้วย
# 1386 ปลากระพงนึ่งมะนาว
# 1387 ยำปลาดุกฟู
# 1388 เกี๊ยวทอด
# 1389 ไข่ตุ๋น
# 1390 ทาโกะยากิ
# 1391 ข้าวหน้าเป็ด
# 1392 แกงส้มชะอมกุ้ง
# 1393 ไอศกรีม
# 1394 ขนมปังปิ้ง
# 1395 ขนมปังสังขยา
# 1396 ขนมปังสังขยา
# 1397 ขนมปังปิ้ง
# 1398 ข้าวหมกไก่
# 1399 ยำหมูยอ
# 1400 เป็ดย่าง
# 1401 ยำหมูยอ
# 1402 ขนมถ้วย
# 1403 ขนมถ้วย
# 1404 เป็ดย่าง
# 1405 ปอเปี๊ยะทอด
# 1406 ขาหมูเยอรมัน
# 1407 ขาหมูเยอรมัน
# 1408 น้ำตกหมู
# 1409 ไอศกรีม
# 1410 ก๋วยเตี๋ยวคั่วไก่
# 1411 ปูม้านึ่ง
# 1412 ไข่กระทะ
# 1413 ฮะเก๋า
# 1414 ไข่ตุ๋น
# 1415 น้ำตกหมู
# 1416 ขนมปังสังขยา
# 1417 ข้าวผัดกระเทียม
# 1418 ไข่กระทะ
# 1419 ซุปเห็ด
# 1420 เนื้อย่าง
# 1421 ไข่กระทะ
# 1422 ข้าวผัดกระเทียม
# 1423 ไอศกรีม
# 1424 ชาบู
# 1425 ขนมปังสังขยา
# 1426 ปอเปี๊ยะทอด
# 1427 ปลากระพงนึ่งมะนาว
# 1428 หมูมะนาว
# 1429 กระเพาะปลา
# 1430 บะหมี่แห้ง
# 1431 เกี๊ยวทอด
# 1432 ขนมปัง
# 1433 สปาเก็ตตี้คาโบนาร่า
# 1434 แกงคั่วหอยขม
# 1435 ยำหมูยอ
# 1436 ก๋วยเตี๋ยวคั่วไก่
# 1437 ออส่วน
# 1438 ขนมถ้วย
# 1439 น้ำตกหมู
# 1440 แกงคั่วหอยขม
# 1441 เกี๊ยวทอด
# 1442 ขนมถ้วย
# 1443 ยำสาหร่าย
# 1444 ก๋วยเตี๋ยวเรือ
# 1445 เค้ก
# 1446 น้ำพริกไข่ปู
# 1447 กระเพาะปลา
# 1448 ไข่ตุ๋น
# 1449 ซุปเห็ด
# 1450 ยำถั่วพลู
# 1451 แกงคั่วหอยขม
# 1452 น้ำตกหมู
# 1453 ชาบู
# 1454 ก๋วยเตี๋ยวเรือ
# 1455 ข้าวผัดกระเทียม
# 1456 ก๋วยจั๊บญวน
# 1457 ขนมปังปิ้ง
# 1458 เป็ดพะโล้
# 1459 ชาบู
# 1460 honey toast
# 1461 ไอศกรีม
# 1462 เกี๊ยวทอด
# 1463 ยำสาหร่าย
# 1464 ข้าวผัดกระเทียม
# 1465 ก๋วยจั๊บญวน
# 1466 บะหมี่แห้ง
# 1467 ข้าวหมูกรอบ
# 1468 เป็ดพะโล้
# 1469 ขนมถ้วย
# 1470 ก๋วยจั๊บ
# 1471 ทาโกะยากิ
# 1472 ขนมถ้วย
# 1473 ข้าวหมกไก่
# 1474 สปาเก็ตตี้คาโบนาร่า
# 1475 ไส้อั่ว
# 1476 honey toast
# 1477 honey toast
# 1478 ยำแซลมอน
# 1479 ปลากระพงนึ่งมะนาว
# 1480 ต้มเลือดหมู
# 1481 เค้ก
# 1482 ขนมปังปิ้ง
# 1483 แกงส้มชะอมกุ้ง
# 1484 สปาเก็ตตี้ขี้เมาทะเล
# 1485 ปูผัดผงกะหรี่
# 1486 สเต็กหมู
# 1487 ขนมปัง
# 1488 สปาเก็ตตี้คาโบนาร่า
# 1489 ข้าวผัดกระเทียม
# 1490 ออส่วน
# 1491 ขาหมูเยอรมัน
# 1492 ปูม้านึ่ง
# 1493 เค้ก
# 1494 ซุปเห็ด
# 1495 ข้าวผัดกระเทียม
# 1496 ออส่วน
# 1497 ขาหมูเยอรมัน
# 1498 ปูผัดผงกะหรี่
# 1499 ข้าวหมูกรอบ
# 1500 น้ำพริกไข่ปู
# 1501 ก๋วยจั๊บ
# 1502 ขาหมูเยอรมัน
# 1503 ข้าวผัดกระเทียม
# 1504 เป็ดย่าง
# 1505 ก๋วยจั๊บ
# 1506 น้ำพริกไข่ปู
# 1507 ข้าวหมูกรอบ
# 1508 ไอศกรีม
# 1509 ทาโกะยากิ
# 1510 ยำแซลมอน
# 1511 หมูมะนาว
# 1512 ไข่กระทะ
# 1513 น้ำตกหมู
# 1514 ไข่กระทะ
# 1515 ยำถั่วพลู
# 1516 ขนมปังสังขยา
# 1517 แกงคั่วหอยขม
# 1518 ขนมปังสังขยา
# 1519 กระเพาะปลา
# 1520 ยำสาหร่าย
# 1521 ยำถั่วพลู
# 1522 สปาเก็ตตี้คาโบนาร่า
# 1523 ก๋วยเตี๋ยวเรือ
# 1524 กระเพาะปลา
# 1525 ขาหมูเยอรมัน
# 1526 ข้าวผัดกระเทียม
# 1527 ยำแซลมอน
# 1528 ไข่กระทะ
# 1529 ข้าวผัดกระเทียม
# 1530 ข้าวหมูกรอบ
# 1531 ขนมถ้วย
# 1532 เนื้อย่าง
# 1533 ปอเปี๊ยะทอด
# 1534 กระเพาะปลา
# 1535 เป็ดย่าง
# 1536 ปลากระพงนึ่งมะนาว
# 1537 ออส่วน
# 1538 ไส้อั่ว
# 1539 ก๋วยจั๊บญวน
# 1540 ต้มเลือดหมู
# 1541 ไส้อั่ว
# 1542 เป็ดพะโล้
# 1543 เค้ก
# 1544 ไข่ตุ๋น
# 1545 ต้มเลือดหมู
# 1546 ต้มเลือดหมู
# 1547 น้ำพริกไข่ปู
# 1548 ขนมปังปิ้ง
# 1549 เป็ดย่าง
# 1550 ฮะเก๋า
# 1551 ข้าวผัดกระเทียม
# 1552 ก๋วยเตี๋ยวคั่วไก่
# 1553 ไข่ตุ๋น
# 1554 ไข่ตุ๋น
# 1555 น้ำตกหมู
# 1556 ยำถั่วพลู
# 1557 ยำหมูยอ
# 1558 ยำสาหร่าย
# 1559 ออส่วน
# 1560 น้ำตกหมู
# 1561 ปลากระพงนึ่งมะนาว
# 1562 กระเพาะปลา
# 1563 เกี๊ยวทอด
# 1564 สปาเก็ตตี้คาโบนาร่า
# 1565 ก๋วยจั๊บญวน
# 1566 ยำสาหร่าย
# 1567 บะหมี่แห้ง
# 1568 ข้าวหมูกรอบ
# 1569 ยำปลาดุกฟู
# 1570 ขาหมูเยอรมัน
# 1571 สปาเก็ตตี้ขี้เมาทะเล
# 1572 สปาเก็ตตี้คาโบนาร่า
# 1573 ก๋วยเตี๋ยวเรือ
# 1574 ก๋วยจั๊บญวน
# 1575 ปูม้านึ่ง
# 1576 ขนมปังสังขยา
# 1577 ยำแซลมอน
# 1578 ชาบู
# 1579 แกงส้มชะอมกุ้ง
# 1580 สเต็กหมู
# 1581 สเต็กหมู
# 1582 บะหมี่แห้ง
# 1583 ขนมปังสังขยา
# 1584 ขนมปังปิ้ง
# 1585 ยำปลาดุกฟู
# 1586 ก๋วยเตี๋ยวคั่วไก่
# 1587 ปลากระพงนึ่งมะนาว
# 1588 ปูม้านึ่ง
# 1589 ชาบู
# 1590 สปาเก็ตตี้คาโบนาร่า
# 1591 น้ำพริกไข่ปู
# 1592 บะหมี่แห้ง
# 1593 ซุปเห็ด
# 1594 เกี๊ยวทอด
# 1595 ข้าวหมกไก่
# 1596 สปาเก็ตตี้คาโบนาร่า
# 1597 ข้าวผัดกระเทียม
# 1598 ขนมปังปิ้ง
# 1599 หมูมะนาว
# 1600 แกงส้มชะอมกุ้ง
# 1601 หมูมะนาว
# 1602 honey toast
# 1603 น้ำพริกไข่ปู
# 1604 ก๋วยจั๊บ
# 1605 เป็ดพะโล้
# 1606 ขาหมูเยอรมัน
# 1607 ไข่กระทะ
# 1608 ปูนิ่มทอดกระเทียม
# 1609 ซุปเห็ด
# 1610 ก๋วยจั๊บ
# 1611 เค้ก
# 1612 ก๋วยจั๊บ
# 1613 เกี๊ยวทอด
# 1614 ออส่วน
# 1615 ก๋วยจั๊บ
# 1616 ก๋วยจั๊บญวน
# 1617 ปูนิ่มทอดกระเทียม
# 1618 ข้าวผัดกระเทียม
# 1619 น้ำพริกไข่ปู
# 1620 ไข่ตุ๋น
# 1621 ข้าวหน้าเป็ด
# 1622 บะหมี่แห้ง
# 1623 ข้าวหน้าเป็ด
# 1624 สเต็กหมู
# 1625 ขนมปัง
# 1626 ยำสาหร่าย
# 1627 ขนมปังปิ้ง
# 1628 ข้าวหน้าเป็ด
# 1629 ฮะเก๋า
# 1630 ข้าวหน้าเนื้อ
# 1631 แกงส้มชะอมกุ้ง
# 1632 สเต็กหมู
# 1633 ปลากระพงนึ่งมะนาว
# 1634 น้ำพริกไข่ปู
# 1635 ขนมปังสังขยา
# 1636 ยำปลาดุกฟู
# 1637 ออส่วน
# 1638 ต้มเลือดหมู
# 1639 หมูมะนาว
# 1640 ยำสาหร่าย
# 1641 สปาเก็ตตี้ขี้เมาทะเล
# 1642 ฮะเก๋า
# 1643 ก๋วยจั๊บญวน
# 1644 ยำแซลมอน
# 1645 กระเพาะปลา
# 1646 ขนมถ้วย
# 1647 ข้าวหน้าเป็ด
# 1648 ไข่กระทะ
# 1649 ออส่วน
# 1650 หมูมะนาว
# 1651 ยำหมูยอ
# 1652 เป็ดย่าง
# 1653 เป็ดย่าง
# 1654 ข้าวหน้าเป็ด
# 1655 ฮะเก๋า
# 1656 ไข่ตุ๋น
# 1657 ยำแซลมอน
# 1658 ขนมถ้วย
# 1659 ปลากระพงนึ่งมะนาว
# 1660 ก๋วยเตี๋ยวเรือ
# 1661 ปูนิ่มทอดกระเทียม
# 1662 น้ำตกหมู
# 1663 ไข่กระทะ
# 1664 honey toast
# 1665 ข้าวหมูกรอบ
# 1666 ก๋วยเตี๋ยวเรือ
# 1667 น้ำพริกไข่ปู
# 1668 แกงส้มชะอมกุ้ง
# 1669 ข้าวหมกไก่
# 1670 ทาโกะยากิ
# 1671 ออส่วน
# 1672 ก๋วยเตี๋ยวคั่วไก่
# 1673 ปอเปี๊ยะทอด
# 1674 ทาโกะยากิ
# 1675 ขนมปัง
# 1676 สปาเก็ตตี้ขี้เมาทะเล
# 1677 ทาโกะยากิ
# 1678 ข้าวผัดกระเทียม
# 1679 ขนมปังปิ้ง
# 1680 ไอศกรีม
# 1681 สปาเก็ตตี้ขี้เมาทะเล
# 1682 ทาโกะยากิ
# 1683 กระเพาะปลา
# 1684 ขาหมูเยอรมัน
# 1685 ชาบู
# 1686 เกี๊ยวทอด
# 1687 ปูม้านึ่ง
# 1688 สปาเก็ตตี้คาโบนาร่า
# 1689 ยำแซลมอน
# 1690 ขนมปังสังขยา
# 1691 ไส้อั่ว
# 1692 ปูนิ่มทอดกระเทียม
# 1693 ชาบู
# 1694 ขนมปังปิ้ง
# 1695 ยำสาหร่าย
# 1696 ขนมปังปิ้ง
# 1697 บะหมี่แห้ง
# 1698 เกี๊ยวทอด
# 1699 กระเพาะปลา
# 1700 ข้าวหมูกรอบ
# 1701 ขนมปังสังขยา
# 1702 ข้าวหน้าเป็ด
# 1703 ปูนิ่มทอดกระเทียม
# 1704 เป็ดย่าง
# 1705 ปอเปี๊ยะทอด
# 1706 ข้าวหมูกรอบ
# 1707 เนื้อย่าง
# 1708 ก๋วยเตี๋ยวเรือ
# 1709 ก๋วยเตี๋ยวเรือ
# 1710 ปูม้านึ่ง
# 1711 ขาหมูเยอรมัน
# 1712 เนื้อย่าง
# 1713 ไอศกรีม
# 1714 ปูนิ่มทอดกระเทียม
# 1715 ซุปเห็ด
# 1716 แกงส้มชะอมกุ้ง
# 1717 หมูมะนาว
# 1718 ข้าวหน้าเนื้อ
# 1719 กระเพาะปลา
# 1720 ก๋วยจั๊บญวน
# 1721 ชาบู
# 1722 บะหมี่แห้ง
# 1723 ปอเปี๊ยะทอด
# 1724 แกงส้มชะอมกุ้ง
# 1725 แกงส้มชะอมกุ้ง
# 1726 เค้ก
# 1727 ขนมปังสังขยา
# 1728 ขาหมูเยอรมัน
# 1729 ปูผัดผงกะหรี่
# 1730 บะหมี่แห้ง
# 1731 ข้าวผัดกระเทียม
# 1732 ข้าวหมูกรอบ
# 1733 ข้าวผัดกระเทียม
# 1734 ออส่วน
# 1735 ก๋วยเตี๋ยวคั่วไก่
# 1736 ขนมปังปิ้ง
# 1737 ขนมถ้วย
# 1738 แกงส้มชะอมกุ้ง
# 1739 ขนมถ้วย
# 1740 สเต็กหมู
# 1741 ขาหมูเยอรมัน
# 1742 สปาเก็ตตี้ขี้เมาทะเล
# 1743 สปาเก็ตตี้ขี้เมาทะเล
# 1744 ยำแซลมอน
# 1745 ก๋วยเตี๋ยวคั่วไก่
# 1746 ข้าวหน้าเนื้อ
# 1747 ทาโกะยากิ
# 1748 ไข่กระทะ
# 1749 ต้มเลือดหมู
# 1750 สปาเก็ตตี้ขี้เมาทะเล
# 1751 ชาบู
# 1752 ซุปเห็ด
# 1753 เนื้อย่าง
# 1754 ฮะเก๋า
# 1755 ปูม้านึ่ง
# 1756 เกี๊ยวทอด
# 1757 ข้าวผัดกระเทียม
# 1758 ยำปลาดุกฟู
# 1759 ทาโกะยากิ
# 1760 ก๋วยเตี๋ยวเรือ
# 1761 ข้าวหมกไก่
# 1762 ขนมปัง
# 1763 ข้าวหน้าเป็ด
# 1764 ข้าวหน้าเนื้อ
# 1765 ยำปลาดุกฟู
# 1766 ขนมปังสังขยา
# 1767 สเต็กหมู
# 1768 น้ำพริกไข่ปู
# 1769 ข้าวหมกไก่
# 1770 ก๋วยจั๊บญวน
# 1771 ขนมปังสังขยา
# 1772 ออส่วน
# 1773 เค้ก
# 1774 ข้าวผัดกระเทียม
# 1775 ทาโกะยากิ
# 1776 ทาโกะยากิ
# 1777 ชาบู
# 1778 honey toast
# 1779 สปาเก็ตตี้ขี้เมาทะเล
# 1780 สปาเก็ตตี้คาโบนาร่า
# 1781 ก๋วยเตี๋ยวคั่วไก่
# 1782 ขนมปังสังขยา
# 1783 ไข่ตุ๋น
# 1784 ก๋วยเตี๋ยวเรือ
# 1785 ฮะเก๋า
# 1786 ขนมปัง
# 1787 ยำหมูยอ
# 1788 ขนมปังปิ้ง
# 1789 ไข่กระทะ
# 1790 ต้มเลือดหมู
# 1791 ก๋วยจั๊บ
# 1792 ข้าวหน้าเนื้อ
# 1793 เนื้อย่าง
# 1794 น้ำพริกไข่ปู
# 1795 ไข่กระทะ
# 1796 เป็ดย่าง
# 1797 กระเพาะปลา
# 1798 ขนมปัง
# 1799 ยำปลาดุกฟู
# 1800 ยำหมูยอ
# 1801 เนื้อย่าง
# 1802 บะหมี่แห้ง
# 1803 ยำถั่วพลู
# 1804 ยำปลาดุกฟู
# 1805 ซุปเห็ด
# 1806 แกงส้มชะอมกุ้ง
# 1807 ออส่วน
# 1808 ขนมปังปิ้ง
# 1809 กระเพาะปลา
# 1810 กระเพาะปลา
# 1811 ทาโกะยากิ
# 1812 สปาเก็ตตี้คาโบนาร่า
# 1813 ต้มเลือดหมู
# 1814 เป็ดย่าง
# 1815 เป็ดพะโล้
# 1816 ยำสาหร่าย
# 1817 ออส่วน
# 1818 ยำปลาดุกฟู
# 1819 เค้ก
# 1820 ซุปเห็ด
# 1821 ปูผัดผงกะหรี่
# 1822 ซุปเห็ด
# 1823 ปูผัดผงกะหรี่
# 1824 ไอศกรีม
# 1825 กระเพาะปลา
# 1826 ยำหมูยอ
# 1827 สปาเก็ตตี้ขี้เมาทะเล
# 1828 ยำหมูยอ
# 1829 ยำสาหร่าย
# 1830 ยำปลาดุกฟู
# 1831 หมูมะนาว
# 1832 ปูนิ่มทอดกระเทียม
# 1833 แกงส้มชะอมกุ้ง
# 1834 ยำสาหร่าย
# 1835 honey toast
# 1836 ข้าวผัดกระเทียม
# 1837 ก๋วยเตี๋ยวเรือ
# 1838 สปาเก็ตตี้ขี้เมาทะเล
# 1839 ปลากระพงนึ่งมะนาว
# 1840 ต้มเลือดหมู
# 1841 ปูนิ่มทอดกระเทียม
# 1842 ไข่กระทะ
# 1843 ยำถั่วพลู
# 1844 น้ำตกหมู
# 1845 ปลากระพงนึ่งมะนาว
# 1846 น้ำตกหมู
# 1847 สเต็กหมู
# 1848 แกงส้มชะอมกุ้ง
# 1849 ไส้อั่ว
# 1850 ปลากระพงนึ่งมะนาว
# 1851 น้ำพริกไข่ปู
# 1852 ยำหมูยอ
# 1853 ข้าวหน้าเนื้อ
# 1854 ยำถั่วพลู
# 1855 ชาบู
# 1856 ขนมปัง
# 1857 น้ำพริกไข่ปู
# 1858 ปูผัดผงกะหรี่
# 1859 ก๋วยจั๊บ
# 1860 ไข่กระทะ
# 1861 ปูม้านึ่ง
# 1862 เป็ดพะโล้
# 1863 น้ำพริกไข่ปู
# 1864 สปาเก็ตตี้ขี้เมาทะเล
# 1865 ก๋วยจั๊บ
# 1866 ปูผัดผงกะหรี่
# 1867 ก๋วยเตี๋ยวคั่วไก่
# 1868 แกงส้มชะอมกุ้ง
# 1869 ไอศกรีม
# 1870 ก๋วยจั๊บ
# 1871 ไอศกรีม
# 1872 สปาเก็ตตี้คาโบนาร่า
# 1873 ฮะเก๋า
# 1874 ขนมถ้วย
# 1875 เป็ดพะโล้
# 1876 honey toast
# 1877 ก๋วยจั๊บ
# 1878 ขนมปังสังขยา
# 1879 ไส้อั่ว
# 1880 ปูผัดผงกะหรี่
# 1881 ไข่กระทะ
# 1882 เค้ก
# 1883 ซุปเห็ด
# 1884 ไข่กระทะ
# 1885 ก๋วยจั๊บญวน
# 1886 ต้มเลือดหมู
# 1887 ไอศกรีม
# 1888 บะหมี่แห้ง
# 1889 น้ำตกหมู
# 1890 ข้าวหน้าเนื้อ
# 1891 เนื้อย่าง
# 1892 ขนมปังสังขยา
# 1893 ปอเปี๊ยะทอด
# 1894 ก๋วยจั๊บ
# 1895 honey toast
# 1896 ต้มเลือดหมู
# 1897 ต้มเลือดหมู
# 1898 ซุปเห็ด
# 1899 ชาบู
# 1900 ก๋วยจั๊บญวน
# 1901 หมูมะนาว
# 1902 ยำหมูยอ
# 1903 ก๋วยเตี๋ยวเรือ
# 1904 ปอเปี๊ยะทอด
# 1905 สปาเก็ตตี้คาโบนาร่า
# 1906 ข้าวหมกไก่
# 1907 สปาเก็ตตี้คาโบนาร่า
# 1908 น้ำตกหมู
# 1909 ขนมปัง
# 1910 น้ำตกหมู
# 1911 ยำสาหร่าย
# 1912 กระเพาะปลา
# 1913 honey toast
# 1914 honey toast
# 1915 ชาบู
# 1916 ข้าวหน้าเนื้อ
# 1917 ข้าวหน้าเป็ด
# 1918 ขนมปังปิ้ง
# 1919 ขาหมูเยอรมัน
# 1920 ยำปลาดุกฟู
# 1921 ก๋วยเตี๋ยวคั่วไก่
# 1922 ก๋วยเตี๋ยวคั่วไก่
# 1923 ก๋วยเตี๋ยวเรือ
# 1924 ชาบู
# 1925 ขาหมูเยอรมัน
# 1926 ไอศกรีม
# 1927 ก๋วยจั๊บญวน
# 1928 ไส้อั่ว
# 1929 ขนมปังสังขยา
# 1930 ต้มเลือดหมู
# 1931 ยำหมูยอ
# 1932 บะหมี่แห้ง
# 1933 เนื้อย่าง
# 1934 ปูผัดผงกะหรี่
# 1935 ยำปลาดุกฟู
# 1936 สเต็กหมู
# 1937 ชาบู
# 1938 ข้าวหน้าเป็ด
# 1939 เค้ก
# 1940 หมูมะนาว
# 1941 ก๋วยเตี๋ยวคั่วไก่
# 1942 เกี๊ยวทอด
# 1943 ขนมปังสังขยา
# 1944 เกี๊ยวทอด
# 1945 ปูม้านึ่ง
# 1946 ไอศกรีม
# 1947 ปลากระพงนึ่งมะนาว
# 1948 ทาโกะยากิ
# 1949 ขนมปังปิ้ง
# 1950 เกี๊ยวทอด
# 1951 ออส่วน
# 1952 ต้มเลือดหมู
# 1953 honey toast
# 1954 ปลากระพงนึ่งมะนาว
# 1955 ออส่วน
# 1956 honey toast
# 1957 ข้าวหน้าเนื้อ
# 1958 ไอศกรีม
# 1959 ปลากระพงนึ่งมะนาว
# 1960 ขนมปังสังขยา
# 1961 เป็ดย่าง
# 1962 ก๋วยเตี๋ยวคั่วไก่
# 1963 ไส้อั่ว
# 1964 ข้าวหน้าเนื้อ
# 1965 เกี๊ยวทอด
# 1966 บะหมี่แห้ง
# 1967 ข้าวหมูกรอบ
# 1968 ข้าวหมกไก่
# 1969 ก๋วยจั๊บญวน
# 1970 ข้าวผัดกระเทียม
# 1971 สปาเก็ตตี้ขี้เมาทะเล
# 1972 ก๋วยจั๊บญวน
# 1973 แกงส้มชะอมกุ้ง
# 1974 แกงส้มชะอมกุ้ง
# 1975 เป็ดพะโล้
# 1976 ยำปลาดุกฟู
# 1977 ต้มเลือดหมู
# 1978 น้ำตกหมู
# 1979 ยำแซลมอน
# 1980 เป็ดย่าง
# 1981 ยำสาหร่าย
# 1982 ก๋วยจั๊บญวน
# 1983 ปูม้านึ่ง
# 1984 ต้มเลือดหมู
# 1985 ยำแซลมอน
# 1986 ข้าวหมกไก่
# 1987 กระเพาะปลา
# 1988 ขาหมูเยอรมัน
# 1989 น้ำพริกไข่ปู
# 1990 ปูม้านึ่ง
# 1991 เค้ก
# 1992 กระเพาะปลา
# 1993 เป็ดย่าง
# 1994 ข้าวหมูกรอบ
# 1995 ขนมปังสังขยา
# 1996 ขนมปังปิ้ง
# 1997 เกี๊ยวทอด
# 1998 น้ำพริกไข่ปู
# 1999 ปอเปี๊ยะทอด
# 2000 ปูม้านึ่ง
# 2001 หมูมะนาว
# 2002 ซุปเห็ด
# 2003 honey toast
# 2004 ไส้อั่ว
# 2005 ต้มเลือดหมู
# 2006 ไอศกรีม
# 2007 ขนมปังสังขยา
# 2008 ก๋วยจั๊บ
# 2009 ข้าวผัดกระเทียม
# 2010 ต้มเลือดหมู
# 2011 ก๋วยจั๊บ
# 2012 น้ำพริกไข่ปู
# 2013 ปลากระพงนึ่งมะนาว
# 2014 ก๋วยจั๊บญวน
# 2015 ปูม้านึ่ง
# 2016 ก๋วยเตี๋ยวคั่วไก่
# 2017 หมูมะนาว
# 2018 ยำหมูยอ
# 2019 สเต็กหมู
# 2020 กระเพาะปลา
# 2021 น้ำตกหมู
# 2022 ขาหมูเยอรมัน
# 2023 เป็ดย่าง
# 2024 ข้าวผัดกระเทียม
# 2025 เป็ดพะโล้
# 2026 ยำหมูยอ
# 2027 ออส่วน
# 2028 ขนมถ้วย
# 2029 ขนมปัง
# 2030 ซุปเห็ด
# 2031 สเต็กหมู
# 2032 ขนมปังปิ้ง
# 2033 ยำสาหร่าย
# 2034 ฮะเก๋า
# 2035 ขนมปัง
# 2036 ซุปเห็ด
# 2037 ยำหมูยอ
# 2038 ก๋วยเตี๋ยวคั่วไก่
# 2039 ไส้อั่ว
# 2040 ยำสาหร่าย
# 2041 สเต็กหมู
# 2042 ปลากระพงนึ่งมะนาว
# 2043 ก๋วยจั๊บ
# 2044 สปาเก็ตตี้ขี้เมาทะเล
# 2045 ฮะเก๋า
# 2046 เค้ก
# 2047 แกงคั่วหอยขม
# 2048 ก๋วยจั๊บญวน
# 2049 ข้าวหมกไก่
# 2050 honey toast
# 2051 ซุปเห็ด
# 2052 honey toast
# 2053 ฮะเก๋า
# 2054 ปูม้านึ่ง
# 2055 เกี๊ยวทอด
# 2056 ยำปลาดุกฟู
# 2057 ก๋วยเตี๋ยวเรือ
# 2058 หมูมะนาว
# 2059 แกงส้มชะอมกุ้ง
# 2060 honey toast
# 2061 ปูม้านึ่ง
# 2062 ข้าวผัดกระเทียม
# 2063 ซุปเห็ด
# 2064 บะหมี่แห้ง
# 2065 บะหมี่แห้ง
# 2066 ข้าวผัดกระเทียม
# 2067 ข้าวหน้าเนื้อ
# 2068 ก๋วยจั๊บ
# 2069 ขาหมูเยอรมัน
# 2070 สปาเก็ตตี้คาโบนาร่า
# 2071 ซุปเห็ด
# 2072 ยำหมูยอ
# 2073 ไส้อั่ว
# 2074 สเต็กหมู
# 2075 กระเพาะปลา
# 2076 สปาเก็ตตี้คาโบนาร่า
# 2077 ขาหมูเยอรมัน
# 2078 เกี๊ยวทอด
# 2079 ต้มเลือดหมู
# 2080 หมูมะนาว
# 2081 ไส้อั่ว
# 2082 น้ำตกหมู
# 2083 ไข่กระทะ
# 2084 แกงส้มชะอมกุ้ง
# 2085 ข้าวหน้าเป็ด
# 2086 ก๋วยเตี๋ยวคั่วไก่
# 2087 เนื้อย่าง
# 2088 เนื้อย่าง
# 2089 เนื้อย่าง
# 2090 ข้าวหน้าเนื้อ
# 2091 ทาโกะยากิ
# 2092 ปูม้านึ่ง
# 2093 ปูม้านึ่ง
# 2094 ชาบู
# 2095 กระเพาะปลา
# 2096 ขนมปังปิ้ง
# 2097 เกี๊ยวทอด
# 2098 ยำถั่วพลู
# 2099 เค้ก
# 2100 ก๋วยเตี๋ยวเรือ
# 2101 ยำแซลมอน
# 2102 ทาโกะยากิ
# 2103 ก๋วยเตี๋ยวคั่วไก่
# 2104 ขนมปังสังขยา
# 2105 เนื้อย่าง
# 2106 สปาเก็ตตี้คาโบนาร่า
# 2107 ชาบู
# 2108 ยำแซลมอน
# 2109 ยำสาหร่าย
# 2110 เป็ดพะโล้
# 2111 ขนมปังสังขยา
# 2112 เป็ดพะโล้
# 2113 ขาหมูเยอรมัน
# 2114 ขนมปังสังขยา
# 2115 ข้าวผัดกระเทียม
# 2116 ข้าวหมูกรอบ
# 2117 honey toast
# 2118 สปาเก็ตตี้คาโบนาร่า
# 2119 น้ำตกหมู
# 2120 ปูผัดผงกะหรี่
# 2121 ยำปลาดุกฟู
# 2122 ทาโกะยากิ
# 2123 ทาโกะยากิ
# 2124 ซุปเห็ด
# 2125 ต้มเลือดหมู
# 2126 honey toast
# 2127 ยำแซลมอน
# 2128 ขนมปังปิ้ง
# 2129 ไข่กระทะ
# 2130 ยำแซลมอน
# 2131 ฮะเก๋า
# 2132 เค้ก
# 2133 ปอเปี๊ยะทอด
# 2134 ข้าวผัดกระเทียม
# 2135 ขนมปังปิ้ง
# 2136 ต้มเลือดหมู
# 2137 สเต็กหมู
# 2138 ยำถั่วพลู
# 2139 เกี๊ยวทอด
# 2140 ขนมถ้วย
# 2141 ก๋วยจั๊บญวน
# 2142 ขนมปัง
# 2143 แกงคั่วหอยขม
# 2144 ชาบู
# 2145 ปูนิ่มทอดกระเทียม
# 2146 ก๋วยจั๊บ
# 2147 ข้าวหน้าเป็ด
# 2148 แกงคั่วหอยขม
# 2149 เนื้อย่าง
# 2150 ต้มเลือดหมู
# 2151 ไอศกรีม
# 2152 ไส้อั่ว
# 2153 เป็ดย่าง
# 2154 ไอศกรีม
# 2155 ข้าวหมูกรอบ
# 2156 ยำปลาดุกฟู
# 2157 ออส่วน
# 2158 ขนมถ้วย
# 2159 แกงคั่วหอยขม
# 2160 เค้ก
# 2161 เนื้อย่าง
# 2162 ขนมปัง
# 2163 ข้าวหน้าเนื้อ
# 2164 เกี๊ยวทอด
# 2165 ข้าวหมกไก่
# 2166 ยำแซลมอน
# 2167 honey toast
# 2168 เนื้อย่าง
# 2169 ขนมปังสังขยา
# 2170 ก๋วยเตี๋ยวคั่วไก่
# 2171 เค้ก
# 2172 ซุปเห็ด
# 2173 เนื้อย่าง
# 2174 เกี๊ยวทอด
# 2175 ขนมปังสังขยา
# 2176 ขนมปัง
# 2177 ออส่วน
# 2178 สปาเก็ตตี้ขี้เมาทะเล
# 2179 ไข่กระทะ
# 2180 ก๋วยเตี๋ยวเรือ
# 2181 แกงคั่วหอยขม
# 2182 ก๋วยจั๊บญวน
# 2183 ก๋วยเตี๋ยวเรือ
# 2184 ขนมถ้วย
# 2185 เนื้อย่าง
# 2186 ขาหมูเยอรมัน
# 2187 ก๋วยจั๊บ
# 2188 น้ำพริกไข่ปู
# 2189 ซุปเห็ด
# 2190 หมูมะนาว
# 2191 เป็ดพะโล้
# 2192 ขนมถ้วย
# 2193 สปาเก็ตตี้คาโบนาร่า
# 2194 ไอศกรีม
# 2195 honey toast
# 2196 สเต็กหมู
# 2197 ยำปลาดุกฟู
# 2198 ยำถั่วพลู
# 2199 ขนมถ้วย
# 2200 ข้าวหน้าเนื้อ
# 2201 ไข่กระทะ
# 2202 ขนมปัง
# 2203 หมูมะนาว
# 2204 ยำถั่วพลู
# 2205 ขนมถ้วย
# 2206 แกงส้มชะอมกุ้ง
# 2207 ขนมปัง
# 2208 ขนมปังปิ้ง
# 2209 ยำแซลมอน
# 2210 ปูม้านึ่ง
# 2211 ข้าวผัดกระเทียม
# 2212 ไข่กระทะ
# 2213 ออส่วน
# 2214 ยำถั่วพลู
# 2215 ข้าวหน้าเป็ด
# 2216 ไส้อั่ว
# 2217 ยำถั่วพลู
# 2218 ปูนิ่มทอดกระเทียม
# 2219 แกงส้มชะอมกุ้ง
# 2220 ข้าวหมูกรอบ
# 2221 ก๋วยจั๊บ
# 2222 ก๋วยจั๊บ
# 2223 ขาหมูเยอรมัน
# 2224 สปาเก็ตตี้คาโบนาร่า
# 2225 ข้าวหน้าเนื้อ
# 2226 บะหมี่แห้ง
# 2227 ปอเปี๊ยะทอด
# 2228 ฮะเก๋า
# 2229 ปอเปี๊ยะทอด
# 2230 ข้าวหน้าเป็ด
# 2231 ปูผัดผงกะหรี่
# 2232 สเต็กหมู
# 2233 ข้าวหมูกรอบ
# 2234 ขนมปังสังขยา
# 2235 ยำแซลมอน
# 2236 ปลากระพงนึ่งมะนาว
# 2237 กระเพาะปลา
# 2238 ปูม้านึ่ง
# 2239 หมูมะนาว
# 2240 ก๋วยจั๊บญวน
# 2241 หมูมะนาว
# 2242 ก๋วยจั๊บญวน
# 2243 เป็ดพะโล้
# 2244 ฮะเก๋า
# 2245 ปูม้านึ่ง
# 2246 ปลากระพงนึ่งมะนาว
# 2247 ข้าวหน้าเนื้อ
# 2248 ไข่ตุ๋น
# 2249 ไข่กระทะ
# 2250 เป็ดพะโล้
# 2251 น้ำตกหมู
# 2252 ข้าวผัดกระเทียม
# 2253 ขนมถ้วย
# 2254 ข้าวหน้าเนื้อ
# 2255 แกงคั่วหอยขม
# 2256 ชาบู
# 2257 ขาหมูเยอรมัน
# 2258 ปลากระพงนึ่งมะนาว
# 2259 ก๋วยเตี๋ยวคั่วไก่
# 2260 น้ำพริกไข่ปู
# 2261 ไข่ตุ๋น
# 2262 ไข่ตุ๋น
# 2263 ข้าวหมกไก่
# 2264 ยำแซลมอน
# 2265 ยำแซลมอน
# 2266 ปลากระพงนึ่งมะนาว
# 2267 ซุปเห็ด
# 2268 ข้าวหมูกรอบ
# 2269 ขาหมูเยอรมัน
# 2270 แกงคั่วหอยขม
# 2271 เนื้อย่าง
# 2272 ขาหมูเยอรมัน
# 2273 ไข่ตุ๋น
# 2274 เป็ดย่าง
# 2275 แกงคั่วหอยขม
# 2276 ปูม้านึ่ง
# 2277 ก๋วยจั๊บญวน
# 2278 ไส้อั่ว
# 2279 ก๋วยเตี๋ยวเรือ
# 2280 ก๋วยเตี๋ยวคั่วไก่
# 2281 honey toast
# 2282 ออส่วน
# 2283 สปาเก็ตตี้ขี้เมาทะเล
# 2284 ขนมปังสังขยา
# 2285 เป็ดย่าง
# 2286 เค้ก
# 2287 honey toast
# 2288 แกงคั่วหอยขม
# 2289 น้ำตกหมู
# 2290 ก๋วยจั๊บ
# 2291 เป็ดย่าง
# 2292 เป็ดย่าง
# 2293 ข้าวหน้าเนื้อ
# 2294 ไส้อั่ว
# 2295 ยำสาหร่าย
# 2296 ก๋วยเตี๋ยวเรือ
# 2297 ขนมปังปิ้ง
# 2298 ทาโกะยากิ
# 2299 เป็ดย่าง
# 2300 เค้ก
# 2301 ยำปลาดุกฟู
# 2302 ออส่วน
# 2303 น้ำตกหมู
# 2304 ออส่วน
# 2305 ข้าวหมูกรอบ
# 2306 ปูนิ่มทอดกระเทียม
# 2307 กระเพาะปลา
# 2308 ก๋วยจั๊บญวน
# 2309 ยำถั่วพลู
# 2310 เค้ก
# 2311 ปูนิ่มทอดกระเทียม
# 2312 สปาเก็ตตี้ขี้เมาทะเล
# 2313 ปลากระพงนึ่งมะนาว
# 2314 ทาโกะยากิ
# 2315 ก๋วยเตี๋ยวคั่วไก่
# 2316 ก๋วยจั๊บญวน
# 2317 เค้ก
# 2318 ข้าวหน้าเนื้อ
# 2319 ขาหมูเยอรมัน
# 2320 ทาโกะยากิ
# 2321 ข้าวหมูกรอบ
# 2322 ชาบู
# 2323 เนื้อย่าง
# 2324 ข้าวหน้าเนื้อ
# 2325 ยำหมูยอ
# 2326 ชาบู
# 2327 เค้ก
# 2328 ทาโกะยากิ
# 2329 ปลากระพงนึ่งมะนาว
# 2330 แกงคั่วหอยขม
# 2331 กระเพาะปลา
# 2332 หมูมะนาว
# 2333 แกงส้มชะอมกุ้ง
# 2334 ยำแซลมอน
# 2335 ยำถั่วพลู
# 2336 เป็ดย่าง
# 2337 ปูนิ่มทอดกระเทียม
# 2338 ก๋วยจั๊บญวน
# 2339 น้ำตกหมู
# 2340 ข้าวหมกไก่
# 2341 ยำหมูยอ
# 2342 honey toast
# 2343 เป็ดย่าง
# 2344 ยำแซลมอน
# 2345 สปาเก็ตตี้คาโบนาร่า
# 2346 ไข่ตุ๋น
# 2347 ข้าวผัดกระเทียม
# 2348 เค้ก
# 2349 กระเพาะปลา
# 2350 honey toast
# 2351 ไข่กระทะ
# 2352 ปลากระพงนึ่งมะนาว
# 2353 ยำปลาดุกฟู
# 2354 ฮะเก๋า
# 2355 ปูผัดผงกะหรี่
# 2356 ก๋วยจั๊บญวน
# 2357 สเต็กหมู
# 2358 ยำสาหร่าย
# 2359 ไส้อั่ว
# 2360 น้ำตกหมู
# 2361 ข้าวหมูกรอบ
# 2362 ขนมปังสังขยา
# 2363 ยำแซลมอน
# 2364 ก๋วยเตี๋ยวคั่วไก่
# 2365 ขนมปังปิ้ง
# 2366 สปาเก็ตตี้ขี้เมาทะเล
# 2367 ขาหมูเยอรมัน
# 2368 บะหมี่แห้ง
# 2369 น้ำตกหมู
# 2370 หมูมะนาว
# 2371 ปูม้านึ่ง
# 2372 ปอเปี๊ยะทอด
# 2373 ต้มเลือดหมู
# 2374 ยำถั่วพลู
# 2375 ข้าวหมูกรอบ
# 2376 ขนมปังปิ้ง
# 2377 ฮะเก๋า
# 2378 แกงคั่วหอยขม
# 2379 ก๋วยเตี๋ยวคั่วไก่
# 2380 หมูมะนาว
# 2381 ออส่วน
# 2382 ปูม้านึ่ง
# 2383 ออส่วน
# 2384 แกงคั่วหอยขม
# 2385 ไอศกรีม
# 2386 หมูมะนาว
# 2387 ข้าวหน้าเนื้อ
# 2388 เป็ดพะโล้
# 2389 สปาเก็ตตี้ขี้เมาทะเล
# 2390 ต้มเลือดหมู
# 2391 สเต็กหมู
# 2392 ขนมถ้วย
# 2393 สปาเก็ตตี้ขี้เมาทะเล
# 2394 ยำสาหร่าย
# 2395 เนื้อย่าง
# 2396 แกงส้มชะอมกุ้ง
# 2397 ข้าวหมูกรอบ
# 2398 ข้าวหน้าเนื้อ
# 2399 ปูนิ่มทอดกระเทียม
# 2400 ไส้อั่ว
# 2401 ปลากระพงนึ่งมะนาว
# 2402 ขนมปังปิ้ง
# 2403 ชาบู
# 2404 ปูนิ่มทอดกระเทียม
# 2405 ต้มเลือดหมู
# 2406 ปูม้านึ่ง
# 2407 ออส่วน
# 2408 ปอเปี๊ยะทอด
# 2409 ปูผัดผงกะหรี่
# 2410 ยำแซลมอน
# 2411 ขนมปังปิ้ง
# 2412 ปอเปี๊ยะทอด
# 2413 ข้าวหมกไก่
# 2414 เนื้อย่าง
# 2415 ยำแซลมอน
# 2416 ข้าวหมูกรอบ
# 2417 ออส่วน
# 2418 เค้ก
# 2419 ปลากระพงนึ่งมะนาว
# 2420 สปาเก็ตตี้คาโบนาร่า
# 2421 ไข่กระทะ
# 2422 ไส้อั่ว
# 2423 ซุปเห็ด
# 2424 น้ำพริกไข่ปู
# 2425 ยำสาหร่าย
# 2426 ยำปลาดุกฟู
# 2427 ขนมปัง
# 2428 ข้าวหน้าเนื้อ
# 2429 ทาโกะยากิ
# 2430 ไข่กระทะ
# 2431 ปูนิ่มทอดกระเทียม
# 2432 กระเพาะปลา
# 2433 น้ำพริกไข่ปู
# 2434 ยำถั่วพลู
# 2435 แกงคั่วหอยขม
# 2436 น้ำพริกไข่ปู
# 2437 honey toast
# 2438 ข้าวหน้าเนื้อ
# 2439 ต้มเลือดหมู
# 2440 ปูนิ่มทอดกระเทียม
# 2441 น้ำพริกไข่ปู
# 2442 สปาเก็ตตี้คาโบนาร่า
# 2443 ชาบู
# 2444 ข้าวหน้าเนื้อ
# 2445 honey toast
# 2446 เป็ดย่าง
# 2447 ฮะเก๋า
# 2448 ข้าวหน้าเป็ด
# 2449 ปูนิ่มทอดกระเทียม
# 2450 ก๋วยจั๊บ
# 2451 เค้ก
# 2452 ข้าวหน้าเนื้อ
# 2453 น้ำตกหมู
# 2454 หมูมะนาว
# 2455 แกงส้มชะอมกุ้ง
# 2456 ก๋วยเตี๋ยวเรือ
# 2457 ข้าวหมูกรอบ
# 2458 เค้ก
# 2459 สเต็กหมู
# 2460 สเต็กหมู
# 2461 ปูนิ่มทอดกระเทียม
# 2462 ไข่กระทะ
# 2463 ทาโกะยากิ
# 2464 ก๋วยเตี๋ยวคั่วไก่
# 2465 ซุปเห็ด
# 2466 ปลากระพงนึ่งมะนาว
# 2467 ขนมถ้วย
# 2468 ก๋วยเตี๋ยวคั่วไก่
# 2469 บะหมี่แห้ง
# 2470 น้ำตกหมู
# 2471 ปูม้านึ่ง
# 2472 ฮะเก๋า
# 2473 กระเพาะปลา
# 2474 กระเพาะปลา
# 2475 ไอศกรีม
# 2476 ขนมปัง
# 2477 ยำหมูยอ
# 2478 สปาเก็ตตี้ขี้เมาทะเล
# 2479 ขนมถ้วย
# 2480 ข้าวหน้าเป็ด
# 2481 ปูม้านึ่ง
# 2482 เกี๊ยวทอด
# 2483 ขนมปัง
# 2484 ยำปลาดุกฟู
# 2485 ข้าวหมูกรอบ
# 2486 ออส่วน
# 2487 เป็ดพะโล้
# 2488 ยำถั่วพลู
# 2489 ก๋วยจั๊บ
# 2490 ขาหมูเยอรมัน
# 2491 ก๋วยจั๊บ
# 2492 ปลากระพงนึ่งมะนาว
# 2493 honey toast
# 2494 ขนมถ้วย
# 2495 ข้าวหมูกรอบ
# 2496 แกงส้มชะอมกุ้ง
# 2497 บะหมี่แห้ง
# 2498 เป็ดพะโล้
# 2499 ต้มเลือดหมู
# 2500 ขาหมูเยอรมัน
# 2501 ข้าวหน้าเป็ด
# 2502 ปูผัดผงกะหรี่
# 2503 ยำถั่วพลู
# 2504 ซุปเห็ด
# 2505 ปูผัดผงกะหรี่
# 2506 ไข่ตุ๋น
# 2507 ก๋วยจั๊บ
# 2508 ข้าวผัดกระเทียม
# 2509 ขนมปังปิ้ง
# 2510 ปูนิ่มทอดกระเทียม
# 2511 ไข่ตุ๋น
# 2512 ยำหมูยอ
# 2513 น้ำพริกไข่ปู
# 2514 ยำถั่วพลู
# 2515 ขนมถ้วย
# 2516 น้ำตกหมู
# 2517 บะหมี่แห้ง
# 2518 เนื้อย่าง
# 2519 ไอศกรีม
# 2520 เป็ดพะโล้
# 2521 ปูนิ่มทอดกระเทียม
# 2522 ไอศกรีม
# 2523 กระเพาะปลา
# 2524 ข้าวหมูกรอบ
# 2525 ปอเปี๊ยะทอด
# 2526 ปูนิ่มทอดกระเทียม
# 2527 ยำถั่วพลู
# 2528 เค้ก
# 2529 เกี๊ยวทอด
# 2530 เป็ดพะโล้
# 2531 ไข่กระทะ
# 2532 ซุปเห็ด
# 2533 ยำสาหร่าย
# 2534 ปูผัดผงกะหรี่
# 2535 ไอศกรีม
# 2536 ยำสาหร่าย
# 2537 ข้าวหน้าเนื้อ
# 2538 ก๋วยเตี๋ยวคั่วไก่
# 2539 ทาโกะยากิ
# 2540 ปูผัดผงกะหรี่
# 2541 ขนมปังสังขยา
# 2542 ซุปเห็ด
# 2543 ข้าวหมูกรอบ
# 2544 เกี๊ยวทอด
# 2545 ปูนิ่มทอดกระเทียม
# 2546 ไข่ตุ๋น
# 2547 ซุปเห็ด
# 2548 เป็ดย่าง
# 2549 ก๋วยจั๊บญวน
# 2550 ซุปเห็ด
# 2551 เกี๊ยวทอด
# 2552 ออส่วน
# 2553 แกงคั่วหอยขม
# 2554 ขนมถ้วย
# 2555 ขนมถ้วย
# 2556 เป็ดพะโล้
# 2557 ก๋วยเตี๋ยวเรือ
# 2558 เค้ก
# 2559 ทาโกะยากิ
# 2560 ยำสาหร่าย
# 2561 ข้าวหน้าเนื้อ
# 2562 ก๋วยจั๊บญวน
# 2563 ยำถั่วพลู
# 2564 เกี๊ยวทอด
# 2565 ขนมปังสังขยา
# 2566 ทาโกะยากิ
# 2567 ยำสาหร่าย
# 2568 ทาโกะยากิ
# 2569 บะหมี่แห้ง
# 2570 บะหมี่แห้ง
# 2571 ข้าวผัดกระเทียม
# 2572 ยำหมูยอ
# 2573 ข้าวหมูกรอบ
# 2574 ข้าวหน้าเนื้อ
# 2575 ขนมปังปิ้ง
# 2576 น้ำพริกไข่ปู
# 2577 เค้ก
# 2578 ไข่กระทะ
# 2579 ออส่วน
# 2580 ปูนิ่มทอดกระเทียม
# 2581 ทาโกะยากิ
# 2582 ยำแซลมอน
# 2583 ขนมปัง
# 2584 ไส้อั่ว
# 2585 ยำหมูยอ
# 2586 ทาโกะยากิ
# 2587 แกงคั่วหอยขม
# 2588 เค้ก
# 2589 ปูม้านึ่ง
# 2590 ก๋วยเตี๋ยวเรือ
# 2591 ขนมถ้วย
# 2592 ขนมปังปิ้ง
# 2593 เค้ก
# 2594 ก๋วยจั๊บ
# 2595 ขนมปังสังขยา
# 2596 ขนมถ้วย
# 2597 สปาเก็ตตี้คาโบนาร่า
# 2598 ฮะเก๋า
# 2599 ต้มเลือดหมู
# 2600 ชาบู
# 2601 ก๋วยจั๊บ
# 2602 ข้าวหมกไก่
# 2603 เกี๊ยวทอด
# 2604 เค้ก
# 2605 ยำแซลมอน
# 2606 บะหมี่แห้ง
# 2607 ออส่วน
# 2608 เค้ก
# 2609 ยำปลาดุกฟู
# 2610 น้ำตกหมู
# 2611 หมูมะนาว
# 2612 ฮะเก๋า
# 2613 ปูนิ่มทอดกระเทียม
# 2614 ข้าวหน้าเนื้อ
# 2615 ไข่ตุ๋น
# 2616 ไข่ตุ๋น
# 2617 ขนมปังสังขยา
# 2618 เนื้อย่าง
# 2619 ยำหมูยอ
# 2620 honey toast
# 2621 ก๋วยจั๊บญวน
# 2622 น้ำพริกไข่ปู
# 2623 ก๋วยเตี๋ยวคั่วไก่
# 2624 ทาโกะยากิ
# 2625 ไข่กระทะ
# 2626 บะหมี่แห้ง
# 2627 ก๋วยเตี๋ยวคั่วไก่
# 2628 กระเพาะปลา
# 2629 ออส่วน
# 2630 ขนมปังสังขยา
# 2631 น้ำพริกไข่ปู
# 2632 ปูม้านึ่ง
# 2633 ข้าวหน้าเป็ด
# 2634 ฮะเก๋า
# 2635 ปูนิ่มทอดกระเทียม
# 2636 ยำถั่วพลู
# 2637 ไข่กระทะ
# 2638 ยำปลาดุกฟู
# 2639 ขนมปัง
# 2640 ปูผัดผงกะหรี่
# 2641 ขนมปังสังขยา
# 2642 ก๋วยเตี๋ยวเรือ
# 2643 ข้าวหน้าเป็ด
# 2644 เป็ดพะโล้
# 2645 ไข่กระทะ
# 2646 honey toast
# 2647 ไอศกรีม
# 2648 ออส่วน
# 2649 ก๋วยจั๊บ
# 2650 ยำสาหร่าย
# 2651 ยำแซลมอน
# 2652 ไข่ตุ๋น
# 2653 เป็ดย่าง
# 2654 น้ำพริกไข่ปู
# 2655 กระเพาะปลา
# 2656 ข้าวผัดกระเทียม
# 2657 แกงคั่วหอยขม
# 2658 หมูมะนาว
# 2659 ทาโกะยากิ
# 2660 ไข่กระทะ
# 2661 ข้าวผัดกระเทียม
# 2662 ไส้อั่ว
# 2663 ไส้อั่ว
# 2664 เค้ก
# 2665 เป็ดพะโล้
# 2666 ยำปลาดุกฟู
# 2667 แกงคั่วหอยขม
# 2668 เค้ก
# 2669 บะหมี่แห้ง
# 2670 ปลากระพงนึ่งมะนาว
# 2671 ก๋วยเตี๋ยวคั่วไก่
# 2672 ขนมถ้วย
# 2673 ยำหมูยอ
# 2674 ชาบู
# 2675 ขนมปังสังขยา
# 2676 เค้ก
# 2677 ข้าวหน้าเนื้อ
# 2678 ข้าวหน้าเนื้อ
# 2679 ปูผัดผงกะหรี่
# 2680 เค้ก
# 2681 น้ำพริกไข่ปู
# 2682 ยำหมูยอ
# 2683 ยำแซลมอน
# 2684 เนื้อย่าง
# 2685 ก๋วยเตี๋ยวเรือ
# 2686 สเต็กหมู
# 2687 เนื้อย่าง
# 2688 สปาเก็ตตี้ขี้เมาทะเล
# 2689 ฮะเก๋า
# 2690 ปูม้านึ่ง
# 2691 ปอเปี๊ยะทอด
# 2692 ก๋วยจั๊บ
# 2693 ปูนิ่มทอดกระเทียม
# 2694 ข้าวผัดกระเทียม
# 2695 ยำแซลมอน
# 2696 สปาเก็ตตี้ขี้เมาทะเล
# 2697 ชาบู
# 2698 ไส้อั่ว
# 2699 ชาบู
# 2700 สปาเก็ตตี้ขี้เมาทะเล
# 2701 ไข่ตุ๋น
# 2702 ก๋วยเตี๋ยวเรือ
# 2703 สเต็กหมู
# 2704 ขาหมูเยอรมัน
# 2705 ข้าวหน้าเป็ด
# 2706 ขาหมูเยอรมัน
# 2707 กระเพาะปลา
# 2708 ไอศกรีม
# 2709 หมูมะนาว
# 2710 ก๋วยจั๊บญวน
# 2711 ไข่ตุ๋น
# 2712 ยำถั่วพลู
# 2713 ยำปลาดุกฟู
# 2714 แกงส้มชะอมกุ้ง
# 2715 ขาหมูเยอรมัน
# 2716 ขนมปัง
# 2717 ไข่ตุ๋น
# 2718 ปูผัดผงกะหรี่
# 2719 น้ำพริกไข่ปู
# 2720 เป็ดย่าง
# 2721 ไอศกรีม
# 2722 ฮะเก๋า
# 2723 ก๋วยจั๊บ
# 2724 ยำหมูยอ
# 2725 หมูมะนาว
# 2726 บะหมี่แห้ง
# 2727 ไส้อั่ว
# 2728 ข้าวหมูกรอบ
# 2729 สเต็กหมู
# 2730 สปาเก็ตตี้ขี้เมาทะเล
# 2731 สปาเก็ตตี้คาโบนาร่า
# 2732 น้ำตกหมู
# 2733 ก๋วยจั๊บญวน
# 2734 ข้าวหน้าเนื้อ
# 2735 ยำปลาดุกฟู
# 2736 บะหมี่แห้ง
# 2737 ขนมถ้วย
# 2738 ปูนิ่มทอดกระเทียม
# 2739 ยำปลาดุกฟู
# 2740 ขาหมูเยอรมัน
# 2741 เป็ดย่าง
# 2742 ขนมปังสังขยา
# 2743 ยำสาหร่าย
# 2744 ปูม้านึ่ง
# 2745 ชาบู
# 2746 honey toast
# 2747 ปูม้านึ่ง
# 2748 สปาเก็ตตี้ขี้เมาทะเล
# 2749 ออส่วน
# 2750 ปูม้านึ่ง
# 2751 ไส้อั่ว
# 2752 แกงคั่วหอยขม
# 2753 ปูนิ่มทอดกระเทียม
# 2754 ขนมปังสังขยา
# 2755 ข้าวหน้าเป็ด
# 2756 ทาโกะยากิ
# 2757 ชาบู
# 2758 ก๋วยเตี๋ยวเรือ
# 2759 ยำปลาดุกฟู
# 2760 บะหมี่แห้ง
# 2761 แกงส้มชะอมกุ้ง
# 2762 ปลากระพงนึ่งมะนาว
# 2763 เกี๊ยวทอด
# 2764 ยำหมูยอ
# 2765 สเต็กหมู
# 2766 ก๋วยจั๊บญวน
# 2767 ยำถั่วพลู
# 2768 ปูนิ่มทอดกระเทียม
# 2769 สปาเก็ตตี้ขี้เมาทะเล
# 2770 ข้าวผัดกระเทียม
# 2771 ขนมถ้วย
# 2772 ขนมปังปิ้ง
# 2773 ยำหมูยอ
# 2774 ไส้อั่ว
# 2775 บะหมี่แห้ง
# 2776 ก๋วยจั๊บญวน
# 2777 ยำหมูยอ
# 2778 ไอศกรีม
# 2779 กระเพาะปลา
# 2780 ขนมปัง
# 2781 ก๋วยจั๊บ
# 2782 ปูผัดผงกะหรี่
# 2783 ไข่ตุ๋น
# 2784 ก๋วยจั๊บญวน
# 2785 เนื้อย่าง
# 2786 ชาบู
# 2787 สเต็กหมู
# 2788 เป็ดพะโล้
# 2789 ชาบู
# 2790 ข้าวผัดกระเทียม
# 2791 ปูม้านึ่ง
# 2792 ก๋วยเตี๋ยวคั่วไก่
# 2793 ออส่วน
# 2794 เนื้อย่าง
# 2795 เนื้อย่าง
# 2796 ขนมปังสังขยา
# 2797 ข้าวผัดกระเทียม
# 2798 ปอเปี๊ยะทอด
# 2799 เกี๊ยวทอด
# 2800 ข้าวหน้าเนื้อ
# 2801 ไส้อั่ว
# 2802 ปูม้านึ่ง
# 2803 สเต็กหมู
# 2804 ปูนิ่มทอดกระเทียม
# 2805 ไอศกรีม
# 2806 ขนมปังสังขยา
# 2807 สเต็กหมู
# 2808 ข้าวหน้าเป็ด
# 2809 เค้ก
# 2810 ปอเปี๊ยะทอด
# 2811 น้ำตกหมู
# 2812 ข้าวหน้าเป็ด
# 2813 ก๋วยจั๊บญวน
# 2814 สเต็กหมู
# 2815 ฮะเก๋า
# 2816 ข้าวผัดกระเทียม
# 2817 เค้ก
# 2818 สเต็กหมู
# 2819 ปูผัดผงกะหรี่
# 2820 ข้าวหมูกรอบ
# 2821 ทาโกะยากิ
# 2822 ขนมปังสังขยา
# 2823 ไอศกรีม
# 2824 ปูม้านึ่ง
# 2825 กระเพาะปลา
# 2826 แกงคั่วหอยขม
# 2827 ยำปลาดุกฟู
# 2828 ออส่วน
# 2829 ขนมปังสังขยา
# 2830 เป็ดพะโล้
# 2831 เนื้อย่าง
# 2832 ก๋วยเตี๋ยวเรือ
# 2833 ปอเปี๊ยะทอด
# 2834 ข้าวหน้าเนื้อ
# 2835 ไข่ตุ๋น
# 2836 ยำสาหร่าย
# 2837 เกี๊ยวทอด
# 2838 ไข่ตุ๋น
# 2839 ยำถั่วพลู
# 2840 ยำสาหร่าย
# 2841 ทาโกะยากิ
# 2842 ยำปลาดุกฟู
# 2843 ฮะเก๋า
# 2844 ขนมปังปิ้ง
# 2845 ฮะเก๋า
# 2846 ขาหมูเยอรมัน
# 2847 เกี๊ยวทอด
# 2848 ก๋วยจั๊บ
# 2849 ข้าวหมกไก่
# 2850 เค้ก
# 2851 ยำปลาดุกฟู
# 2852 ไข่ตุ๋น
# 2853 ฮะเก๋า
# 2854 ข้าวหน้าเนื้อ
# 2855 ยำแซลมอน
# 2856 ออส่วน
# 2857 ออส่วน
# 2858 แกงส้มชะอมกุ้ง
# 2859 ไข่กระทะ
# 2860 น้ำตกหมู
# 2861 ยำหมูยอ
# 2862 ชาบู
# 2863 honey toast
# 2864 หมูมะนาว
# 2865 ขาหมูเยอรมัน
# 2866 ข้าวผัดกระเทียม
# 2867 ชาบู
# 2868 ปูผัดผงกะหรี่
# 2869 ข้าวหน้าเป็ด
# 2870 ยำหมูยอ
# 2871 ขนมถ้วย
# 2872 ชาบู
# 2873 ขนมปัง
# 2874 เนื้อย่าง
# 2875 ปูม้านึ่ง
# 2876 ก๋วยจั๊บ
# 2877 ขาหมูเยอรมัน
# 2878 ก๋วยเตี๋ยวเรือ
# 2879 ยำถั่วพลู
# 2880 ไข่กระทะ
# 2881 แกงคั่วหอยขม
# 2882 ยำถั่วพลู
# 2883 ยำปลาดุกฟู
# 2884 ข้าวหน้าเนื้อ
# 2885 ปอเปี๊ยะทอด
# 2886 น้ำพริกไข่ปู
# 2887 ยำสาหร่าย
# 2888 บะหมี่แห้ง
# 2889 honey toast
# 2890 ปูม้านึ่ง
# 2891 ยำสาหร่าย
# 2892 ยำสาหร่าย
# 2893 ข้าวหมูกรอบ
# 2894 เค้ก
# 2895 กระเพาะปลา
# 2896 สเต็กหมู
# 2897 ออส่วน
# 2898 ข้าวหน้าเนื้อ
# 2899 ขาหมูเยอรมัน
# 2900 honey toast
# 2901 ต้มเลือดหมู
# 2902 ทาโกะยากิ
# 2903 หมูมะนาว
# 2904 ยำถั่วพลู
# 2905 ยำปลาดุกฟู
# 2906 ชาบู
# 2907 สปาเก็ตตี้ขี้เมาทะเล
# 2908 ยำถั่วพลู
# 2909 ยำแซลมอน
# 2910 ยำแซลมอน
# 2911 น้ำพริกไข่ปู
# 2912 สปาเก็ตตี้คาโบนาร่า
# 2913 ก๋วยเตี๋ยวเรือ
# 2914 เค้ก
# 2915 ก๋วยเตี๋ยวเรือ
# 2916 ทาโกะยากิ
# 2917 ซุปเห็ด
# 2918 ขนมปังสังขยา
# 2919 ปูนิ่มทอดกระเทียม
# 2920 ข้าวหน้าเป็ด
# 2921 ไอศกรีม
# 2922 ไข่กระทะ
# 2923 ข้าวหมกไก่
# 2924 ปูผัดผงกะหรี่
# 2925 ปูม้านึ่ง
# 2926 ทาโกะยากิ
# 2927 ขาหมูเยอรมัน
# 2928 เค้ก
# 2929 ก๋วยเตี๋ยวเรือ
# 2930 ขนมปัง
# 2931 สเต็กหมู
# 2932 เกี๊ยวทอด
# 2933 ฮะเก๋า
# 2934 น้ำตกหมู
# 2935 กระเพาะปลา
# 2936 ข้าวผัดกระเทียม
# 2937 แกงคั่วหอยขม
# 2938 ข้าวผัดกระเทียม
# 2939 ข้าวหน้าเป็ด
# 2940 เค้ก
# 2941 ไอศกรีม
# 2942 บะหมี่แห้ง
# 2943 น้ำพริกไข่ปู
# 2944 ก๋วยเตี๋ยวเรือ
# 2945 ไอศกรีม
# 2946 ขนมปังปิ้ง
# 2947 ปูผัดผงกะหรี่
# 2948 ปูนิ่มทอดกระเทียม
# 2949 ออส่วน
# 2950 ซุปเห็ด
# 2951 ก๋วยเตี๋ยวคั่วไก่
# 2952 ขนมปัง
# 2953 ซุปเห็ด
# 2954 ข้าวหมกไก่
# 2955 ก๋วยเตี๋ยวเรือ
# 2956 ข้าวหมกไก่
# 2957 ปูม้านึ่ง
# 2958 ก๋วยจั๊บ
# 2959 ขนมปัง
# 2960 เค้ก
# 2961 ยำปลาดุกฟู
# 2962 ข้าวผัดกระเทียม
# 2963 ฮะเก๋า
# 2964 เป็ดพะโล้
# 2965 ออส่วน
# 2966 ยำถั่วพลู
# 2967 ฮะเก๋า
# 2968 ไข่กระทะ
# 2969 ข้าวหมูกรอบ
# 2970 ปูผัดผงกะหรี่
# 2971 ชาบู
# 2972 ปลากระพงนึ่งมะนาว
# 2973 ก๋วยจั๊บญวน
# 2974 ปลากระพงนึ่งมะนาว
# 2975 ข้าวหน้าเป็ด
# 2976 ชาบู
# 2977 ขนมปังปิ้ง
# 2978 ก๋วยจั๊บญวน
# 2979 เป็ดพะโล้
# 2980 น้ำตกหมู
# 2981 ชาบู
# 2982 ยำหมูยอ
# 2983 เนื้อย่าง
# 2984 ข้าวหน้าเป็ด
# 2985 ฮะเก๋า
# 2986 honey toast
# 2987 honey toast
# 2988 ยำปลาดุกฟู
# 2989 ต้มเลือดหมู
# 2990 แกงส้มชะอมกุ้ง
# 2991 ก๋วยเตี๋ยวคั่วไก่
# 2992 ขาหมูเยอรมัน
# 2993 สปาเก็ตตี้ขี้เมาทะเล
# 2994 ข้าวหน้าเนื้อ
# 2995 สเต็กหมู
# 2996 honey toast
# 2997 กระเพาะปลา
# 2998 ข้าวหมกไก่
# 2999 honey toast
# 3000 ข้าวหมกไก่
# 3001 ขนมปังสังขยา
# 3002 หมูมะนาว
# 3003 ขนมถ้วย
# 3004 ไส้อั่ว
# 3005 ข้าวหน้าเป็ด
# 3006 ยำสาหร่าย
# 3007 ไข่ตุ๋น
# 3008 สปาเก็ตตี้คาโบนาร่า
# 3009 ออส่วน
# 3010 ออส่วน
# 3011 ข้าวผัดกระเทียม
# 3012 ไข่ตุ๋น
# 3013 สปาเก็ตตี้คาโบนาร่า
# 3014 ก๋วยเตี๋ยวคั่วไก่
# 3015 ยำถั่วพลู
# 3016 ขนมถ้วย
# 3017 กระเพาะปลา
# 3018 ปอเปี๊ยะทอด
# 3019 ออส่วน
# 3020 แกงส้มชะอมกุ้ง
# 3021 ขาหมูเยอรมัน
# 3022 ไอศกรีม
# 3023 สปาเก็ตตี้คาโบนาร่า
# 3024 ขนมถ้วย
# 3025 ยำถั่วพลู
# 3026 ชาบู
# 3027 ไข่ตุ๋น
# ...
# 4016 ข้าวผัดกระเทียม
# 4017 ออส่วน
# 4018 ก๋วยจั๊บญวน
# 4019 ชาบู
# 4020 น้ำตกหมู
# 4021 เกี๊ยวทอด
# 4022 ก๋วยจั๊บญวน
# 4023 ยำสาหร่าย
# 4024 เป็ดย่าง
# 4025 ขนมปังปิ้ง
# 4026 เค้ก
# 4027 เค้ก
# 4028 ข้าวหน้าเป็ด
# 4029 ไส้อั่ว
# 4030 กระเพาะปลา
# 4031 เป็ดย่าง
# 4032 สเต็กหมู
# 4033 ยำหมูยอ
# 4034 แกงคั่วหอยขม
# 4035 ขาหมูเยอรมัน
# 4036 เค้ก
# 4037 honey toast
# 4038 สปาเก็ตตี้ขี้เมาทะเล
# 4039 ฮะเก๋า
# 4040 ก๋วยจั๊บ
# 4041 ปอเปี๊ยะทอด
# 4042 ก๋วยเตี๋ยวคั่วไก่
# 4043 สปาเก็ตตี้ขี้เมาทะเล
# 4044 ออส่วน
# 4045 หมูมะนาว
# 4046 เกี๊ยวทอด
# 4047 ปูนิ่มทอดกระเทียม
# 4048 ขาหมูเยอรมัน
# 4049 ก๋วยเตี๋ยวเรือ
# 4050 ก๋วยเตี๋ยวคั่วไก่
# 4051 สปาเก็ตตี้คาโบนาร่า
# 4052 กระเพาะปลา
# 4053 ต้มเลือดหมู
# 4054 ชาบู
# 4055 แกงคั่วหอยขม
# 4056 เป็ดย่าง
# 4057 ก๋วยเตี๋ยวเรือ
# 4058 ปอเปี๊ยะทอด
# 4059 ก๋วยเตี๋ยวเรือ
# 4060 แกงคั่วหอยขม
# 4061 หมูมะนาว
# 4062 ต้มเลือดหมู
# 4063 ไข่กระทะ
# 4064 ชาบู
# 4065 น้ำพริกไข่ปู
# 4066 บะหมี่แห้ง
# 4067 ก๋วยจั๊บ
# 4068 ปูผัดผงกะหรี่
# 4069 สเต็กหมู
# 4070 ซุปเห็ด
# 4071 ปูม้านึ่ง
# 4072 ข้าวหน้าเนื้อ
# 4073 ต้มเลือดหมู
# 4074 ต้มเลือดหมู
# 4075 ปูม้านึ่ง
# 4076 ยำแซลมอน
# 4077 ขนมปังปิ้ง
# 4078 ขนมถ้วย
# 4079 สปาเก็ตตี้ขี้เมาทะเล
# 4080 ไส้อั่ว
# 4081 แกงคั่วหอยขม
# 4082 ยำสาหร่าย
# 4083 น้ำตกหมู
# 4084 ทาโกะยากิ
# 4085 ยำหมูยอ
# 4086 เป็ดย่าง
# 4087 ฮะเก๋า
# 4088 ข้าวหน้าเนื้อ
# 4089 เกี๊ยวทอด
# 4090 แกงคั่วหอยขม
# 4091 ปลากระพงนึ่งมะนาว
# 4092 ยำแซลมอน
# 4093 honey toast
# 4094 แกงส้มชะอมกุ้ง
# 4095 ก๋วยเตี๋ยวเรือ
# 4096 ต้มเลือดหมู
# 4097 ขนมถ้วย
# 4098 ไส้อั่ว
# 4099 เค้ก
# 4100 ขาหมูเยอรมัน
# 4101 ไข่ตุ๋น
# 4102 ก๋วยจั๊บ
# 4103 สปาเก็ตตี้คาโบนาร่า
# 4104 หมูมะนาว
# 4105 แกงส้มชะอมกุ้ง
# 4106 ยำถั่วพลู
# 4107 ปูนิ่มทอดกระเทียม
# 4108 เนื้อย่าง
# 4109 แกงคั่วหอยขม
# 4110 ไอศกรีม
# 4111 สเต็กหมู
# 4112 เป็ดย่าง
# 4113 ยำปลาดุกฟู
# 4114 ขนมปังปิ้ง
# 4115 ซุปเห็ด
# 4116 ขนมปังสังขยา
# 4117 น้ำพริกไข่ปู
# 4118 ทาโกะยากิ
# 4119 เป็ดพะโล้
# 4120 เค้ก
# 4121 เค้ก
# 4122 เกี๊ยวทอด
# 4123 กระเพาะปลา
# 4124 ขนมปังปิ้ง
# 4125 ยำหมูยอ
# 4126 ยำถั่วพลู
# 4127 เป็ดย่าง
# 4128 เนื้อย่าง
# 4129 น้ำตกหมู
# 4130 honey toast
# 4131 ก๋วยเตี๋ยวคั่วไก่
# 4132 ปลากระพงนึ่งมะนาว
# 4133 ทาโกะยากิ
# 4134 ก๋วยเตี๋ยวเรือ
# 4135 ต้มเลือดหมู
# 4136 ปูนิ่มทอดกระเทียม
# 4137 น้ำพริกไข่ปู
# 4138 แกงส้มชะอมกุ้ง
# 4139 น้ำตกหมู
# 4140 ข้าวหมกไก่
# 4141 ทาโกะยากิ
# 4142 ยำสาหร่าย
# 4143 ยำแซลมอน
# 4144 ยำสาหร่าย
# 4145 แกงส้มชะอมกุ้ง
# 4146 ข้าวหมกไก่
# 4147 ฮะเก๋า
# 4148 ไส้อั่ว
# 4149 ปูผัดผงกะหรี่
# 4150 ข้าวหน้าเนื้อ
# 4151 ออส่วน
# 4152 honey toast
# 4153 ก๋วยจั๊บ
# 4154 honey toast
# 4155 ยำปลาดุกฟู
# 4156 บะหมี่แห้ง
# 4157 ขาหมูเยอรมัน
# 4158 ไอศกรีม
# 4159 ปลากระพงนึ่งมะนาว
# 4160 honey toast
# 4161 ยำแซลมอน
# 4162 ก๋วยจั๊บญวน
# 4163 ก๋วยเตี๋ยวเรือ
# 4164 ปูผัดผงกะหรี่
# 4165 สปาเก็ตตี้ขี้เมาทะเล
# 4166 ข้าวหน้าเนื้อ
# 4167 แกงส้มชะอมกุ้ง
# 4168 แกงคั่วหอยขม
# 4169 ยำแซลมอน
# 4170 ขนมปัง
# 4171 ก๋วยจั๊บ
# 4172 เป็ดพะโล้
# 4173 ไข่กระทะ
# 4174 ปลากระพงนึ่งมะนาว
# 4175 แกงส้มชะอมกุ้ง
# 4176 ยำแซลมอน
# 4177 ต้มเลือดหมู
# 4178 ปลากระพงนึ่งมะนาว
# 4179 แกงส้มชะอมกุ้ง
# 4180 ข้าวหมูกรอบ
# 4181 น้ำตกหมู
# 4182 ฮะเก๋า
# 4183 ขนมปังสังขยา
# 4184 ก๋วยเตี๋ยวคั่วไก่
# 4185 เค้ก
# 4186 เค้ก
# 4187 ก๋วยจั๊บญวน
# 4188 ชาบู
# 4189 honey toast
# 4190 ยำปลาดุกฟู
# 4191 ขนมปังปิ้ง
# 4192 ขนมถ้วย
# 4193 ก๋วยเตี๋ยวคั่วไก่
# 4194 เป็ดพะโล้
# 4195 เนื้อย่าง
# 4196 เกี๊ยวทอด
# 4197 ก๋วยเตี๋ยวเรือ
# 4198 ยำสาหร่าย
# 4199 ไข่ตุ๋น
# 4200 แกงส้มชะอมกุ้ง
# 4201 ข้าวหมกไก่
# 4202 ปลากระพงนึ่งมะนาว
# 4203 ทาโกะยากิ
# 4204 ข้าวหน้าเนื้อ
# 4205 ยำสาหร่าย
# 4206 honey toast
# 4207 สปาเก็ตตี้คาโบนาร่า
# 4208 ปูม้านึ่ง
# 4209 ยำหมูยอ
# 4210 กระเพาะปลา
# 4211 ก๋วยจั๊บ
# 4212 ข้าวหมูกรอบ
# 4213 สปาเก็ตตี้คาโบนาร่า
# 4214 ยำปลาดุกฟู
# 4215 ชาบู
# 4216 ไข่กระทะ
# 4217 น้ำตกหมู
# 4218 ปูนิ่มทอดกระเทียม
# 4219 แกงคั่วหอยขม
# 4220 ข้าวหน้าเป็ด
# 4221 ข้าวหมกไก่
# 4222 ยำสาหร่าย
# 4223 ข้าวหน้าเป็ด
# 4224 ยำปลาดุกฟู
# 4225 ปลากระพงนึ่งมะนาว
# 4226 ขนมปังสังขยา
# 4227 ทาโกะยากิ
# 4228 ไส้อั่ว
# 4229 ต้มเลือดหมู
# 4230 ขนมปังปิ้ง
# 4231 ยำสาหร่าย
# 4232 เนื้อย่าง
# 4233 เป็ดพะโล้
# 4234 ปูม้านึ่ง
# 4235 ไส้อั่ว
# 4236 ไส้อั่ว
# 4237 ขนมปังสังขยา
# 4238 กระเพาะปลา
# 4239 ทาโกะยากิ
# 4240 บะหมี่แห้ง
# 4241 ปูนิ่มทอดกระเทียม
# 4242 ข้าวหมูกรอบ
# 4243 กระเพาะปลา
# 4244 ข้าวหมูกรอบ
# 4245 ก๋วยเตี๋ยวเรือ
# 4246 ปอเปี๊ยะทอด
# 4247 เนื้อย่าง
# 4248 บะหมี่แห้ง
# 4249 เกี๊ยวทอด
# 4250 สปาเก็ตตี้คาโบนาร่า
# 4251 ก๋วยเตี๋ยวเรือ
# 4252 บะหมี่แห้ง
# 4253 ออส่วน
# 4254 ขนมปังปิ้ง
# 4255 ขนมถ้วย
# 4256 ขนมถ้วย
# 4257 น้ำพริกไข่ปู
# 4258 ยำแซลมอน
# 4259 ยำหมูยอ
# 4260 ฮะเก๋า
# 4261 ต้มเลือดหมู
# 4262 ปอเปี๊ยะทอด
# 4263 ซุปเห็ด
# 4264 เค้ก
# 4265 ขนมปังปิ้ง
# 4266 ข้าวหมูกรอบ
# 4267 ยำสาหร่าย
# 4268 ข้าวหน้าเป็ด
# 4269 ก๋วยจั๊บ
# 4270 ทาโกะยากิ
# 4271 บะหมี่แห้ง
# 4272 ข้าวหน้าเป็ด
# 4273 เป็ดพะโล้
# 4274 ชาบู
# 4275 น้ำพริกไข่ปู
# 4276 กระเพาะปลา
# 4277 ก๋วยจั๊บ
# 4278 ก๋วยจั๊บญวน
# 4279 ปลากระพงนึ่งมะนาว
# 4280 เค้ก
# 4281 ข้าวหน้าเนื้อ
# 4282 ไส้อั่ว
# 4283 honey toast
# 4284 ขนมปังปิ้ง
# 4285 เค้ก
# 4286 ยำถั่วพลู
# 4287 ยำถั่วพลู
# 4288 ยำสาหร่าย
# 4289 ฮะเก๋า
# 4290 ข้าวหมกไก่
# 4291 ข้าวหน้าเป็ด
# 4292 ยำหมูยอ
# 4293 ขนมปังสังขยา
# 4294 เนื้อย่าง
# 4295 เค้ก
# 4296 ทาโกะยากิ
# 4297 แกงคั่วหอยขม
# 4298 ก๋วยจั๊บ
# 4299 ข้าวผัดกระเทียม
# 4300 ข้าวหมกไก่
# 4301 ขาหมูเยอรมัน
# 4302 ยำถั่วพลู
# 4303 เป็ดย่าง
# 4304 ก๋วยเตี๋ยวเรือ
# 4305 ข้าวหน้าเป็ด
# 4306 ไข่กระทะ
# 4307 ชาบู
# 4308 ข้าวหน้าเนื้อ
# 4309 แกงส้มชะอมกุ้ง
# 4310 สปาเก็ตตี้ขี้เมาทะเล
# 4311 กระเพาะปลา
# 4312 น้ำตกหมู
# 4313 สปาเก็ตตี้ขี้เมาทะเล
# 4314 ก๋วยจั๊บญวน
# 4315 แกงคั่วหอยขม
# 4316 ไอศกรีม
# 4317 ซุปเห็ด
# 4318 ข้าวผัดกระเทียม
# 4319 เป็ดย่าง
# 4320 แกงคั่วหอยขม
# 4321 ปูนิ่มทอดกระเทียม
# 4322 ไข่กระทะ
# 4323 ยำหมูยอ
# 4324 เป็ดพะโล้
# 4325 ปอเปี๊ยะทอด
# 4326 ปอเปี๊ยะทอด
# 4327 แกงคั่วหอยขม
# 4328 สปาเก็ตตี้คาโบนาร่า
# 4329 ต้มเลือดหมู
# 4330 เป็ดพะโล้
# 4331 ขาหมูเยอรมัน
# 4332 ขนมถ้วย
# 4333 ยำสาหร่าย
# 4334 ยำถั่วพลู
# 4335 ยำหมูยอ
# 4336 สเต็กหมู
# 4337 ปอเปี๊ยะทอด
# 4338 หมูมะนาว
# 4339 ขาหมูเยอรมัน
# 4340 สเต็กหมู
# 4341 ยำหมูยอ
# 4342 กระเพาะปลา
# 4343 ต้มเลือดหมู
# 4344 ขาหมูเยอรมัน
# 4345 ยำถั่วพลู
# 4346 ไส้อั่ว
# 4347 น้ำตกหมู
# 4348 ปอเปี๊ยะทอด
# 4349 แกงคั่วหอยขม
# 4350 ปูนิ่มทอดกระเทียม
# 4351 หมูมะนาว
# 4352 ปูนิ่มทอดกระเทียม
# 4353 ไส้อั่ว
# 4354 เป็ดย่าง
# 4355 สปาเก็ตตี้คาโบนาร่า
# 4356 ข้าวหมกไก่
# 4357 ปูนิ่มทอดกระเทียม
# 4358 ปูผัดผงกะหรี่
# 4359 ชาบู
# 4360 ยำถั่วพลู
# 4361 ก๋วยจั๊บญวน
# 4362 ยำถั่วพลู
# 4363 honey toast
# 4364 เค้ก
# 4365 น้ำตกหมู
# 4366 ก๋วยจั๊บ
# 4367 ขนมถ้วย
# 4368 ซุปเห็ด
# 4369 ปูม้านึ่ง
# 4370 ข้าวหน้าเนื้อ
# 4371 บะหมี่แห้ง
# 4372 ปูผัดผงกะหรี่
# 4373 ขนมถ้วย
# 4374 ยำถั่วพลู
# 4375 ไข่ตุ๋น
# 4376 ไอศกรีม
# 4377 ยำสาหร่าย
# 4378 ยำหมูยอ
# 4379 เนื้อย่าง
# 4380 ข้าวหมูกรอบ
# 4381 น้ำพริกไข่ปู
# 4382 ไข่กระทะ
# 4383 ยำหมูยอ
# 4384 ขาหมูเยอรมัน
# 4385 เป็ดย่าง
# 4386 ข้าวหมูกรอบ
# 4387 น้ำตกหมู
# 4388 ปูนิ่มทอดกระเทียม
# 4389 แกงส้มชะอมกุ้ง
# 4390 เป็ดย่าง
# 4391 ปลากระพงนึ่งมะนาว
# 4392 ปูนิ่มทอดกระเทียม
# 4393 เป็ดพะโล้
# 4394 ขนมถ้วย
# 4395 สปาเก็ตตี้คาโบนาร่า
# 4396 สเต็กหมู
# 4397 ยำหมูยอ
# 4398 ยำสาหร่าย
# 4399 สปาเก็ตตี้ขี้เมาทะเล
# 4400 ยำหมูยอ
# 4401 เป็ดพะโล้
# 4402 น้ำตกหมู
# 4403 ข้าวหมกไก่
# 4404 สปาเก็ตตี้ขี้เมาทะเล
# 4405 ก๋วยเตี๋ยวคั่วไก่
# 4406 น้ำตกหมู
# 4407 แกงส้มชะอมกุ้ง
# 4408 เค้ก
# 4409 ไข่ตุ๋น
# 4410 ก๋วยเตี๋ยวเรือ
# 4411 เค้ก
# 4412 ข้าวหน้าเป็ด
# 4413 ขนมปังปิ้ง
# 4414 ก๋วยเตี๋ยวคั่วไก่
# 4415 ข้าวผัดกระเทียม
# 4416 ปูผัดผงกะหรี่
# 4417 ต้มเลือดหมู
# 4418 ยำหมูยอ
# 4419 ซุปเห็ด
# 4420 ก๋วยเตี๋ยวเรือ
# 4421 ออส่วน
# 4422 เป็ดพะโล้
# 4423 แกงคั่วหอยขม
# 4424 ก๋วยเตี๋ยวเรือ
# 4425 ขนมปังสังขยา
# 4426 หมูมะนาว
# 4427 แกงส้มชะอมกุ้ง
# 4428 ข้าวหมูกรอบ
# 4429 ปูนิ่มทอดกระเทียม
# 4430 ก๋วยจั๊บ
# 4431 สปาเก็ตตี้คาโบนาร่า
# 4432 ปลากระพงนึ่งมะนาว
# 4433 ทาโกะยากิ
# 4434 สปาเก็ตตี้ขี้เมาทะเล
# 4435 ยำแซลมอน
# 4436 หมูมะนาว
# 4437 ยำปลาดุกฟู
# 4438 เป็ดพะโล้
# 4439 เนื้อย่าง
# 4440 ก๋วยจั๊บญวน
# 4441 เป็ดพะโล้
# 4442 ปูนิ่มทอดกระเทียม
# 4443 ออส่วน
# 4444 ยำถั่วพลู
# 4445 ฮะเก๋า
# 4446 ไอศกรีม
# 4447 แกงคั่วหอยขม
# 4448 ซุปเห็ด
# 4449 ข้าวหน้าเป็ด
# 4450 สเต็กหมู
# 4451 ไข่กระทะ
# 4452 น้ำตกหมู
# 4453 ทาโกะยากิ
# 4454 น้ำพริกไข่ปู
# 4455 ต้มเลือดหมู
# 4456 ขนมปังสังขยา
# 4457 ปอเปี๊ยะทอด
# 4458 ปอเปี๊ยะทอด
# 4459 แกงคั่วหอยขม
# 4460 ไส้อั่ว
# 4461 ไอศกรีม
# 4462 เนื้อย่าง
# 4463 ปูนิ่มทอดกระเทียม
# 4464 เกี๊ยวทอด
# 4465 ต้มเลือดหมู
# 4466 ปูผัดผงกะหรี่
# 4467 เนื้อย่าง
# 4468 ขาหมูเยอรมัน
# 4469 ฮะเก๋า
# 4470 ซุปเห็ด
# 4471 ไข่กระทะ
# 4472 ยำแซลมอน
# 4473 บะหมี่แห้ง
# 4474 เกี๊ยวทอด
# 4475 ก๋วยจั๊บญวน
# 4476 ไอศกรีม
# 4477 ยำแซลมอน
# 4478 ข้าวหมกไก่
# 4479 ฮะเก๋า
# 4480 ยำหมูยอ
# 4481 ข้าวผัดกระเทียม
# 4482 สปาเก็ตตี้คาโบนาร่า
# 4483 ปูผัดผงกะหรี่
# 4484 ขนมปัง
# 4485 ข้าวผัดกระเทียม
# 4486 เกี๊ยวทอด
# 4487 ขนมถ้วย
# 4488 ก๋วยเตี๋ยวคั่วไก่
# 4489 แกงคั่วหอยขม
# 4490 ก๋วยเตี๋ยวคั่วไก่
# 4491 ไข่กระทะ
# 4492 ข้าวหน้าเนื้อ
# 4493 ก๋วยจั๊บ
# 4494 ขาหมูเยอรมัน
# 4495 ซุปเห็ด
# 4496 ข้าวหน้าเป็ด
# 4497 เป็ดย่าง
# 4498 น้ำพริกไข่ปู
# 4499 แกงคั่วหอยขม
# 4500 เป็ดพะโล้
# 4501 ไอศกรีม
# 4502 ก๋วยเตี๋ยวเรือ
# 4503 ขาหมูเยอรมัน
# 4504 สเต็กหมู
# 4505 ก๋วยจั๊บญวน
# 4506 honey toast
# 4507 บะหมี่แห้ง
# 4508 เป็ดย่าง
# 4509 ยำถั่วพลู
# 4510 บะหมี่แห้ง
# 4511 honey toast
# 4512 ไส้อั่ว
# 4513 ก๋วยเตี๋ยวเรือ
# 4514 ยำปลาดุกฟู
# 4515 ขนมปังปิ้ง
# 4516 ไส้อั่ว
# 4517 ปลากระพงนึ่งมะนาว
# 4518 หมูมะนาว
# 4519 เนื้อย่าง
# 4520 สเต็กหมู
# 4521 ฮะเก๋า
# 4522 ข้าวหน้าเป็ด
# 4523 ไอศกรีม
# 4524 สปาเก็ตตี้ขี้เมาทะเล
# 4525 ข้าวหน้าเนื้อ
# 4526 บะหมี่แห้ง
# 4527 แกงส้มชะอมกุ้ง
# 4528 ไข่ตุ๋น
# 4529 ยำปลาดุกฟู
# 4530 honey toast
# 4531 เป็ดย่าง
# 4532 ยำแซลมอน
# 4533 สปาเก็ตตี้ขี้เมาทะเล
# 4534 เค้ก
# 4535 ขนมถ้วย
# 4536 สปาเก็ตตี้คาโบนาร่า
# 4537 หมูมะนาว
# 4538 ซุปเห็ด
# 4539 แกงส้มชะอมกุ้ง
# 4540 ก๋วยจั๊บ
# 4541 ยำหมูยอ
# 4542 ยำแซลมอน
# 4543 ปอเปี๊ยะทอด
# 4544 ซุปเห็ด
# 4545 ขนมปังปิ้ง
# 4546 สปาเก็ตตี้ขี้เมาทะเล
# 4547 ต้มเลือดหมู
# 4548 ขนมปัง
# 4549 ต้มเลือดหมู
# 4550 ปูม้านึ่ง
# 4551 ไส้อั่ว
# 4552 ออส่วน
# 4553 ไอศกรีม
# 4554 ไข่กระทะ
# 4555 ยำหมูยอ
# 4556 ปูม้านึ่ง
# 4557 ไข่ตุ๋น
# 4558 ยำหมูยอ
# 4559 แกงส้มชะอมกุ้ง
# 4560 ซุปเห็ด
# 4561 ปูผัดผงกะหรี่
# 4562 บะหมี่แห้ง
# 4563 ยำปลาดุกฟู
# 4564 ก๋วยเตี๋ยวคั่วไก่
# 4565 น้ำตกหมู
# 4566 ปูนิ่มทอดกระเทียม
# 4567 ขาหมูเยอรมัน
# 4568 ซุปเห็ด
# 4569 ก๋วยจั๊บญวน
# 4570 เกี๊ยวทอด
# 4571 เกี๊ยวทอด
# 4572 แกงส้มชะอมกุ้ง
# 4573 แกงส้มชะอมกุ้ง
# 4574 เนื้อย่าง
# 4575 ข้าวหน้าเนื้อ
# 4576 เค้ก
# 4577 ข้าวหมูกรอบ
# 4578 ข้าวหมูกรอบ
# 4579 ยำถั่วพลู
# 4580 ทาโกะยากิ
# 4581 เป็ดย่าง
# 4582 ข้าวหมูกรอบ
# 4583 ไข่ตุ๋น
# 4584 ก๋วยเตี๋ยวคั่วไก่
# 4585 ไข่ตุ๋น
# 4586 เค้ก
# 4587 ปลากระพงนึ่งมะนาว
# 4588 เค้ก
# 4589 สเต็กหมู
# 4590 ขนมปังปิ้ง
# 4591 ข้าวหน้าเป็ด
# 4592 ปูม้านึ่ง
# 4593 ข้าวหมูกรอบ
# 4594 ข้าวหน้าเป็ด
# 4595 ไอศกรีม
# 4596 ไอศกรีม
# 4597 ทาโกะยากิ
# 4598 น้ำพริกไข่ปู
# 4599 น้ำตกหมู
# 4600 น้ำตกหมู
# 4601 แกงคั่วหอยขม
# 4602 ขนมถ้วย
# 4603 ข้าวหมูกรอบ
# 4604 ขนมปังปิ้ง
# 4605 กระเพาะปลา
# 4606 ข้าวหมกไก่
# 4607 ปูนิ่มทอดกระเทียม
# 4608 เค้ก
# 4609 เค้ก
# 4610 ข้าวหน้าเป็ด
# 4611 แกงคั่วหอยขม
# 4612 ซุปเห็ด
# 4613 ไข่กระทะ
# 4614 honey toast
# 4615 น้ำพริกไข่ปู
# 4616 หมูมะนาว
# 4617 ยำปลาดุกฟู
# 4618 ปลากระพงนึ่งมะนาว
# 4619 ปลากระพงนึ่งมะนาว
# 4620 ต้มเลือดหมู
# 4621 ก๋วยจั๊บ
# 4622 ไอศกรีม
# 4623 ฮะเก๋า
# 4624 ข้าวหมูกรอบ
# 4625 ก๋วยเตี๋ยวเรือ
# 4626 ไข่ตุ๋น
# 4627 เป็ดพะโล้
# 4628 น้ำพริกไข่ปู
# 4629 เป็ดย่าง
# 4630 ต้มเลือดหมู
# 4631 สเต็กหมู
# 4632 ก๋วยเตี๋ยวคั่วไก่
# 4633 เป็ดย่าง
# 4634 ปูผัดผงกะหรี่
# 4635 ขนมถ้วย
# 4636 น้ำพริกไข่ปู
# 4637 ปูผัดผงกะหรี่
# 4638 สเต็กหมู
# 4639 ข้าวผัดกระเทียม
# 4640 ปูม้านึ่ง
# 4641 ขนมปังสังขยา
# 4642 บะหมี่แห้ง
# 4643 ยำถั่วพลู
# 4644 honey toast
# 4645 กระเพาะปลา
# 4646 ชาบู
# 4647 ปอเปี๊ยะทอด
# 4648 ปูม้านึ่ง
# 4649 ปอเปี๊ยะทอด
# 4650 บะหมี่แห้ง
# 4651 ก๋วยเตี๋ยวคั่วไก่
# 4652 ชาบู
# 4653 ขนมปังปิ้ง
# 4654 ไข่ตุ๋น
# 4655 เนื้อย่าง
# 4656 ไข่ตุ๋น
# 4657 สปาเก็ตตี้คาโบนาร่า
# 4658 น้ำพริกไข่ปู
# 4659 ข้าวหมกไก่
# 4660 ก๋วยเตี๋ยวเรือ
# 4661 ก๋วยเตี๋ยวคั่วไก่
# 4662 ยำแซลมอน
# 4663 เค้ก
# 4664 ซุปเห็ด
# 4665 สปาเก็ตตี้ขี้เมาทะเล
# 4666 ก๋วยจั๊บญวน
# 4667 ขนมถ้วย
# 4668 ยำปลาดุกฟู
# 4669 ยำถั่วพลู
# 4670 ปูนิ่มทอดกระเทียม
# 4671 ทาโกะยากิ
# 4672 ไส้อั่ว
# 4673 เป็ดพะโล้
# 4674 ขนมปังสังขยา
# 4675 เป็ดย่าง
# 4676 ก๋วยเตี๋ยวคั่วไก่
# 4677 ก๋วยจั๊บ
# 4678 ชาบู
# 4679 เค้ก
# 4680 ซุปเห็ด
# 4681 ข้าวหมกไก่
# 4682 เป็ดย่าง
# 4683 ข้าวหน้าเนื้อ
# 4684 honey toast
# 4685 ไข่กระทะ
# 4686 ขนมถ้วย
# 4687 เกี๊ยวทอด
# 4688 ปูม้านึ่ง
# 4689 honey toast
# 4690 ปอเปี๊ยะทอด
# 4691 ก๋วยจั๊บญวน
# 4692 ขนมถ้วย
# 4693 ออส่วน
# 4694 ก๋วยเตี๋ยวเรือ
# 4695 ต้มเลือดหมู
# 4696 ปูม้านึ่ง
# 4697 กระเพาะปลา
# 4698 สเต็กหมู
# 4699 ยำปลาดุกฟู
# 4700 ขนมถ้วย
# 4701 เกี๊ยวทอด
# 4702 ยำหมูยอ
# 4703 แกงคั่วหอยขม
# 4704 ปอเปี๊ยะทอด
# 4705 ต้มเลือดหมู
# 4706 หมูมะนาว
# 4707 ฮะเก๋า
# 4708 ข้าวหน้าเป็ด
# 4709 ไข่กระทะ
# 4710 ไส้อั่ว
# 4711 ก๋วยเตี๋ยวเรือ
# 4712 ยำแซลมอน
# 4713 ชาบู
# 4714 ขนมปังสังขยา
# 4715 ทาโกะยากิ
# 4716 ปูผัดผงกะหรี่
# 4717 ปูนิ่มทอดกระเทียม
# 4718 สเต็กหมู
# 4719 ยำหมูยอ
# 4720 ยำถั่วพลู
# 4721 ทาโกะยากิ
# 4722 ไข่ตุ๋น
# 4723 ปูนิ่มทอดกระเทียม
# 4724 ข้าวผัดกระเทียม
# 4725 ขนมปัง
# 4726 สเต็กหมู
# 4727 ปอเปี๊ยะทอด
# 4728 ข้าวผัดกระเทียม
# 4729 ยำปลาดุกฟู
# 4730 สเต็กหมู
# 4731 ฮะเก๋า
# 4732 ฮะเก๋า
# 4733 ปอเปี๊ยะทอด
# 4734 ขนมปังสังขยา
# 4735 เป็ดย่าง
# 4736 ก๋วยเตี๋ยวคั่วไก่
# 4737 ต้มเลือดหมู
# 4738 เนื้อย่าง
# 4739 หมูมะนาว
# 4740 เกี๊ยวทอด
# 4741 ปูผัดผงกะหรี่
# 4742 honey toast
# 4743 ก๋วยเตี๋ยวเรือ
# 4744 ปูผัดผงกะหรี่
# 4745 ไอศกรีม
# 4746 ขนมปังปิ้ง
# 4747 สเต็กหมู
# 4748 ไอศกรีม
# 4749 ปอเปี๊ยะทอด
# 4750 ข้าวหน้าเป็ด
# 4751 บะหมี่แห้ง
# 4752 สปาเก็ตตี้คาโบนาร่า
# 4753 ขนมปังปิ้ง
# 4754 ก๋วยเตี๋ยวคั่วไก่
# 4755 ทาโกะยากิ
# 4756 เป็ดพะโล้
# 4757 ก๋วยเตี๋ยวเรือ
# 4758 ก๋วยเตี๋ยวคั่วไก่
# 4759 น้ำพริกไข่ปู
# 4760 ข้าวผัดกระเทียม
# 4761 สเต็กหมู
# 4762 ชาบู
# 4763 ไส้อั่ว
# 4764 ปูนิ่มทอดกระเทียม
# 4765 ข้าวหมกไก่
# 4766 น้ำพริกไข่ปู
# 4767 ฮะเก๋า
# 4768 ก๋วยเตี๋ยวคั่วไก่
# 4769 กระเพาะปลา
# 4770 เป็ดพะโล้
# 4771 บะหมี่แห้ง
# 4772 ปูผัดผงกะหรี่
# 4773 ออส่วน
# 4774 ยำถั่วพลู
# 4775 ต้มเลือดหมู
# 4776 ข้าวหน้าเป็ด
# 4777 หมูมะนาว
# 4778 เค้ก
# 4779 น้ำพริกไข่ปู
# 4780 ไข่ตุ๋น
# 4781 เค้ก
# 4782 น้ำพริกไข่ปู
# 4783 กระเพาะปลา
# 4784 น้ำพริกไข่ปู
# 4785 สปาเก็ตตี้คาโบนาร่า
# 4786 ยำแซลมอน
# 4787 สปาเก็ตตี้ขี้เมาทะเล
# 4788 ชาบู
# 4789 ขนมปังปิ้ง
# 4790 เป็ดพะโล้
# 4791 ยำถั่วพลู
# 4792 ยำแซลมอน
# 4793 ปอเปี๊ยะทอด
# 4794 ยำถั่วพลู
# 4795 เค้ก
# 4796 honey toast
# 4797 ข้าวผัดกระเทียม
# 4798 น้ำพริกไข่ปู
# 4799 น้ำตกหมู
# 4800 ซุปเห็ด
# 4801 ไอศกรีม
# 4802 ก๋วยจั๊บญวน
# 4803 ยำหมูยอ
# 4804 ยำปลาดุกฟู
# 4805 น้ำพริกไข่ปู
# 4806 ปูผัดผงกะหรี่
# 4807 เป็ดย่าง
# 4808 ไข่กระทะ
# 4809 ข้าวผัดกระเทียม
# 4810 ต้มเลือดหมู
# 4811 เป็ดพะโล้
# 4812 ข้าวผัดกระเทียม
# 4813 ก๋วยจั๊บญวน
# 4814 ขนมปังสังขยา
# 4815 ยำสาหร่าย
# 4816 ยำแซลมอน
# 4817 ไข่กระทะ
# 4818 ก๋วยเตี๋ยวคั่วไก่
# 4819 ยำปลาดุกฟู
# 4820 เกี๊ยวทอด
# 4821 เกี๊ยวทอด
# 4822 ปลากระพงนึ่งมะนาว
# 4823 กระเพาะปลา
# 4824 ฮะเก๋า
# 4825 ยำปลาดุกฟู
# 4826 ก๋วยเตี๋ยวเรือ
# 4827 ไข่กระทะ
# 4828 ขนมปังสังขยา
# 4829 เกี๊ยวทอด
# 4830 ยำหมูยอ
# 4831 ออส่วน
# 4832 ข้าวผัดกระเทียม
# 4833 ขนมปัง
# 4834 สเต็กหมู
# 4835 เนื้อย่าง
# 4836 หมูมะนาว
# 4837 เนื้อย่าง
# 4838 ขนมปังสังขยา
# 4839 แกงคั่วหอยขม
# 4840 ขนมปังปิ้ง
# 4841 ขาหมูเยอรมัน
# 4842 ขนมปังปิ้ง
# 4843 สเต็กหมู
# 4844 ขนมปัง
# 4845 แกงคั่วหอยขม
# 4846 น้ำพริกไข่ปู
# 4847 ชาบู
# 4848 ข้าวผัดกระเทียม
# 4849 ไอศกรีม
# 4850 สปาเก็ตตี้คาโบนาร่า
# 4851 เป็ดพะโล้
# 4852 ไอศกรีม
# 4853 ข้าวผัดกระเทียม
# 4854 ฮะเก๋า
# 4855 เค้ก
# 4856 เป็ดย่าง
# 4857 ก๋วยจั๊บ
# 4858 เป็ดย่าง
# 4859 น้ำพริกไข่ปู
# 4860 ปลากระพงนึ่งมะนาว
# 4861 ยำแซลมอน
# 4862 ขนมปัง
# 4863 ข้าวหน้าเป็ด
# 4864 ข้าวหมกไก่
# 4865 ปูม้านึ่ง
# 4866 ขนมปัง
# 4867 ปลากระพงนึ่งมะนาว
# 4868 ชาบู
# 4869 เกี๊ยวทอด
# 4870 ยำหมูยอ
# 4871 ยำถั่วพลู
# 4872 ไอศกรีม
# 4873 เกี๊ยวทอด
# 4874 ข้าวหมกไก่
# 4875 honey toast
# 4876 ข้าวหมกไก่
# 4877 ก๋วยจั๊บ
# 4878 น้ำตกหมู
# 4879 honey toast
# 4880 ไข่กระทะ
# 4881 ข้าวหมูกรอบ
# 4882 ข้าวหมูกรอบ
# 4883 ก๋วยเตี๋ยวเรือ
# 4884 ข้าวหมกไก่
# 4885 ข้าวหน้าเป็ด
# 4886 ข้าวหน้าเนื้อ
# 4887 ไข่กระทะ
# 4888 honey toast
# 4889 ทาโกะยากิ
# 4890 ยำถั่วพลู
# 4891 ยำถั่วพลู
# 4892 สปาเก็ตตี้คาโบนาร่า
# 4893 ปูผัดผงกะหรี่
# 4894 เป็ดย่าง
# 4895 ต้มเลือดหมู
# 4896 ไข่ตุ๋น
# 4897 ฮะเก๋า
# 4898 ยำหมูยอ
# 4899 เป็ดย่าง
# 4900 ข้าวหมกไก่
# 4901 ขนมปังปิ้ง
# 4902 ข้าวหมูกรอบ
# 4903 ปูม้านึ่ง
# 4904 ก๋วยเตี๋ยวเรือ
# 4905 แกงส้มชะอมกุ้ง
# 4906 เนื้อย่าง
# 4907 ปอเปี๊ยะทอด
# 4908 ปูม้านึ่ง
# 4909 ยำถั่วพลู
# 4910 กระเพาะปลา
# 4911 ข้าวหมูกรอบ
# 4912 ข้าวหน้าเป็ด
# 4913 ก๋วยเตี๋ยวเรือ
# 4914 ชาบู
# 4915 เกี๊ยวทอด
# 4916 สเต็กหมู
# 4917 ข้าวผัดกระเทียม
# 4918 ปูนิ่มทอดกระเทียม
# 4919 ปูม้านึ่ง
# 4920 เนื้อย่าง
# 4921 เนื้อย่าง
# 4922 ยำแซลมอน
# 4923 ออส่วน
# 4924 สเต็กหมู
# 4925 แกงคั่วหอยขม
# 4926 ออส่วน
# 4927 ยำปลาดุกฟู
# 4928 แกงคั่วหอยขม
# 4929 ข้าวหน้าเนื้อ
# 4930 ชาบู
# 4931 น้ำพริกไข่ปู
# 4932 ซุปเห็ด
# 4933 ข้าวหมูกรอบ
# 4934 ก๋วยเตี๋ยวคั่วไก่
# 4935 ก๋วยจั๊บ
# 4936 ข้าวผัดกระเทียม
# 4937 ปูนิ่มทอดกระเทียม
# 4938 ก๋วยจั๊บญวน
# 4939 ข้าวผัดกระเทียม
# 4940 ขนมปังสังขยา
# 4941 ปอเปี๊ยะทอด
# 4942 น้ำตกหมู
# 4943 เกี๊ยวทอด
# 4944 ไข่ตุ๋น
# 4945 สเต็กหมู
# 4946 ก๋วยเตี๋ยวเรือ
# 4947 ฮะเก๋า
# 4948 ก๋วยจั๊บญวน
# 4949 ก๋วยเตี๋ยวเรือ
# 4950 ข้าวหน้าเนื้อ
# 4951 ขาหมูเยอรมัน
# 4952 ข้าวหมกไก่
# 4953 ข้าวหมกไก่
# 4954 เนื้อย่าง
# 4955 ต้มเลือดหมู
# 4956 น้ำพริกไข่ปู
# 4957 เนื้อย่าง
# 4958 บะหมี่แห้ง
# 4959 เนื้อย่าง
# 4960 หมูมะนาว
# 4961 ชาบู
# 4962 เป็ดพะโล้
# 4963 ขนมปังสังขยา
# 4964 ไข่กระทะ
# 4965 ซุปเห็ด
# 4966 หมูมะนาว
# 4967 สปาเก็ตตี้ขี้เมาทะเล
# 4968 ขาหมูเยอรมัน
# 4969 ก๋วยจั๊บ
# 4970 แกงส้มชะอมกุ้ง
# 4971 เป็ดย่าง
# 4972 ซุปเห็ด
# 4973 ยำแซลมอน
# 4974 เป็ดพะโล้
# 4975 ขนมถ้วย
# 4976 ข้าวหน้าเป็ด
# 4977 ปูผัดผงกะหรี่
# 4978 ยำปลาดุกฟู
# 4979 ยำสาหร่าย
# 4980 ไข่กระทะ
# 4981 ข้าวหน้าเป็ด
# 4982 ขนมถ้วย
# 4983 ชาบู
# 4984 ปลากระพงนึ่งมะนาว
# 4985 ยำปลาดุกฟู
# 4986 ปูนิ่มทอดกระเทียม
# 4987 ก๋วยเตี๋ยวคั่วไก่
# 4988 ชาบู
# 4989 แกงคั่วหอยขม
# 4990 ยำสาหร่าย
# 4991 ข้าวผัดกระเทียม
# 4992 ก๋วยจั๊บ
# 4993 สปาเก็ตตี้คาโบนาร่า
# 4994 ปลากระพงนึ่งมะนาว
# 4995 น้ำตกหมู
# 4996 ข้าวหน้าเนื้อ
# 4997 ขนมปังสังขยา
# 4998 แกงคั่วหอยขม
# 4999 ฮะเก๋า
# 5000 เกี๊ยวทอด

# %%
#### Design you network here ####
class foodNet(nn.Module):
  def __init__(self,):
    super(foodNet, self).__init__()
    ### Layers goes here ###
  def forward(self, input):
    ### Conntections goes here ###
    return ?

# %% [markdown]
# ## Construct the model, optimizer and loss function

# %%
#### FILL HERE ####
foodNet.cuda()

criterion = 
optimizer = 
scheduler =

foodTrainDatasetLoader = 
foodValDatasetLoader =

# %% [markdown]
# ## Train the model

# %%
### Train and test helper function ###
def testModel(testDatasetLoader, net):
  net.eval()
  correctImages = 0
  totalImages = 0
  allLabels = []
  allPredicted = []
  testingProgressbar = tqdm(enumerate(testDatasetLoader), total=len(testDatasetLoader), ncols=100)
  with torch.no_grad():
    for batchIdx, batchData in testingProgressbar:
      images, labels = batchData
      
      images, labels = images.cuda(), labels.cuda()
      outputs = net(images)
      _, predicted = torch.max(outputs, 1)

      correctImages += (predicted == labels).sum().item()
      totalImages += labels.size(0)

      accumulateAccuracy = round((correctImages/totalImages)*100,4)
      testingProgressbar.set_description("Testing accuracy: {}".format(accumulateAccuracy ) )
    
      allLabels.append(labels)
      allPredicted.append(predicted)
  allLabels = torch.cat(allLabels).cpu().numpy()
  allPredicted = torch.cat(allPredicted).cpu().numpy()
  return correctImages, totalImages, allLabels, allPredicted

def trainAndTestModel(trainDatasetLoader, testDatasetLoader, net, optimizer,scheduler, criterion, trainEpoch):
  
  bestAccuracy = 0
  correctImages = 0
  totalImages = 0
  for currentEpoch in tqdm(range(trainEpoch), desc='Overall Training Progress:', ncols=100):
    trainingLoss = 0.0
    net.train()
    print('Epoch',str(currentEpoch+1),'/',str(trainEpoch))
    trainingProgressbar = tqdm(enumerate(trainDatasetLoader), total=len(trainDatasetLoader), ncols=100)
    for batchIdx, batchData in trainingProgressbar:
      images, labels = batchData
      images, labels = images.cuda(), labels.cuda()

      # zero the parameter gradients
      optimizer.zero_grad()

      # forward + backward + optimize
      outputs = net(images)
      loss = criterion(outputs, labels)
    
      _, predicted = torch.max(outputs, 1)
      correctImages += (predicted == labels).sum().item()
      totalImages += labels.size(0)
    
      loss.backward()
      optimizer.step()
      

      trainingLoss += loss.item()
      accumulateAccuracy = round((correctImages/totalImages)*100,4)
      trainingProgressbar.set_description("Training accuracy: {} loss: {}".format(accumulateAccuracy, round(loss.item(),4) ) )
    scheduler.step(trainingLoss)
    correctImages, totalImages, allLabels, allPredicted = testModel(testDatasetLoader, net)
    testAccuracy = round((correctImages/totalImages)*100,2)

    print('='*10)
    
    if testAccuracy > bestAccuracy:
      bestAccuracy = testAccuracy
      bestPredicted = allPredicted
      bestNet = net

  return bestAccuracy, bestPredicted, allLabels, bestNet

# %%
bestAccuracy, bestPredicted, allLabels, bestNet = trainAndTestModel(??)

# %% [markdown]
# ## Classify on validation set and send result to server!

# %%
from PIL import Image
import json
import requests

class ImageFolderWithPaths(Dataset):
    def __init__(self, root_dir, transform=None):
        self.imageFileNames = sorted(glob.glob(root_dir+'/*.jpg'))
        self.transform = transform
    
    def __getitem__(self, idx):
        imageData = Image.oppredicpath.basename(self.imageFileNames[idx])
        if self.transform is not None:
            imageData = self.transform(imageData)
        return imageFileName, imageData.unsqueeze(0)
    def __len__(self):
        return len(self.imageFileNames)



def generatePredictedResults(valDataset, net):
    net.eval()
    predictedResults = {}
    with torch.no_grad():
        for imageFileName, imageData in tqdm(valDataset, ncols=100):
            imageData = imageData.cuda()
            outputs = net(imageData)
            _, predicted = torch.max(outputs, 1)
            #print(imageFileName, predicted.item())
            predictedResults[imageFileName] =  foodTrainDataset.classes[predicted.item()]
    return predictedResults

def sendResult(predictedResults,studentID=6432085221):
    sendDict = { 'studentID':studentID, 'results':  predictedResults }
    print(sendDict)
    response = requests.post('https://www.piclab.ai/classes/cv2023/lab8/scoreboard/submit',headers={'Content-Type': 'application/json' }, json=sendDict)
    return response.text

# %% [markdown]
# Example Result JSON <br>
# resultDict = {
#   'studentID': 555555555521,
#   'results':{
#     '1.jpg':'ต้มเลือดหมู',
#     '2.jpg':'บะหมี่แห้ง',
#     ...
#   }
# }

# %%
# foodTestDataset = ImageFolderWithPaths('test', transform=transformTest)
# predictedResults = generatePredictedResults(foodTestDataset, bestNet)
predictedResults = resultDict
print(sendResult(predictedResults, studentID=6432085221))
# Out:
# {'studentID': 6432085221, 'results': {'1.jpg': 'honey toast', '10.jpg': 'ข้าวหมูกรอบ', '100.jpg': 'ทาโกะยากิ', '1000.jpg': 'น้ำตกหมู', '1001.jpg': 'ก๋วยจั๊บ', '1002.jpg': 'ปูผัดผงกะหรี่', '1003.jpg': 'ยำสาหร่าย', '1004.jpg': 'ก๋วยเตี๋ยวคั่วไก่', '1005.jpg': 'ข้าวผัดกระเทียม', '1006.jpg': 'ข้าวหมูกรอบ', '1007.jpg': 'ก๋วยเตี๋ยวคั่วไก่', '1008.jpg': 'ปูผัดผงกะหรี่', '1009.jpg': 'ขนมถ้วย', '101.jpg': 'แกงส้มชะอมกุ้ง', '1010.jpg': 'ยำแซลมอน', '1011.jpg': 'ก๋วยเตี๋ยวคั่วไก่', '1012.jpg': 'ข้าวผัดกระเทียม', '1013.jpg': 'ไส้อั่ว', '1014.jpg': 'ข้าวหมกไก่', '1015.jpg': 'เป็ดพะโล้', '1016.jpg': 'เป็ดย่าง', '1017.jpg': 'แกงคั่วหอยขม', '1018.jpg': 'ต้มเลือดหมู', '1019.jpg': 'ชาบู', '102.jpg': 'ไข่กระทะ', '1020.jpg': 'ไข่กระทะ', '1021.jpg': 'ปูนิ่มทอดกระเทียม', '1022.jpg': 'ปลากระพงนึ่งมะนาว', '1023.jpg': 'เป็ดพะโล้', '1024.jpg': 'ข้าวหน้าเนื้อ', '1025.jpg': 'น้ำตกหมู', '1026.jpg': 'ฮะเก๋า', '1027.jpg': 'เค้ก', '1028.jpg': 'ขนมถ้วย', '1029.jpg': 'เกี๊ยวทอด', '103.jpg': 'บะหมี่แห้ง', '1030.jpg': 'สปาเก็ตตี้ขี้เมาทะเล', '1031.jpg': 'ขนมปังปิ้ง', '1032.jpg': 'เนื้อย่าง', '1033.jpg': 'แกงคั่วหอยขม', '1034.jpg': 'ไอศกรีม', '1035.jpg': 'ต้มเลือดหมู', '1036.jpg': 'ฮะเก๋า', '1037.jpg': 'ปูม้านึ่ง', '1038.jpg': 'ปลากระพงนึ่งมะนาว', '1039.jpg': 'ขาหมูเยอรมัน', '104.jpg': 'ยำแซลมอน', '1040.jpg': 'กระเพาะปลา', '1041.jpg': 'กระเพาะปลา', '1042.jpg': 'ปอเปี๊ยะทอด', '1043.jpg': 'ยำถั่วพลู', '1044.jpg': 'ยำสาหร่าย', '1045.jpg': 'สปาเก็ตตี้คาโบนาร่า', '1046.jpg': 'ฮะเก๋า', '1047.jpg': 'ต้มเลือดหมู', '1048.jpg': 'ยำหมูยอ', '1049.jpg': 'น้ำพริกไข่ปู', '105.jpg': 'ยำถั่วพลู', '1050.jpg': 'ข้าวหมกไก่', '1051.jpg': 'ซุปเห็ด', '1052.jpg': 'ซุปเห็ด', '1053.jpg': 'ไข่ตุ๋น', '1054.jpg': 'ยำแซลมอน', '1055.jpg': 'ขนมปังสังขยา', '1056.jpg': 'ขนมปัง', '1057.jpg': 'สเต็กหมู', '1058.jpg': 'เค้ก', '1059.jpg': 'ยำแซลมอน', '106.jpg': 'แกงคั่วหอยขม', '1060.jpg': 'สปาเก็ตตี้ขี้เมาทะเล', '1061.jpg': 'ข้าวหมกไก่', '1062.jpg': 'ขนมปังปิ้ง', '1063.jpg': 'ไข่ตุ๋น', '1064.jpg': 'ขนมถ้วย', '1065.jpg': 'ซุปเห็ด', '1066.jpg': 'ขนมปังปิ้ง', '1067.jpg': 'บะหมี่แห้ง', '1068.jpg': 'ปูม้านึ่ง', '1069.jpg': 'ขนมปังสังขยา', '107.jpg': 'ไอศกรีม', '1070.jpg': 'ทาโกะยากิ', '1071.jpg': 'ฮะเก๋า', '1072.jpg': 'เป็ดย่าง', '1073.jpg': 'ยำหมูยอ', '1074.jpg': 'ข้าวหมกไก่', '1075.jpg': 'แกงส้มชะอมกุ้ง', '1076.jpg': 'แกงส้มชะอมกุ้ง', '1077.jpg': 'เกี๊ยวทอด', '1078.jpg': 'ปลากระพงนึ่งมะนาว', '1079.jpg': 'สเต็กหมู', '108.jpg': 'แกงคั่วหอยขม', '1080.jpg': 'ปูผัดผงกะหรี่', '1081.jpg': 'ยำหมูยอ', '1082.jpg': 'ยำถั่วพลู', '1083.jpg': 'ข้าวหน้าเป็ด', '1084.jpg': 'ปลากระพงนึ่งมะนาว', '1085.jpg': 'ก๋วยเตี๋ยวคั่วไก่', '1086.jpg': 'ก๋วยเตี๋ยวคั่วไก่', '1087.jpg': 'ชาบู', '1088.jpg': 'ชาบู', '1089.jpg': 'ปูนิ่มทอดกระเทียม', '109.jpg': 'เนื้อย่าง', '1090.jpg': 'ข้าวหมกไก่', '1091.jpg': 'ก๋วยจั๊บ', '1092.jpg': 'ยำปลาดุกฟู', '1093.jpg': 'เค้ก', '1094.jpg': 'เป็ดย่าง', '1095.jpg': 'ปูนิ่มทอดกระเทียม', '1096.jpg': 'ขนมปังปิ้ง', '1097.jpg': 'ข้าวหน้าเนื้อ', '1098.jpg': 'ก๋วยเตี๋ยวคั่วไก่', '1099.jpg': 'ขนมปัง', '11.jpg': 'ปอเปี๊ยะทอด', '110.jpg': 'ออส่วน', '1100.jpg': 'ขนมปัง', '1101.jpg': 'สปาเก็ตตี้ขี้เมาทะเล', '1102.jpg': 'บะหมี่แห้ง', '1103.jpg': 'ขาหมูเยอรมัน', '1104.jpg': 'ข้าวหน้าเป็ด', '1105.jpg': 'เป็ดพะโล้', '1106.jpg': 'ข้าวหมูกรอบ', '1107.jpg': 'ไข่กระทะ', '1108.jpg': 'ข้าวหน้าเนื้อ', '1109.jpg': 'ขนมปังปิ้ง', '111.jpg': 'ยำแซลมอน', '1110.jpg': 'ไอศกรีม', '1111.jpg': 'บะหมี่แห้ง', '1112.jpg': 'กระเพาะปลา', '1113.jpg': 'บะหมี่แห้ง', '1114.jpg': 'แกงส้มชะอมกุ้ง', '1115.jpg': 'ก๋วยจั๊บ', '1116.jpg': 'ขนมปังปิ้ง', '1117.jpg': 'ไส้อั่ว', '1118.jpg': 'ยำหมูยอ', '1119.jpg': 'ออส่วน', '112.jpg': 'น้ำพริกไข่ปู', '1120.jpg': 'ขนมปังปิ้ง', '1121.jpg': 'ข้าวหน้าเป็ด', '1122.jpg': 'ข้าวหมกไก่', '1123.jpg': 'ปอเปี๊ยะทอด', '1124.jpg': 'แกงคั่วหอยขม', '1125.jpg': 'เป็ดย่าง', '1126.jpg': 'ยำปลาดุกฟู', '1127.jpg': 'ปูผัดผงกะหรี่', '1128.jpg': 'ก๋วยเตี๋ยวคั่วไก่', '1129.jpg': 'ก๋วยเตี๋ยวเรือ', '113.jpg': 'ไข่ตุ๋น', '1130.jpg': 'ไข่กระทะ', '1131.jpg': 'ข้าวหน้าเนื้อ', '1132.jpg': 'ไอศกรีม', '1133.jpg': 'ออส่วน', '1134.jpg': 'ต้มเ ...
# {"accuracy":"92.9","status":"SUCCESS"}
