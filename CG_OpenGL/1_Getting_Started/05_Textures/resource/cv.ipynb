# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.array(cv.imread('./image_2.jpg', cv.IMREAD_UNCHANGED)[:, :, ::-1])
print(img.shape)
print(img.min(), img.max())
plt.imshow(img, cmap='gray')

cv.imwrite('image_4.jpg', img)
# Out:
# (278, 278, 3)
# 0 241
# True
